# %%
from b_fetch_data import fetch_news
from e_main import final

# %%
tickers=['AMZN', 'TSLA', 'GOOGL', 'ADBE', 'AXP', 'META', 'NVDA' ,'SPOT' ,'MSFT' ,'JPM']

# %% [markdown]
# ### For Amazon Stocks- AMZN ______________________________________________________________________________________

# %%
ticker=tickers[0]
news=fetch_news(f"{ticker}")
final(f'{ticker}',0.03,10000,news)
# Out:
# Fetching news for AMZN...
# Fetching news headlines...
#   0%|          | 0/199 [00:00<?, ?it/s]
# 9950 headlines scraped from 200 pages
# Fetching stock prices for AMZN ...
# [*********************100%%**********************]  1 of 1 completed
# Simulating trades for AMZN...
#         date  type       price       capital     profit
# 0 2020-10-15   buy  166.932495    150.982788        NaN
# 1 2021-07-02  sell  175.548996  10667.149568  516.16678
# 2 2021-07-07   buy  184.828995    131.896868        NaN
#
# Initial capital: $10000
# Total Trades: 1
# Win Percentage: 100.00%
# Total Portfolio Returns: $516.17
# Sharpe ratio:nan with risk free rate of 0.03
# Max drawdown: 0.0

# %% [markdown]
# ### For Google stocks- GOOGL _______________________________________________________________________________________

# %%
ticker=tickers[2]
news=fetch_news(f"{ticker}")
final(f'{ticker}',0.03,10000,news)
# Out:
# Fetching news for GOOGL...
# Fetching news headlines...
#   0%|          | 0/199 [00:00<?, ?it/s]
# 9950 headlines scraped from 200 pages
# Fetching stock prices for GOOGL ...
# [*********************100%%**********************]  1 of 1 completed
# Simulating trades for GOOGL...
#          date  type       price       capital       profit
# 0  2017-10-06   buy   49.681999     13.918159          NaN
# 1  2017-11-01  sell   52.130001  10506.652329   492.734169
# 2  2017-11-08   buy   52.914501     29.581093          NaN
# 3  2017-11-28  sell   53.164501  10585.873181    49.639759
# 4  2017-12-05   buy   50.980000     33.013276          NaN
# 5  2018-01-08  sell   55.710499  11601.163149   982.276692
# 6  2018-02-07   buy   52.770500     44.423609          NaN
# 7  2018-02-21  sell   55.687500  12286.865327   641.278568
# 8  2018-03-06   buy   55.044998     11.830735          NaN
# 9  2018-03-13  sell   56.995499  12734.076889   435.380827
# ...

# %% [markdown]
# ### For Adobe Stocks - ADBE ____________________________________________________________________________________

# %%
ticker=tickers[3]
news=fetch_news(f"{ticker}")
final(f'{ticker}',0.03,10000,news)
# Out:
# Fetching news for ADBE...
# Fetching news headlines...
#   0%|          | 0/199 [00:00<?, ?it/s]
# 1699 headlines scraped from 200 pages
# Fetching stock prices for ADBE ...
# [*********************100%%**********************]  1 of 1 completed
# Simulating trades for ADBE...
#          date  type       price        capital        profit
# 0  2013-06-18   buy   43.360001      27.199860           NaN
# 1  2014-09-16  sell   70.730003   16339.469777   6312.269917
# 2  2015-01-14   buy   69.989998      31.800275           NaN
# 3  2016-10-20  sell  109.029999   25485.328267   9114.058216
# 4  2016-10-27   buy  107.070000       2.668340           NaN
# 5  2017-07-25  sell  148.210007   35280.343546   9792.346939
# 6  2017-07-27   buy  146.199997      46.144282           NaN
# 7  2017-08-14  sell  149.160004   36040.783697    714.295868
# 8  2017-09-07   buy  155.470001     127.213415           NaN
# 9  2018-12-14  sell  230.000000   53445.411042  17277.413931
# ...
