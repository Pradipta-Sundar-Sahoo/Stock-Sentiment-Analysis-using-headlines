# 28  7 Stocks to Buy if the Market Ends Up Plunging... 2024-05-24
# 29  Strap In for Gains: 7 High-Octane Tech Stocks ... 2024-05-26
# 30  The Bull Market Blastoff: 3 Stocks Ready to Sk... 2024-05-27
# 31  3 Sorry Big Data Stocks to Sell in May While Y... 2024-05-28
# 32  Q1 Winners: S&P 500 Stocks Ready to Rocket on ... 2024-05-29
# 33  Amazon And Grubhub Partner To Enhance Convenie... 2024-05-30
# 34  Analysts Have Conflicting Sentiments on These ... 2024-05-31
# 35  Amazon (NASDAQ:AMZN): Prepping for Its Next De... 2024-06-01
# 36  Apple Stock Outlook: The Calm Before the AI St... 2024-06-03
# 37  The Next Nvidia? 3 Stocks With the Potential t... 2024-06-04
# 38  Jefferies Reaffirms Their Buy Rating on Amazon... 2024-06-05
# 39  Amazon Labor Union Formally Affiliates With Te... 2024-06-06
# 40  Cathie Wood-Led Ark Invest Buys $9.9M Worth Of... 2024-06-07
# 41  The 3 Most Undervalued EV Stocks to Buy in Jun... 2024-06-08
# 42  The 3 Most Undervalued Warren Buffett Stocks t... 2024-06-09
# 43  Schwab Trading Activity Index rises slightly i... 2024-06-10
# 44  Amazon’s Expansion and Margin Improvement Outl... 2024-06-11
# 45  Amazon Adds $1.4 Bln To Housing Equity Fund  A... 2024-06-12
# 46  UBS Keeps Their Buy Rating on Amazon (AMZN) AM... 2024-06-13
# 47  AI Artisans: 3 Stocks Crafting the Future of I... 2024-06-14
# 48  Stock Splits 101: The 5 Most Common Questions ... 2024-06-15
# 49  3 Reasons to Buy Amazon Stock Now 3 Stocks to ... 2024-06-17
# 50  Cathie Wood-Led Ark Picks Up $5.3M Worth Of TS... 2024-06-18

# %%
# !pip install -q yfinance

import yfinance as yf

def process(data):
    data["Tomorrow"] = data["Close"].shift(-1)
    data["target"] = (data["Tomorrow"] > data["Close"]).astype(int)
    # data['P/L'] = data["Close"]-data['Open']
    data.drop(columns=['Volume','Adj Close'], inplace = True)
    return data

def pull_out(stock, data):
    price = pd.DataFrame(yf.download(stock, period="max"))
    # data = data[data.index>= '2023-12-31']
    price.reset_index(inplace = True)
    merged_df = pd.merge(data, price, on='Date', how='outer').dropna()
    return (merged_df)

# %%
import spacy
# Load the spaCy English model
nlp = spacy.load('en_core_web_sm')

def tokenize_text(text):
    # Process the text with spaCy
    doc = nlp(text)
    # Extract tokens (lemmatized tokens in this example)
    tokens = [token.lemma_ for token in doc if not token.is_stop and not token.is_punct]
    return tokens

# %%
data = process(pull_out("AMZN", df))
data['text'] = data['headline'].apply(tokenize_text)
news = data.copy()
news.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                                             headline       Date        Open  \
# 0  Google becomes latest cloud provider to invest... 2024-04-26  177.800003
# 3  Microsoft Stock: Why This Magnificent 7 Baddie... 2024-04-29  182.750000
# 4  Stock Market Crash Alert: 3 Must-Buy Transport... 2024-04-30  181.089996
# 5  AMZN Stock Earnings: Amazon.com Beats EPS, Bea... 2024-05-01  181.639999
# 6  Wall Street Analysts Are Bullish on Top Consum... 2024-05-02  180.850006
#
#          High         Low       Close    Tomorrow  target  \
# 0  180.820007  176.130005  179.619995  180.960007       1
# 3  183.529999  179.389999  180.960007  175.000000       0
# 4  182.990005  174.800003  175.000000  179.000000       1
# 5  185.149994  176.559998  179.000000  184.720001       1
# 6  185.100006  179.910004  184.720001  186.210007       1
#
#                                                 text
# 0  [Google, late, cloud, provider, invest, Hoosie...
# 3  [Microsoft, Stock, Magnificent, 7, Baddie, lea...
# 4  [Stock, Market, Crash, Alert, 3, Buy, Transpor...
# 5  [AMZN, Stock, earning, Amazon.com, Beats, EPS,...
# 6  [Wall, Street, analyst, bullish, Consumer, Cyc...

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
import nltk
nltk.download('vader_lexicon')
from tqdm.notebook import tqdm

sia = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
res = {}
for i, row in tqdm(news.iterrows(), total=len(news)):
    text = row['headline']
    myid = row['Date']
    res[myid] = sia.polarity_scores(text)
# Out:
#   0%|          | 0/37 [00:00<?, ?it/s]

# %%
vaders = pd.DataFrame(res).T
vaders = vaders.reset_index().rename(columns={'index': 'Date'})
vaders = vaders.merge(news, how='left')

# %%
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from scipy.special import softmax

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from scipy.special import softmax
import torch

# Initialize tokenizer and model
tokenizer = AutoTokenizer.from_pretrained("cardiffnlp/twitter-roberta-base-sentiment")
model = AutoModelForSequenceClassification.from_pretrained("cardiffnlp/twitter-roberta-base-sentiment")


def polarity_scores_roberta(text):
    # Tokenize input text
    inputs = tokenizer(text, return_tensors='pt', padding=True, truncation=True, max_length=512)  # Adjust max_length as per your need

    # Forward pass through the model
    with torch.no_grad():
        outputs = model(**inputs)

    # Get logits and apply softmax
    logits = outputs.logits
    probabilities = softmax(logits, axis=1).flatten()  # Flatten to convert 2D array to 1D

    # Assuming logits order: [negative, positive]
    scores_dict = {
        'roberta_neg': probabilities[0],
        'roberta_pos': probabilities[1]
    }

    return scores_dict

# # Example usage
# example_text = "he is a good boy best"
# scores = polarity_scores_roberta(example_text)
# print(scores)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
res = {}
for i, row in tqdm(news.iterrows(), total=len(news)):
        text = row['headline']
        myid = row['Date']
        vader_result = sia.polarity_scores(text)
        vader_result_rename = {}
        for key, value in vader_result.items():
            vader_result_rename[f"vader_{key}"] = value
        roberta_result = polarity_scores_roberta(text)
        both = {**vader_result_rename, **roberta_result}
        res[myid] = vader_result_rename
# Out:
#   0%|          | 0/37 [00:00<?, ?it/s]

# %%
results_df = pd.DataFrame(res).T
results_df = results_df.reset_index().rename(columns={'index': 'Date'})
results_df = results_df.merge(news, how='left').dropna()

# %%
results_df.tail()
# Out:
#          Date  vader_neg  vader_neu  vader_pos  vader_compound  \
# 31 2024-06-11      0.039      0.804      0.157          0.9064
# 32 2024-06-12      0.017      0.740      0.243          0.9881
# 33 2024-06-13      0.012      0.783      0.205          0.9655
# 34 2024-06-14      0.000      0.781      0.219          0.9674
# 35 2024-06-17      0.015      0.821      0.164          0.9348
#
#                                              headline        Open        High  \
# 31  Amazon’s Expansion and Margin Improvement Outl...  187.059998  187.770004
# 32  Amazon Adds $1.4 Bln To Housing Equity Fund  A...  188.020004  188.350006
# 33  UBS Keeps Their Buy Rating on Amazon (AMZN) AM...  186.089996  187.669998
# 34  AI Artisans: 3 Stocks Crafting the Future of I...  183.080002  183.720001
# 35  3 Reasons to Buy Amazon Stock Now 3 Stocks to ...  182.520004  185.000000
#
#            Low       Close    Tomorrow  target  \
# 31  184.539993  187.229996  186.889999       0
# 32  185.429993  186.889999  183.830002       0
# 33  182.669998  183.830002  183.660004       0
# 34  182.229996  183.660004  184.059998       1
# 35  181.220001  184.059998  182.809998       0
#
#                                                  text
# 31  [Amazon, expansion, Margin, Improvement, Outlo...
# 32  [Amazon, add, $, 1.4, Bln, Housing, Equity, Fu...
# 33  [UBS, keep, Buy, rating, Amazon, AMZN, AMD, St...
# 34  [AI, Artisans, 3, stock, craft, Future, Intell...
# 35  [3, reason, buy, Amazon, Stock, 3, stock, buy,...

# %%
X = results_df.drop(columns=['Date','Close','headline','target', 'text','High','Low','Open','vader_pos'])
y=results_df['target']

# %%
import gensim.downloader

glove_vectors = gensim.downloader.load('word2vec-google-news-300')

# %%
def get_average_word2vec(tokens, model):
    valid_tokens = [token for token in tokens if token in model]
    if not valid_tokens:
        return np.zeros(model.vector_size)
    vectors = [model[token] for token in valid_tokens]
    return np.mean(vectors, axis=0)

# Apply the function to the 'tokens' column to get the embeddings
news['embedding'] = news['text'].apply(lambda x: get_average_word2vec(x, glove_vectors))

# %%
# Convert embeddings to separate columns
embedding_df = pd.DataFrame(news['embedding'].to_list(), index=news.index)
embedding_df.columns = [f'embedding_{i}' for i in range(embedding_df.shape[1])]

# Concatenate the embeddings with the original DataFrame
news = pd.concat([news, embedding_df], axis=1).drop(columns=['embedding'])

# %%
news.head()
# Out:
#                                             headline       Date        Open  \
# 0  Google becomes latest cloud provider to invest... 2024-04-26  177.800003
# 3  Microsoft Stock: Why This Magnificent 7 Baddie... 2024-04-29  182.750000
# 4  Stock Market Crash Alert: 3 Must-Buy Transport... 2024-04-30  181.089996
# 5  AMZN Stock Earnings: Amazon.com Beats EPS, Bea... 2024-05-01  181.639999
# 6  Wall Street Analysts Are Bullish on Top Consum... 2024-05-02  180.850006
#
#          High         Low       Close    Tomorrow  target  \
# 0  180.820007  176.130005  179.619995  180.960007       1
# 3  183.529999  179.389999  180.960007  175.000000       0
# 4  182.990005  174.800003  175.000000  179.000000       1
# 5  185.149994  176.559998  179.000000  184.720001       1
# 6  185.100006  179.910004  184.720001  186.210007       1
#
#                                                 text  embedding_0  ...  \
# 0  [Google, late, cloud, provider, invest, Hoosie...     0.039746  ...
# 3  [Microsoft, Stock, Magnificent, 7, Baddie, lea...     0.087587  ...
# 4  [Stock, Market, Crash, Alert, 3, Buy, Transpor...     0.023929  ...
# 5  [AMZN, Stock, earning, Amazon.com, Beats, EPS,...     0.020751  ...
# 6  [Wall, Street, analyst, bullish, Consumer, Cyc...     0.044872  ...
#
#    embedding_290  embedding_291  embedding_292  embedding_293  embedding_294  \
# 0      -0.007951       0.035014      -0.127064       0.047656       0.037577
# 3       0.022291       0.028126      -0.110173      -0.010450       0.034868
# 4       0.017611      -0.001279      -0.136135       0.034467       0.071464
# 5       0.030924       0.048549      -0.152956       0.022599       0.085451
# 6       0.041873       0.020826      -0.129871       0.026035       0.068217
#
#    embedding_295  embedding_296  embedding_297  embedding_298  embedding_299
# 0      -0.077344       0.047033      -0.005640       0.033557      -0.002012
# 3      -0.064529       0.027718      -0.014236       0.050798      -0.000159
# 4      -0.052433       0.025949       0.024659       0.066714      -0.014446
# 5      -0.085593       0.068454       0.028926       0.080187      -0.007711
# 6      -0.092564       0.005545       0.031193       0.026251      -0.011564
#
# [5 rows x 309 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X, y,test_size=0.2,random_state=2)

# %% [markdown]
# ### Import Metrics

# %%
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score
from sklearn.metrics import confusion_matrix # will plot the confusion matrix
import time
model_performance = pd.DataFrame(columns=['Accuracy','Recall','Precision','F1-Score','time to train','time to predict','total time'])

# %% [markdown]
# MultinomailNB

# %%
from sklearn.naive_bayes import MultinomialNB
start = time.time()
model =MultinomialNB().fit(X_train,y_train)
end_train = time.time()
y_predictions = model.predict(X_test) # These are the predictions from the test data.
end_predict = time.time()

# %%
accuracy = accuracy_score(y_test, y_predictions)
recall = recall_score(y_test, y_predictions, average='weighted')
precision = precision_score(y_test, y_predictions, average='weighted')
f1s = f1_score(y_test, y_predictions, average='weighted')

print("Accuracy: "+ "{:.2%}".format(accuracy))
print("Recall: "+ "{:.2%}".format(recall))
print("Precision: "+ "{:.2%}".format(precision))
print("F1-Score: "+ "{:.2%}".format(f1s))
print("time to train: "+ "{:.2f}".format(end_train-start)+" s")
print("time to predict: "+"{:.2f}".format(end_predict-end_train)+" s")
print("total: "+"{:.2f}".format(end_predict-start)+" s")
model_performance.loc['MultiNB'] = [accuracy, recall, precision, f1s,end_train-start,end_predict-end_train,end_predict-start]
# Out:
# Accuracy: 50.00%
# Recall: 50.00%
# Precision: 25.00%
# F1-Score: 33.33%
# time to train: 0.00 s
# time to predict: 0.00 s
# total: 0.00 s
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
start = time.time()
model = KNeighborsClassifier().fit(X_train,y_train)
end_train = time.time()
y_predictions = model.predict(X_test) # These are the predictions from the test data.
end_predict = time.time()

# %%
accuracy = accuracy_score(y_test, y_predictions)
recall = recall_score(y_test, y_predictions, average='weighted')
precision = precision_score(y_test, y_predictions, average='weighted')
f1s = f1_score(y_test, y_predictions, average='weighted')

print("Accuracy: "+ "{:.2%}".format(accuracy))
print("Recall: "+ "{:.2%}".format(recall))
print("Precision: "+ "{:.2%}".format(precision))
print("F1-Score: "+ "{:.2%}".format(f1s))
print("time to train: "+ "{:.2f}".format(end_train-start)+" s")
print("time to predict: "+"{:.2f}".format(end_predict-end_train)+" s")
print("total: "+"{:.2f}".format(end_predict-start)+" s")
model_performance.loc['KNN'] = [accuracy, recall, precision, f1s,end_train-start,end_predict-end_train,end_predict-start]
# Out:
# Accuracy: 37.50%
# Recall: 37.50%
# Precision: 36.67%
# F1-Score: 36.51%
# time to train: 0.00 s
# time to predict: 0.00 s
# total: 0.01 s

# %% [markdown]
# SVC

# %%
from sklearn.svm import SVC
start = time.time()
model = SVC(kernel='sigmoid', gamma=1.0).fit(X_train,y_train)
end_train = time.time()
y_predictions = model.predict(X_test) # These are the predictions from the test data.
end_predict = time.time()

# %%
accuracy = accuracy_score(y_test, y_predictions)
recall = recall_score(y_test, y_predictions, average='weighted')
precision = precision_score(y_test, y_predictions, average='weighted')
f1s = f1_score(y_test, y_predictions, average='weighted')

print("Accuracy: "+ "{:.2%}".format(accuracy))
print("Recall: "+ "{:.2%}".format(recall))
print("Precision: "+ "{:.2%}".format(precision))
print("F1-Score: "+ "{:.2%}".format(f1s))
print("time to train: "+ "{:.2f}".format(end_train-start)+" s")
print("time to predict: "+"{:.2f}".format(end_predict-end_train)+" s")
print("total: "+"{:.2f}".format(end_predict-start)+" s")
model_performance.loc['SVC'] = [accuracy, recall, precision, f1s,end_train-start,end_predict-end_train,end_predict-start]
# Out:
# Accuracy: 50.00%
# Recall: 50.00%
# Precision: 25.00%
# F1-Score: 33.33%
# time to train: 0.01 s
# time to predict: 0.01 s
# total: 0.01 s
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
start = time.time()
model = LogisticRegression().fit(X_train,y_train)
end_train = time.time()
y_predictions = model.predict(X_test) # These are the predictions from the test data.
end_predict = time.time()

# %%
accuracy = accuracy_score(y_test, y_predictions)
recall = recall_score(y_test, y_predictions, average='weighted')
precision = precision_score(y_test, y_predictions, average='weighted')
f1s = f1_score(y_test, y_predictions, average='weighted')

print("Accuracy: "+ "{:.2%}".format(accuracy))
print("Recall: "+ "{:.2%}".format(recall))
print("Precision: "+ "{:.2%}".format(precision))
print("F1-Score: "+ "{:.2%}".format(f1s))
print("time to train: "+ "{:.2f}".format(end_train-start)+" s")
print("time to predict: "+"{:.2f}".format(end_predict-end_train)+" s")
print("total: "+"{:.2f}".format(end_predict-start)+" s")
model_performance.loc['Logistic'] = [accuracy, recall, precision, f1s,end_train-start,end_predict-end_train,end_predict-start]
# Out:
# Accuracy: 50.00%
# Recall: 50.00%
# Precision: 50.00%
# F1-Score: 50.00%
# time to train: 0.02 s
# time to predict: 0.00 s
# total: 0.03 s

# %% [markdown]
# Decision Trees

# %%
from sklearn.tree import DecisionTreeClassifier
start = time.time()
model = DecisionTreeClassifier().fit(X_train,y_train)
end_train = time.time()
y_predictions = model.predict(X_test) # These are the predictions from the test data.
end_predict = time.time()

# %%
accuracy = accuracy_score(y_test, y_predictions)
recall = recall_score(y_test, y_predictions, average='weighted')
precision = precision_score(y_test, y_predictions, average='weighted')
f1s = f1_score(y_test, y_predictions, average='weighted')

print("Accuracy: "+ "{:.2%}".format(accuracy))
print("Recall: "+ "{:.2%}".format(recall))
print("Precision: "+ "{:.2%}".format(precision))
print("F1-Score: "+ "{:.2%}".format(f1s))
print("time to train: "+ "{:.2f}".format(end_train-start)+" s")
print("time to predict: "+"{:.2f}".format(end_predict-end_train)+" s")
print("total: "+"{:.2f}".format(end_predict-start)+" s")
model_performance.loc['Decision Tree'] = [accuracy, recall, precision, f1s,end_train-start,end_predict-end_train,end_predict-start]
# Out:
# Accuracy: 37.50%
# Recall: 37.50%
# Precision: 21.43%
# F1-Score: 27.27%
# time to train: 0.00 s
# time to predict: 0.00 s
# total: 0.00 s

# %% [markdown]
# Extra Trees

# %%
from sklearn.ensemble import ExtraTreesClassifier
start = time.time()
model_best = ExtraTreesClassifier(random_state=0,n_jobs=-1).fit(X_train,y_train)
end_train = time.time()
y_predictions = model_best.predict(X_test) # These are the predictions from the test data.
end_predict = time.time()

# %%
accuracy = accuracy_score(y_test, y_predictions)
recall = recall_score(y_test, y_predictions, average='weighted')
precision = precision_score(y_test, y_predictions, average='weighted')
f1s = f1_score(y_test, y_predictions, average='weighted')

print("Accuracy: "+ "{:.2%}".format(accuracy))
print("Recall: "+ "{:.2%}".format(recall))
print("Precision: "+ "{:.2%}".format(precision))
print("F1-Score: "+ "{:.2%}".format(f1s))
print("time to train: "+ "{:.2f}".format(end_train-start)+" s")
print("time to predict: "+"{:.2f}".format(end_predict-end_train)+" s")
print("total: "+"{:.2f}".format(end_predict-start)+" s")
model_performance.loc['Extra Trees'] = [accuracy, recall, precision, f1s,end_train-start,end_predict-end_train,end_predict-start]
# Out:
# Accuracy: 37.50%
# Recall: 37.50%
# Precision: 36.67%
# F1-Score: 36.51%
# time to train: 0.21 s
# time to predict: 0.04 s
# total: 0.25 s

# %% [markdown]
# RandomForest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
start = time.time()
model1 = RandomForestClassifier(n_estimators = 100,n_jobs=-1,random_state=0,bootstrap=True,).fit(X_train,y_train)
end_train = time.time()
y_predictions = model.predict(X_test) # These are the predictions from the test data.
end_predict = time.time()

# %%
accuracy = accuracy_score(y_test, y_predictions)
recall = recall_score(y_test, y_predictions, average='weighted')
precision = precision_score(y_test, y_predictions, average='weighted')
f1s = f1_score(y_test, y_predictions, average='weighted')

print("Accuracy: "+ "{:.2%}".format(accuracy))
print("Recall: "+ "{:.2%}".format(recall))
print("Precision: "+ "{:.2%}".format(precision))
print("F1-Score: "+ "{:.2%}".format(f1s))
print("time to train: "+ "{:.2f}".format(end_train-start)+" s")
print("time to predict: "+"{:.2f}".format(end_predict-end_train)+" s")
print("total: "+"{:.2f}".format(end_predict-start)+" s")
model_performance.loc['Random Forest'] = [accuracy, recall, precision, f1s,end_train-start,end_predict-end_train,end_predict-start]
# Out:
# Accuracy: 37.50%
# Recall: 37.50%
# Precision: 21.43%
# F1-Score: 27.27%
# time to train: 0.23 s
# time to predict: 0.00 s
# total: 0.23 s

# %% [markdown]
# Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier
start = time.time()
model = GradientBoostingClassifier().fit(X_train,y_train)
end_train = time.time()
y_predictions = model.predict(X_test) # These are the predictions from the test data.
end_predict = time.time()

# %%
accuracy = accuracy_score(y_test, y_predictions)
recall = recall_score(y_test, y_predictions, average='weighted')
precision = precision_score(y_test, y_predictions, average='weighted')
f1s = f1_score(y_test, y_predictions, average='weighted')

print("Accuracy: "+ "{:.2%}".format(accuracy))
print("Recall: "+ "{:.2%}".format(recall))
print("Precision: "+ "{:.2%}".format(precision))
print("F1-Score: "+ "{:.2%}".format(f1s))
print("time to train: "+ "{:.2f}".format(end_train-start)+" s")
print("time to predict: "+"{:.2f}".format(end_predict-end_train)+" s")
print("total: "+"{:.2f}".format(end_predict-start)+" s")
model_performance.loc['Gradient Boosting Classifier'] = [accuracy, recall, precision, f1s,end_train-start,end_predict-end_train,end_predict-start]
# Out:
# Accuracy: 37.50%
# Recall: 37.50%
# Precision: 21.43%
# F1-Score: 27.27%
# time to train: 0.07 s
# time to predict: 0.00 s
# total: 0.07 s

# %% [markdown]
# Neural Network MLP

# %%
from sklearn.neural_network import MLPClassifier
start = time.time()
model = MLPClassifier(hidden_layer_sizes = (20,20,),
                      activation='relu',
                      solver='adam',
                      batch_size=2000,
                      verbose=0).fit(X_train,y_train)
end_train = time.time()
y_predictions = model.predict(X_test) # These are the predictions from the test data.
end_predict = time.time()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:605: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(

# %%
accuracy = accuracy_score(y_test, y_predictions)
recall = recall_score(y_test, y_predictions, average='weighted')
precision = precision_score(y_test, y_predictions, average='weighted')
f1s = f1_score(y_test, y_predictions, average='weighted')

print("Accuracy: "+ "{:.2%}".format(accuracy))
print("Recall: "+ "{:.2%}".format(recall))
print("Precision: "+ "{:.2%}".format(precision))
print("F1-Score: "+ "{:.2%}".format(f1s))
print("time to train: "+ "{:.2f}".format(end_train-start)+" s")
print("time to predict: "+"{:.2f}".format(end_predict-end_train)+" s")
print("total: "+"{:.2f}".format(end_predict-start)+" s")
model_performance.loc['MLP'] = [accuracy, recall, precision, f1s,end_train-start,end_predict-end_train,end_predict-start]
# Out:
# Accuracy: 50.00%
# Recall: 50.00%
# Precision: 25.00%
# F1-Score: 33.33%
# time to train: 0.02 s
# time to predict: 0.00 s
# total: 0.02 s
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# Neural Networks MLP classifier

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, GRU
# !pip install keras_metrics
from keras import metrics
import keras_metrics as km
import keras
import numpy as np
from numpy import array
# Out:
# Requirement already satisfied: keras_metrics in /usr/local/lib/python3.10/dist-packages (1.1.0)
# Requirement already satisfied: Keras>=2.1.5 in /usr/local/lib/python3.10/dist-packages (from keras_metrics) (2.15.0)

# %%
from keras import backend as K

def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
#Build the feed forward neural network model
def build_model():
    model = Sequential()
    model.add(Dense(20, input_dim=4, activation='relu'))
    model.add(Dense(20, activation='relu'))
    model.add(Dense(20, activation='softmax')) #for multiclass classification
    #Compile the model
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam',
                  metrics=['accuracy',f1_m,precision_m, recall_m]
                 )
    return model

#institate the model
model = build_model()

#fit the model
start = time.time()
model.fit(X_train, y_train, epochs=50, batch_size=16,verbose=2)
end_train = time.time()
# Out:
# Epoch 1/50
# 2/2 - 6s - loss: 86.3087 - accuracy: 0.0000e+00 - f1_m: 0.6381 - precision_m: 0.4896 - recall_m: 1.0000 - 6s/epoch - 3s/step
# Epoch 2/50
# 2/2 - 0s - loss: 78.0885 - accuracy: 0.0000e+00 - f1_m: 0.6275 - precision_m: 0.4583 - recall_m: 1.0000 - 32ms/epoch - 16ms/step
# Epoch 3/50
# 2/2 - 0s - loss: 69.8972 - accuracy: 0.0000e+00 - f1_m: 0.6275 - precision_m: 0.4583 - recall_m: 1.0000 - 21ms/epoch - 11ms/step
# Epoch 4/50
# 2/2 - 0s - loss: 61.7959 - accuracy: 0.0000e+00 - f1_m: 0.6275 - precision_m: 0.4583 - recall_m: 1.0000 - 16ms/epoch - 8ms/step
# Epoch 5/50
# 2/2 - 0s - loss: 54.7288 - accuracy: 0.0000e+00 - f1_m: 0.6100 - precision_m: 0.4479 - recall_m: 1.0000 - 19ms/epoch - 9ms/step
# Epoch 6/50
# 2/2 - 0s - loss: 50.3252 - accuracy: 0.0000e+00 - f1_m: 0.6377 - precision_m: 0.4688 - recall_m: 1.0000 - 17ms/epoch - 9ms/step
# Epoch 7/50
# 2/2 - 0s - loss: 45.9480 - accuracy: 0.0000e+00 - f1_m: 0.6275 - precision_m: 0.4583 - recall_m: 1.0000 - 17ms/epoch - 9ms/step
# Epoch 8/50
# 2/2 - 0s - loss: 40.9423 - accuracy: 0.0000e+00 - f1_m: 0.6377 - precision_m: 0.4688 - recall_m: 1.0000 - 17ms/epoch - 8ms/step
# Epoch 9/50
# 2/2 - 0s - loss: 35.6674 - accuracy: 0.0000e+00 - f1_m: 0.6275 - precision_m: 0.4583 - recall_m: 1.0000 - 17ms/epoch - 9ms/step
# Epoch 10/50
# 2/2 - 0s - loss: 32.4959 - accuracy: 0.4643 - f1_m: 0.6275 - precision_m: 0.4583 - recall_m: 1.0000 - 17ms/epoch - 9ms/step
# Epoch 11/50
# 2/2 - 0s - loss: 31.9813 - accuracy: 0.4643 - f1_m: 0.6377 - precision_m: 0.4688 - recall_m: 1.0000 - 16ms/epoch - 8ms/step
# Epoch 12/50
# 2/2 - 0s - loss: 30.3176 - accuracy: 0.4643 - f1_m: 0.6377 - precision_m: 0.4688 - recall_m: 1.0000 - 17ms/epoch - 9ms/step
# Epoch 13/50
# 2/2 - 0s - loss: 27.6944 - accuracy: 0.4643 - f1_m: 0.6275 - precision_m: 0.4583 - recall_m: 1.0000 - 20ms/epoch - 10ms/step
# Epoch 14/50
# 2/2 - 0s - loss: 24.4442 - accuracy: 0.4643 - f1_m: 0.6100 - precision_m: 0.4479 - recall_m: 1.0000 - 17ms/epoch - 9ms/step
# Epoch 15/50
# 2/2 - 0s - loss: 21.3072 - accuracy: 0.4643 - f1_m: 0.6411 - precision_m: 0.4792 - recall_m: 1.0000 - 15ms/epoch - 8ms/step
# Epoch 16/50
# 2/2 - 0s - loss: 18.3211 - accuracy: 0.2857 - f1_m: 0.2941 - precision_m: 0.2083 - recall_m: 0.5000 - 16ms/epoch - 8ms/step
# Epoch 17/50
# 2/2 - 0s - loss: 16.6432 - accuracy: 0.0000e+00 - f1_m: 0.6377 - precision_m: 0.4688 - recall_m: 1.0000 - 17ms/epoch - 9ms/step
# Epoch 18/50
# 2/2 - 0s - loss: 14.4187 - accuracy: 0.0000e+00 - f1_m: 0.3333 - precision_m: 0.2500 - recall_m: 0.5000 - 16ms/epoch - 8ms/step
# Epoch 19/50
# 2/2 - 0s - loss: 12.1866 - accuracy: 0.0000e+00 - f1_m: 0.3333 - precision_m: 0.2500 - recall_m: 0.5000 - 18ms/epoch - 9ms/step
# Epoch 20/50
# 2/2 - 0s - loss: 9.6496 - accuracy: 0.0000e+00 - f1_m: 0.5186 - precision_m: 0.4062 - recall_m: 0.7500 - 18ms/epoch - 9ms/step
# Epoch 21/50
# 2/2 - 0s - loss: 7.1344 - accuracy: 0.4643 - f1_m: 0.2500 - precision_m: 0.1667 - recall_m: 0.5000 - 17ms/epoch - 8ms/step
# Epoch 22/50
# 2/2 - 0s - loss: 5.1748 - accuracy: 0.4643 - f1_m: 0.6100 - precision_m: 0.4479 - recall_m: 1.0000 - 17ms/epoch - 9ms/step
# Epoch 23/50
# 2/2 - 0s - loss: 3.1546 - accuracy: 0.4643 - f1_m: 0.6377 - precision_m: 0.4688 - recall_m: 1.0000 - 20ms/epoch - 10ms/step
# Epoch 24/50
# 2/2 - 0s - loss: 1.2318 - accuracy: 0.4643 - f1_m: 0.6377 - precision_m: 0.4688 - recall_m: 1.0000 - 17ms/epoch - 8ms/step
# Epoch 25/50
# 2/2 - 0s - loss: 1.7428 - accuracy: 0.5357 - f1_m: 0.6377 - precision_m: 0.4688 - recall_m: 1.0000 - 17ms/epoch - 9ms/step
# Epoch 26/50
# 2/2 - 0s - loss: 2.4936 - accuracy: 0.5357 - f1_m: 0.6275 - precision_m: 0.4583 - recall_m: 1.0000 - 18ms/epoch - 9ms/step
# Epoch 27/50
# 2/2 - 0s - loss: 2.3401 - accuracy: 0.5357 - f1_m: 0.6275 - precision_m: 0.4583 - recall_m: 1.0000 - 17ms/epoch - 8ms/step
# Epoch 28/50
# 2/2 - 0s - loss: 1.4119 - accuracy: 0.5357 - f1_m: 0.6377 - precision_m: 0.4688 - recall_m: 1.0000 - 16ms/epoch - 8ms/step
# Epoch 29/50
# 2/2 - 0s - loss: 0.8165 - accuracy: 0.4643 - f1_m: 0.6275 - precision_m: 0.4583 - recall_m: 1.0000 - 22ms/epoch - 11ms/step
# Epoch 30/50
# 2/2 - 0s - loss: 1.3783 - accuracy: 0.4643 - f1_m: 0.6377 - precision_m: 0.4688 - recall_m: 1.0000 - 29ms/epoch - 14ms/step
# Epoch 31/50
# 2/2 - 0s - loss: 1.4664 - accuracy: 0.4643 - f1_m: 0.6381 - precision_m: 0.4896 - recall_m: 1.0000 - 62ms/epoch - 31ms/step
# Epoch 32/50
# 2/2 - 0s - loss: 0.9485 - accuracy: 0.4643 - f1_m: 0.6381 - precision_m: 0.4896 - recall_m: 1.0000 - 21ms/epoch - 10ms/step
# Epoch 33/50
# 2/2 - 0s - loss: 0.8283 - accuracy: 0.5357 - f1_m: 0.6377 - precision_m: 0.4688 - recall_m: 1.0000 - 27ms/epoch - 13ms/step
# Epoch 34/50
# 2/2 - 0s - loss: 1.0059 - accuracy: 0.5357 - f1_m: 0.6377 - precision_m: 0.4688 - recall_m: 1.0000 - 18ms/epoch - 9ms/step
# Epoch 35/50
# 2/2 - 0s - loss: 0.7974 - accuracy: 0.5357 - f1_m: 0.6411 - precision_m: 0.4792 - recall_m: 1.0000 - 18ms/epoch - 9ms/step
# Epoch 36/50
# 2/2 - 0s - loss: 0.7437 - accuracy: 0.4643 - f1_m: 0.6275 - precision_m: 0.4583 - recall_m: 1.0000 - 23ms/epoch - 11ms/step
# Epoch 37/50
# 2/2 - 0s - loss: 0.8752 - accuracy: 0.4643 - f1_m: 0.6411 - precision_m: 0.4792 - recall_m: 1.0000 - 17ms/epoch - 8ms/step
# Epoch 38/50
# 2/2 - 0s - loss: 0.7877 - accuracy: 0.4643 - f1_m: 0.6377 - precision_m: 0.4688 - recall_m: 1.0000 - 37ms/epoch - 19ms/step
# Epoch 39/50
# 2/2 - 0s - loss: 0.6916 - accuracy: 0.5357 - f1_m: 0.6275 - precision_m: 0.4583 - recall_m: 1.0000 - 23ms/epoch - 11ms/step
# Epoch 40/50
# 2/2 - 0s - loss: 0.8125 - accuracy: 0.5357 - f1_m: 0.6381 - precision_m: 0.4896 - recall_m: 1.0000 - 23ms/epoch - 12ms/step
# Epoch 41/50
# 2/2 - 0s - loss: 0.7431 - accuracy: 0.5357 - f1_m: 0.6377 - precision_m: 0.4688 - recall_m: 1.0000 - 21ms/epoch - 10ms/step
# Epoch 42/50
# 2/2 - 0s - loss: 0.7744 - accuracy: 0.3214 - f1_m: 0.5846 - precision_m: 0.4375 - recall_m: 1.0000 - 18ms/epoch - 9ms/step
# Epoch 43/50
# 2/2 - 0s - loss: 0.7689 - accuracy: 0.4643 - f1_m: 0.6411 - precision_m: 0.4792 - recall_m: 1.0000 - 18ms/epoch - 9ms/step
# Epoch 44/50
# 2/2 - 0s - loss: 0.7081 - accuracy: 0.4643 - f1_m: 0.6377 - precision_m: 0.4688 - recall_m: 1.0000 - 19ms/epoch - 9ms/step
# Epoch 45/50
# 2/2 - 0s - loss: 0.7251 - accuracy: 0.5357 - f1_m: 0.6411 - precision_m: 0.4792 - recall_m: 1.0000 - 32ms/epoch - 16ms/step
# Epoch 46/50
# 2/2 - 0s - loss: 0.7281 - accuracy: 0.5357 - f1_m: 0.6100 - precision_m: 0.4479 - recall_m: 1.0000 - 37ms/epoch - 19ms/step
# Epoch 47/50
# 2/2 - 0s - loss: 0.6904 - accuracy: 0.5357 - f1_m: 0.6377 - precision_m: 0.4688 - recall_m: 1.0000 - 19ms/epoch - 10ms/step
# Epoch 48/50
# 2/2 - 0s - loss: 0.7023 - accuracy: 0.4643 - f1_m: 0.6275 - precision_m: 0.4583 - recall_m: 1.0000 - 36ms/epoch - 18ms/step
# Epoch 49/50
# 2/2 - 0s - loss: 0.7097 - accuracy: 0.4643 - f1_m: 0.5846 - precision_m: 0.4375 - recall_m: 1.0000 - 34ms/epoch - 17ms/step
# Epoch 50/50
# 2/2 - 0s - loss: 0.7185 - accuracy: 0.5357 - f1_m: 0.6411 - precision_m: 0.4792 - recall_m: 1.0000 - 51ms/epoch - 25ms/step

# %%
#Evaluate the neural network
loss, accuracy, f1s, precision, recall = model.evaluate(X_test, y_test)
end_predict = time.time()
model_performance.loc['MLP (Keras)'] = [accuracy, accuracy, accuracy, accuracy,end_train-start,end_predict-end_train,end_predict-start]
# Out:
# 1/1 [==============================] - 1s 987ms/step - loss: 0.7335 - accuracy: 0.5000 - f1_m: 0.6667 - precision_m: 0.5000 - recall_m: 1.0000

# %% [markdown]
# GRU(keras)

# %%
def build_model():
    model = Sequential()
    model.add(GRU(20, return_sequences=True,input_shape=(1,4)))
    model.add(GRU(20, return_sequences=True))
    model.add(Dense(10, activation='softmax')) #for multiclass classification
    #Compile the model
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam',
                  # metrics=['accuracy',f1_m,precision_m, recall_m]
                  metrics=['accuracy']
                 )
    return model

#The GRU input layer must be 3D.
#The meaning of the 3 input dimensions are: samples, time steps, and features.
#reshape input data
X_train_array = array(X_train) #array has been declared in the previous cell
print(len(X_train_array))
X_train_reshaped = X_train_array.reshape(X_train_array.shape[0],1,4)

#reshape output data
X_test_array=  array(X_test)
X_test_reshaped = X_test_array.reshape(X_test_array.shape[0],1,4)


#institate the model
model = build_model()

start = time.time()
#fit the model
model.fit(X_train_reshaped, y_train, epochs=200, batch_size=16,verbose=2)
end_train = time.time()
# Out:
# 28
# Epoch 1/200
# 2/2 - 8s - loss: 2.4488 - accuracy: 0.0000e+00 - 8s/epoch - 4s/step
# Epoch 2/200
# 2/2 - 0s - loss: 2.3871 - accuracy: 0.0000e+00 - 27ms/epoch - 14ms/step
# Epoch 3/200
# 2/2 - 0s - loss: 2.3208 - accuracy: 0.0000e+00 - 34ms/epoch - 17ms/step
# Epoch 4/200
# 2/2 - 0s - loss: 2.2484 - accuracy: 0.0000e+00 - 24ms/epoch - 12ms/step
# Epoch 5/200
# 2/2 - 0s - loss: 2.1670 - accuracy: 0.0000e+00 - 30ms/epoch - 15ms/step
# Epoch 6/200
# 2/2 - 0s - loss: 2.0875 - accuracy: 0.0000e+00 - 29ms/epoch - 15ms/step
# Epoch 7/200
# 2/2 - 0s - loss: 2.0174 - accuracy: 0.1786 - 23ms/epoch - 12ms/step
# Epoch 8/200
# 2/2 - 0s - loss: 1.9539 - accuracy: 0.5357 - 30ms/epoch - 15ms/step
# Epoch 9/200
# 2/2 - 0s - loss: 1.8931 - accuracy: 0.5357 - 29ms/epoch - 14ms/step
# Epoch 10/200
# 2/2 - 0s - loss: 1.8453 - accuracy: 0.5357 - 23ms/epoch - 11ms/step
# Epoch 11/200
# 2/2 - 0s - loss: 1.7953 - accuracy: 0.5357 - 20ms/epoch - 10ms/step
# Epoch 12/200
# 2/2 - 0s - loss: 1.7490 - accuracy: 0.5357 - 26ms/epoch - 13ms/step
# Epoch 13/200
# 2/2 - 0s - loss: 1.7042 - accuracy: 0.5357 - 20ms/epoch - 10ms/step
# Epoch 14/200
# 2/2 - 0s - loss: 1.6596 - accuracy: 0.5357 - 21ms/epoch - 10ms/step
# Epoch 15/200
# 2/2 - 0s - loss: 1.6150 - accuracy: 0.5357 - 25ms/epoch - 12ms/step
# Epoch 16/200
# 2/2 - 0s - loss: 1.5747 - accuracy: 0.5357 - 26ms/epoch - 13ms/step
# Epoch 17/200
# 2/2 - 0s - loss: 1.5338 - accuracy: 0.5357 - 22ms/epoch - 11ms/step
# Epoch 18/200
# 2/2 - 0s - loss: 1.4933 - accuracy: 0.5357 - 24ms/epoch - 12ms/step
# Epoch 19/200
# 2/2 - 0s - loss: 1.4550 - accuracy: 0.5357 - 19ms/epoch - 9ms/step
# Epoch 20/200
# 2/2 - 0s - loss: 1.4185 - accuracy: 0.5357 - 22ms/epoch - 11ms/step
# Epoch 21/200
# 2/2 - 0s - loss: 1.3841 - accuracy: 0.5357 - 18ms/epoch - 9ms/step
# Epoch 22/200
# 2/2 - 0s - loss: 1.3508 - accuracy: 0.5357 - 18ms/epoch - 9ms/step
# Epoch 23/200
# 2/2 - 0s - loss: 1.3190 - accuracy: 0.5357 - 26ms/epoch - 13ms/step
# Epoch 24/200
# 2/2 - 0s - loss: 1.2884 - accuracy: 0.5357 - 23ms/epoch - 11ms/step
# Epoch 25/200
# 2/2 - 0s - loss: 1.2595 - accuracy: 0.5357 - 20ms/epoch - 10ms/step
# Epoch 26/200
# 2/2 - 0s - loss: 1.2314 - accuracy: 0.5357 - 22ms/epoch - 11ms/step
# Epoch 27/200
# 2/2 - 0s - loss: 1.2050 - accuracy: 0.5357 - 22ms/epoch - 11ms/step
# Epoch 28/200
# 2/2 - 0s - loss: 1.1790 - accuracy: 0.5357 - 21ms/epoch - 11ms/step
# Epoch 29/200
# 2/2 - 0s - loss: 1.1544 - accuracy: 0.5357 - 43ms/epoch - 21ms/step
# Epoch 30/200
# 2/2 - 0s - loss: 1.1310 - accuracy: 0.5357 - 23ms/epoch - 11ms/step
# Epoch 31/200
# 2/2 - 0s - loss: 1.1087 - accuracy: 0.5357 - 27ms/epoch - 14ms/step
# Epoch 32/200
# 2/2 - 0s - loss: 0.7082 - accuracy: 0.5357 - 45ms/epoch - 22ms/step
# Epoch 138/200
# 2/2 - 0s - loss: 0.7080 - accuracy: 0.5357 - 40ms/epoch - 20ms/step
# Epoch 139/200
# 2/2 - 0s - loss: 0.7077 - accuracy: 0.5357 - 36ms/epoch - 18ms/step
# Epoch 140/200
# 2/2 - 0s - loss: 0.7075 - accuracy: 0.5357 - 60ms/epoch - 30ms/step
# Epoch 141/200
# 2/2 - 0s - loss: 0.7074 - accuracy: 0.5357 - 37ms/epoch - 19ms/step
# Epoch 142/200
# 2/2 - 0s - loss: 0.7071 - accuracy: 0.5357 - 36ms/epoch - 18ms/step
# Epoch 143/200
# 2/2 - 0s - loss: 0.7069 - accuracy: 0.5357 - 34ms/epoch - 17ms/step
# Epoch 144/200
# 2/2 - 0s - loss: 0.7075 - accuracy: 0.5357 - 36ms/epoch - 18ms/step
# Epoch 145/200
# 2/2 - 0s - loss: 0.7062 - accuracy: 0.5357 - 27ms/epoch - 13ms/step
# Epoch 146/200
# 2/2 - 0s - loss: 0.7060 - accuracy: 0.5357 - 43ms/epoch - 21ms/step
# Epoch 147/200
# 2/2 - 0s - loss: 0.7059 - accuracy: 0.5357 - 50ms/epoch - 25ms/step
# Epoch 148/200
# 2/2 - 0s - loss: 0.7058 - accuracy: 0.5357 - 34ms/epoch - 17ms/step
# Epoch 149/200
# 2/2 - 0s - loss: 0.7058 - accuracy: 0.5357 - 27ms/epoch - 14ms/step
# Epoch 150/200
# 2/2 - 0s - loss: 0.7058 - accuracy: 0.5357 - 27ms/epoch - 13ms/step
# Epoch 151/200
# 2/2 - 0s - loss: 0.7063 - accuracy: 0.5357 - 39ms/epoch - 19ms/step
# Epoch 152/200
# 2/2 - 0s - loss: 0.7060 - accuracy: 0.5357 - 33ms/epoch - 17ms/step
# Epoch 153/200
# 2/2 - 0s - loss: 0.7056 - accuracy: 0.5357 - 50ms/epoch - 25ms/step
# Epoch 154/200
# 2/2 - 0s - loss: 0.7054 - accuracy: 0.5357 - 44ms/epoch - 22ms/step
# Epoch 155/200
# 2/2 - 0s - loss: 0.7050 - accuracy: 0.5357 - 32ms/epoch - 16ms/step
# Epoch 156/200
# 2/2 - 0s - loss: 0.7054 - accuracy: 0.5357 - 39ms/epoch - 20ms/step
# Epoch 157/200
# 2/2 - 0s - loss: 0.7046 - accuracy: 0.5357 - 44ms/epoch - 22ms/step
# Epoch 158/200
# 2/2 - 0s - loss: 0.7041 - accuracy: 0.5357 - 46ms/epoch - 23ms/step
# Epoch 159/200
# 2/2 - 0s - loss: 0.7042 - accuracy: 0.5357 - 40ms/epoch - 20ms/step
# Epoch 160/200
# 2/2 - 0s - loss: 0.7041 - accuracy: 0.5357 - 29ms/epoch - 14ms/step
# Epoch 161/200
# 2/2 - 0s - loss: 0.7039 - accuracy: 0.5357 - 28ms/epoch - 14ms/step
# Epoch 162/200
# 2/2 - 0s - loss: 0.7038 - accuracy: 0.5357 - 29ms/epoch - 14ms/step
# Epoch 163/200
# 2/2 - 0s - loss: 0.7039 - accuracy: 0.5357 - 33ms/epoch - 16ms/step
# 2/2 - 0s - loss: 0.7013 - accuracy: 0.5357 - 24ms/epoch - 12ms/step
# Epoch 191/200
# 2/2 - 0s - loss: 0.7010 - accuracy: 0.5357 - 31ms/epoch - 15ms/step
# Epoch 192/200
# 2/2 - 0s - loss: 0.7005 - accuracy: 0.5357 - 28ms/epoch - 14ms/step
# Epoch 193/200
# 2/2 - 0s - loss: 0.7007 - accuracy: 0.5357 - 28ms/epoch - 14ms/step
# Epoch 194/200
# 2/2 - 0s - loss: 0.7004 - accuracy: 0.5357 - 41ms/epoch - 20ms/step
# Epoch 195/200
# 2/2 - 0s - loss: 0.7007 - accuracy: 0.5357 - 27ms/epoch - 13ms/step
# Epoch 196/200
# 2/2 - 0s - loss: 0.7006 - accuracy: 0.5357 - 23ms/epoch - 12ms/step
# Epoch 197/200
# 2/2 - 0s - loss: 0.7001 - accuracy: 0.5357 - 23ms/epoch - 11ms/step
# Epoch 198/200
# 2/2 - 0s - loss: 0.7001 - accuracy: 0.5357 - 26ms/epoch - 13ms/step
# Epoch 199/200
# 2/2 - 0s - loss: 0.6998 - accuracy: 0.5357 - 31ms/epoch - 15ms/step
# Epoch 200/200
# 2/2 - 0s - loss: 0.7002 - accuracy: 0.5357 - 35ms/epoch - 17ms/step

# %%
loss, accuracy = model.evaluate(X_test_reshaped, y_test)
# loss, accuracy, f1s, precision, recall = model.evaluate(X_test_reshaped, y_test)
end_predict = time.time()
model_performance.loc['GRU (Keras)'] = [accuracy, accuracy, accuracy, accuracy, end_train-start,end_predict-end_train,end_predict-start]
# Out:
# 1/1 [==============================] - 3s 3s/step - loss: 0.7056 - accuracy: 0.5000

# %% [markdown]
# LSTM(keras)

# %%
def build_model():
    model = Sequential()
    model.add(LSTM(20, return_sequences=True,input_shape=(1,4)))
    model.add(LSTM(20, return_sequences=True))
    model.add(Dense(10, activation='softmax')) #for multiclass classification
    #Compile the model
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam',
                  # metrics=['accuracy',f1_m,precision_m, recall_m]
                  metrics=['accuracy']
                 )
    return model

#The LSTM input layer must be 3D.
#The meaning of the 3 input dimensions are: samples, time steps, and features.
#reshape input data
X_train_array = array(X_train) #array has been declared in the previous cell
print(len(X_train_array))
X_train_reshaped = X_train_array.reshape(X_train_array.shape[0],1,4)

#reshape output data
X_test_array=  array(X_test)
X_test_reshaped = X_test_array.reshape(X_test_array.shape[0],1,4)


#institate the model
model = build_model()


#fit the model
start = time.time()
model.fit(X_train_reshaped, y_train, epochs=200, batch_size=16,verbose=2)
end_train = time.time()
# Out:
# 28
# Epoch 1/200
# 2/2 - 11s - loss: 2.2484 - accuracy: 0.0000e+00 - 11s/epoch - 6s/step
# Epoch 2/200
# 2/2 - 0s - loss: 2.2336 - accuracy: 0.0000e+00 - 27ms/epoch - 14ms/step
# Epoch 3/200
# 2/2 - 0s - loss: 2.2192 - accuracy: 0.0000e+00 - 25ms/epoch - 13ms/step
# Epoch 4/200
# 2/2 - 0s - loss: 2.2041 - accuracy: 0.0000e+00 - 44ms/epoch - 22ms/step
# Epoch 5/200
# 2/2 - 0s - loss: 2.1894 - accuracy: 0.0000e+00 - 28ms/epoch - 14ms/step
# Epoch 6/200
# 2/2 - 0s - loss: 2.1746 - accuracy: 0.2143 - 29ms/epoch - 14ms/step
# Epoch 7/200
# 2/2 - 0s - loss: 2.1597 - accuracy: 0.4643 - 45ms/epoch - 23ms/step
# Epoch 8/200
# 2/2 - 0s - loss: 2.1446 - accuracy: 0.4643 - 29ms/epoch - 15ms/step
# Epoch 9/200
# 2/2 - 0s - loss: 2.1294 - accuracy: 0.4643 - 34ms/epoch - 17ms/step
# Epoch 10/200
# 2/2 - 0s - loss: 2.1141 - accuracy: 0.4643 - 29ms/epoch - 14ms/step
# Epoch 11/200
# 2/2 - 0s - loss: 2.0985 - accuracy: 0.4643 - 34ms/epoch - 17ms/step
# Epoch 12/200
# 2/2 - 0s - loss: 2.0828 - accuracy: 0.4643 - 33ms/epoch - 16ms/step
# Epoch 13/200
# 2/2 - 0s - loss: 2.0669 - accuracy: 0.4643 - 31ms/epoch - 16ms/step
# Epoch 14/200
# 2/2 - 0s - loss: 2.0509 - accuracy: 0.3214 - 32ms/epoch - 16ms/step
# Epoch 15/200
# 2/2 - 0s - loss: 2.0344 - accuracy: 0.5357 - 32ms/epoch - 16ms/step
# Epoch 16/200
# 2/2 - 0s - loss: 2.0176 - accuracy: 0.5357 - 24ms/epoch - 12ms/step
# Epoch 17/200
# 2/2 - 0s - loss: 2.0006 - accuracy: 0.5357 - 22ms/epoch - 11ms/step
# Epoch 18/200
# 2/2 - 0s - loss: 1.9832 - accuracy: 0.5357 - 27ms/epoch - 13ms/step
# Epoch 19/200
# 2/2 - 0s - loss: 1.9654 - accuracy: 0.5357 - 26ms/epoch - 13ms/step
# Epoch 20/200
# 2/2 - 0s - loss: 1.9475 - accuracy: 0.5357 - 31ms/epoch - 15ms/step
# Epoch 21/200
# 2/2 - 0s - loss: 1.9288 - accuracy: 0.5357 - 42ms/epoch - 21ms/step
# Epoch 22/200
# 2/2 - 0s - loss: 1.9096 - accuracy: 0.5357 - 42ms/epoch - 21ms/step
# Epoch 23/200
# 2/2 - 0s - loss: 1.8898 - accuracy: 0.5357 - 67ms/epoch - 33ms/step
# Epoch 24/200
# 2/2 - 0s - loss: 1.8692 - accuracy: 0.5357 - 55ms/epoch - 28ms/step
# Epoch 25/200
# 2/2 - 0s - loss: 1.8474 - accuracy: 0.5357 - 58ms/epoch - 29ms/step
# Epoch 26/200
# 2/2 - 0s - loss: 1.8240 - accuracy: 0.5357 - 61ms/epoch - 31ms/step
# Epoch 27/200
# 2/2 - 0s - loss: 1.7987 - accuracy: 0.5357 - 42ms/epoch - 21ms/step
# Epoch 28/200
# 2/2 - 0s - loss: 1.7713 - accuracy: 0.5357 - 49ms/epoch - 24ms/step
# Epoch 29/200
# 2/2 - 0s - loss: 1.7424 - accuracy: 0.5357 - 30ms/epoch - 15ms/step
# Epoch 30/200
# 2/2 - 0s - loss: 1.7131 - accuracy: 0.5357 - 49ms/epoch - 24ms/step
# Epoch 31/200
# 2/2 - 0s - loss: 1.6837 - accuracy: 0.5357 - 41ms/epoch - 20ms/step
# Epoch 32/200
# 2/2 - 0s - loss: 1.6549 - accuracy: 0.5357 - 39ms/epoch - 19ms/step
# Epoch 33/200
# 2/2 - 0s - loss: 1.6256 - accuracy: 0.5357 - 29ms/epoch - 15ms/step
# Epoch 34/200
# 2/2 - 0s - loss: 1.5947 - accuracy: 0.5357 - 32ms/epoch - 16ms/step
# Epoch 35/200
# 2/2 - 0s - loss: 1.5624 - accuracy: 0.5357 - 20ms/epoch - 10ms/step
# Epoch 36/200
# 2/2 - 0s - loss: 1.5283 - accuracy: 0.5357 - 20ms/epoch - 10ms/step
# Epoch 37/200
# 2/2 - 0s - loss: 1.4950 - accuracy: 0.5357 - 21ms/epoch - 11ms/step
# Epoch 38/200
# 2/2 - 0s - loss: 1.4637 - accuracy: 0.5357 - 24ms/epoch - 12ms/step
# Epoch 39/200
# 2/2 - 0s - loss: 1.4334 - accuracy: 0.5357 - 20ms/epoch - 10ms/step
# Epoch 40/200
# 2/2 - 0s - loss: 1.4054 - accuracy: 0.5357 - 26ms/epoch - 13ms/step
# Epoch 41/200
# 2/2 - 0s - loss: 1.3783 - accuracy: 0.5357 - 17ms/epoch - 9ms/step
# Epoch 42/200
# 2/2 - 0s - loss: 1.3518 - accuracy: 0.5357 - 21ms/epoch - 10ms/step
# Epoch 43/200
# 2/2 - 0s - loss: 1.3258 - accuracy: 0.5357 - 27ms/epoch - 14ms/step
# Epoch 44/200
# 2/2 - 0s - loss: 1.3006 - accuracy: 0.5357 - 41ms/epoch - 20ms/step
# Epoch 45/200
# 2/2 - 0s - loss: 1.2756 - accuracy: 0.5357 - 28ms/epoch - 14ms/step
# Epoch 46/200
# 2/2 - 0s - loss: 1.2511 - accuracy: 0.5357 - 28ms/epoch - 14ms/step
# Epoch 47/200
# 2/2 - 0s - loss: 1.2274 - accuracy: 0.5357 - 26ms/epoch - 13ms/step
# Epoch 48/200
# 2/2 - 0s - loss: 1.2042 - accuracy: 0.5357 - 40ms/epoch - 20ms/step
# Epoch 49/200
# 2/2 - 0s - loss: 1.1817 - accuracy: 0.5357 - 38ms/epoch - 19ms/step
# Epoch 50/200
# 2/2 - 0s - loss: 1.1598 - accuracy: 0.5357 - 29ms/epoch - 15ms/step
# Epoch 51/200
# 2/2 - 0s - loss: 1.1388 - accuracy: 0.5357 - 31ms/epoch - 15ms/step
# Epoch 52/200
# 2/2 - 0s - loss: 1.1183 - accuracy: 0.5357 - 43ms/epoch - 22ms/step
# Epoch 53/200
# 2/2 - 0s - loss: 1.0988 - accuracy: 0.5357 - 30ms/epoch - 15ms/step
# Epoch 54/200
# 2/2 - 0s - loss: 1.0798 - accuracy: 0.5357 - 33ms/epoch - 16ms/step
# Epoch 55/200
# 2/2 - 0s - loss: 1.0619 - accuracy: 0.5357 - 34ms/epoch - 17ms/step
# Epoch 56/200
# 2/2 - 0s - loss: 1.0448 - accuracy: 0.5357 - 44ms/epoch - 22ms/step
# Epoch 57/200
# 2/2 - 0s - loss: 1.0283 - accuracy: 0.5357 - 38ms/epoch - 19ms/step
# Epoch 58/200
# 2/2 - 0s - loss: 1.0125 - accuracy: 0.5357 - 32ms/epoch - 16ms/step
# Epoch 59/200
# 2/2 - 0s - loss: 0.9976 - accuracy: 0.5357 - 21ms/epoch - 11ms/step
# Epoch 60/200
# 2/2 - 0s - loss: 0.9833 - accuracy: 0.5357 - 22ms/epoch - 11ms/step
# Epoch 61/200
# 2/2 - 0s - loss: 0.9698 - accuracy: 0.5357 - 26ms/epoch - 13ms/step
# Epoch 62/200
# 2/2 - 0s - loss: 0.9571 - accuracy: 0.5357 - 24ms/epoch - 12ms/step
# Epoch 63/200
# 2/2 - 0s - loss: 0.9449 - accuracy: 0.5357 - 27ms/epoch - 13ms/step
# Epoch 64/200
# 2/2 - 0s - loss: 0.9336 - accuracy: 0.5357 - 24ms/epoch - 12ms/step
# Epoch 65/200
# 2/2 - 0s - loss: 0.9225 - accuracy: 0.5357 - 52ms/epoch - 26ms/step
# Epoch 66/200
# 2/2 - 0s - loss: 0.9123 - accuracy: 0.5357 - 30ms/epoch - 15ms/step
# Epoch 67/200
# 2/2 - 0s - loss: 0.9026 - accuracy: 0.5357 - 28ms/epoch - 14ms/step
# Epoch 68/200
# 2/2 - 0s - loss: 0.8933 - accuracy: 0.5357 - 36ms/epoch - 18ms/step
# Epoch 69/200
# 2/2 - 0s - loss: 0.8846 - accuracy: 0.5357 - 27ms/epoch - 14ms/step
# Epoch 70/200
# 2/2 - 0s - loss: 0.8764 - accuracy: 0.5357 - 26ms/epoch - 13ms/step
# Epoch 71/200
# 2/2 - 0s - loss: 0.8687 - accuracy: 0.5357 - 34ms/epoch - 17ms/step
# Epoch 72/200
# 2/2 - 0s - loss: 0.8613 - accuracy: 0.5357 - 30ms/epoch - 15ms/step
# Epoch 73/200
# 2/2 - 0s - loss: 0.8544 - accuracy: 0.5357 - 26ms/epoch - 13ms/step
# Epoch 74/200
# 2/2 - 0s - loss: 0.8480 - accuracy: 0.5357 - 26ms/epoch - 13ms/step
# Epoch 75/200
# 2/2 - 0s - loss: 0.8417 - accuracy: 0.5357 - 30ms/epoch - 15ms/step
# Epoch 76/200
# 2/2 - 0s - loss: 0.8358 - accuracy: 0.5357 - 31ms/epoch - 16ms/step
# Epoch 77/200
# 2/2 - 0s - loss: 0.8306 - accuracy: 0.5357 - 23ms/epoch - 11ms/step
# Epoch 78/200
# 2/2 - 0s - loss: 0.8251 - accuracy: 0.5357 - 22ms/epoch - 11ms/step
# Epoch 79/200
# 2/2 - 0s - loss: 0.8202 - accuracy: 0.5357 - 24ms/epoch - 12ms/step
# Epoch 80/200
# 2/2 - 0s - loss: 0.8161 - accuracy: 0.5357 - 42ms/epoch - 21ms/step
# Epoch 81/200
# 2/2 - 0s - loss: 0.8111 - accuracy: 0.5357 - 23ms/epoch - 11ms/step
# Epoch 82/200
# 2/2 - 0s - loss: 0.8070 - accuracy: 0.5357 - 22ms/epoch - 11ms/step
# Epoch 83/200
# 2/2 - 0s - loss: 0.8031 - accuracy: 0.5357 - 22ms/epoch - 11ms/step
# Epoch 84/200
# 2/2 - 0s - loss: 0.7995 - accuracy: 0.5357 - 30ms/epoch - 15ms/step
# Epoch 85/200
# 2/2 - 0s - loss: 0.7958 - accuracy: 0.5357 - 29ms/epoch - 15ms/step
# Epoch 86/200
# 2/2 - 0s - loss: 0.7924 - accuracy: 0.5357 - 32ms/epoch - 16ms/step
# Epoch 87/200
# 2/2 - 0s - loss: 0.7893 - accuracy: 0.5357 - 26ms/epoch - 13ms/step
# Epoch 88/200
# 2/2 - 0s - loss: 0.7861 - accuracy: 0.5357 - 28ms/epoch - 14ms/step
# Epoch 89/200
# 2/2 - 0s - loss: 0.7832 - accuracy: 0.5357 - 22ms/epoch - 11ms/step
# Epoch 90/200
# 2/2 - 0s - loss: 0.7804 - accuracy: 0.5357 - 19ms/epoch - 9ms/step
# Epoch 91/200
# 2/2 - 0s - loss: 0.7780 - accuracy: 0.5357 - 24ms/epoch - 12ms/step
# Epoch 92/200
# 2/2 - 0s - loss: 0.7758 - accuracy: 0.5357 - 20ms/epoch - 10ms/step
# Epoch 93/200
# 2/2 - 0s - loss: 0.7730 - accuracy: 0.5357 - 31ms/epoch - 16ms/step
# Epoch 94/200
# 2/2 - 0s - loss: 0.7706 - accuracy: 0.5357 - 27ms/epoch - 14ms/step
# Epoch 95/200
# 2/2 - 0s - loss: 0.7685 - accuracy: 0.5357 - 24ms/epoch - 12ms/step
# Epoch 96/200
# 2/2 - 0s - loss: 0.7663 - accuracy: 0.5357 - 26ms/epoch - 13ms/step
# Epoch 97/200
# 2/2 - 0s - loss: 0.7643 - accuracy: 0.5357 - 38ms/epoch - 19ms/step
# Epoch 98/200
# 2/2 - 0s - loss: 0.7626 - accuracy: 0.5357 - 27ms/epoch - 13ms/step
# Epoch 99/200
# 2/2 - 0s - loss: 0.7605 - accuracy: 0.5357 - 30ms/epoch - 15ms/step
# Epoch 100/200
# 2/2 - 0s - loss: 0.7588 - accuracy: 0.5357 - 35ms/epoch - 18ms/step
# Epoch 101/200
# 2/2 - 0s - loss: 0.7573 - accuracy: 0.5357 - 28ms/epoch - 14ms/step
# Epoch 102/200
# 2/2 - 0s - loss: 0.7557 - accuracy: 0.5357 - 37ms/epoch - 19ms/step
# Epoch 103/200
# 2/2 - 0s - loss: 0.7541 - accuracy: 0.5357 - 41ms/epoch - 20ms/step
# Epoch 104/200
# 2/2 - 0s - loss: 0.7526 - accuracy: 0.5357 - 22ms/epoch - 11ms/step
# Epoch 105/200
# 2/2 - 0s - loss: 0.7512 - accuracy: 0.5357 - 23ms/epoch - 11ms/step
# Epoch 106/200
# 2/2 - 0s - loss: 0.7498 - accuracy: 0.5357 - 20ms/epoch - 10ms/step
# Epoch 107/200
# 2/2 - 0s - loss: 0.7484 - accuracy: 0.5357 - 24ms/epoch - 12ms/step
# Epoch 108/200
# 2/2 - 0s - loss: 0.7472 - accuracy: 0.5357 - 51ms/epoch - 26ms/step
# Epoch 109/200
# 2/2 - 0s - loss: 0.7459 - accuracy: 0.5357 - 27ms/epoch - 14ms/step
# Epoch 110/200
# 2/2 - 0s - loss: 0.7451 - accuracy: 0.5357 - 21ms/epoch - 11ms/step
# Epoch 111/200
# 2/2 - 0s - loss: 0.7438 - accuracy: 0.5357 - 38ms/epoch - 19ms/step
# Epoch 112/200
# 2/2 - 0s - loss: 0.7426 - accuracy: 0.5357 - 26ms/epoch - 13ms/step
# Epoch 113/200
# 2/2 - 0s - loss: 0.7413 - accuracy: 0.5357 - 29ms/epoch - 14ms/step
# Epoch 114/200
# 2/2 - 0s - loss: 0.7404 - accuracy: 0.5357 - 19ms/epoch - 10ms/step
# Epoch 115/200
# 2/2 - 0s - loss: 0.7393 - accuracy: 0.5357 - 20ms/epoch - 10ms/step
# Epoch 116/200
# 2/2 - 0s - loss: 0.7384 - accuracy: 0.5357 - 18ms/epoch - 9ms/step
# Epoch 117/200
# 2/2 - 0s - loss: 0.7375 - accuracy: 0.5357 - 23ms/epoch - 12ms/step
# Epoch 118/200
# 2/2 - 0s - loss: 0.7366 - accuracy: 0.5357 - 19ms/epoch - 10ms/step
# Epoch 119/200
# 2/2 - 0s - loss: 0.7357 - accuracy: 0.5357 - 21ms/epoch - 11ms/step
# Epoch 120/200
# 2/2 - 0s - loss: 0.7350 - accuracy: 0.5357 - 20ms/epoch - 10ms/step
# Epoch 121/200
# 2/2 - 0s - loss: 0.7345 - accuracy: 0.5357 - 25ms/epoch - 12ms/step
# Epoch 122/200
# 2/2 - 0s - loss: 0.7336 - accuracy: 0.5357 - 18ms/epoch - 9ms/step
# Epoch 123/200
# 2/2 - 0s - loss: 0.7324 - accuracy: 0.5357 - 22ms/epoch - 11ms/step
# Epoch 124/200
# 2/2 - 0s - loss: 0.7316 - accuracy: 0.5357 - 28ms/epoch - 14ms/step
# Epoch 125/200
# 2/2 - 0s - loss: 0.7312 - accuracy: 0.5357 - 25ms/epoch - 13ms/step
# Epoch 126/200
# 2/2 - 0s - loss: 0.7301 - accuracy: 0.5357 - 23ms/epoch - 11ms/step
# Epoch 127/200
# 2/2 - 0s - loss: 0.7294 - accuracy: 0.5357 - 22ms/epoch - 11ms/step
# Epoch 128/200
# 2/2 - 0s - loss: 0.7288 - accuracy: 0.5357 - 22ms/epoch - 11ms/step
# Epoch 129/200
# 2/2 - 0s - loss: 0.7282 - accuracy: 0.5357 - 31ms/epoch - 15ms/step
# Epoch 130/200
# 2/2 - 0s - loss: 0.7275 - accuracy: 0.5357 - 26ms/epoch - 13ms/step
# Epoch 131/200
# 2/2 - 0s - loss: 0.7270 - accuracy: 0.5357 - 24ms/epoch - 12ms/step
# Epoch 132/200
# 2/2 - 0s - loss: 0.7266 - accuracy: 0.5357 - 25ms/epoch - 12ms/step
# Epoch 133/200
# 2/2 - 0s - loss: 0.7258 - accuracy: 0.5357 - 23ms/epoch - 12ms/step
# Epoch 134/200
# 2/2 - 0s - loss: 0.7256 - accuracy: 0.5357 - 23ms/epoch - 12ms/step
# Epoch 135/200
# 2/2 - 0s - loss: 0.7247 - accuracy: 0.5357 - 26ms/epoch - 13ms/step
# Epoch 136/200
# 2/2 - 0s - loss: 0.7241 - accuracy: 0.5357 - 19ms/epoch - 10ms/step
# Epoch 137/200
# 2/2 - 0s - loss: 0.7236 - accuracy: 0.5357 - 23ms/epoch - 12ms/step
# Epoch 138/200
# 2/2 - 0s - loss: 0.7231 - accuracy: 0.5357 - 28ms/epoch - 14ms/step
# Epoch 139/200
# 2/2 - 0s - loss: 0.7228 - accuracy: 0.5357 - 33ms/epoch - 17ms/step
# Epoch 140/200
# 2/2 - 0s - loss: 0.7220 - accuracy: 0.5357 - 45ms/epoch - 22ms/step
# Epoch 141/200
# 2/2 - 0s - loss: 0.7217 - accuracy: 0.5357 - 23ms/epoch - 11ms/step
# Epoch 142/200
# 2/2 - 0s - loss: 0.7211 - accuracy: 0.5357 - 27ms/epoch - 14ms/step
# Epoch 143/200
# 2/2 - 0s - loss: 0.7207 - accuracy: 0.5357 - 26ms/epoch - 13ms/step
# Epoch 144/200
# 2/2 - 0s - loss: 0.7204 - accuracy: 0.5357 - 19ms/epoch - 10ms/step
# Epoch 145/200
# 2/2 - 0s - loss: 0.7200 - accuracy: 0.5357 - 22ms/epoch - 11ms/step
# Epoch 146/200
# 2/2 - 0s - loss: 0.7203 - accuracy: 0.5357 - 28ms/epoch - 14ms/step
# Epoch 147/200
# 2/2 - 0s - loss: 0.7197 - accuracy: 0.5357 - 20ms/epoch - 10ms/step
# Epoch 148/200
# 2/2 - 0s - loss: 0.7189 - accuracy: 0.5357 - 26ms/epoch - 13ms/step
# Epoch 149/200
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.5357 - 25ms/epoch - 12ms/step
# Epoch 150/200
# 2/2 - 0s - loss: 0.7181 - accuracy: 0.5357 - 37ms/epoch - 18ms/step
# Epoch 151/200
# 2/2 - 0s - loss: 0.7175 - accuracy: 0.5357 - 33ms/epoch - 17ms/step
# Epoch 152/200
# 2/2 - 0s - loss: 0.7171 - accuracy: 0.5357 - 26ms/epoch - 13ms/step
# Epoch 153/200
# 2/2 - 0s - loss: 0.7168 - accuracy: 0.5357 - 27ms/epoch - 14ms/step
# Epoch 154/200
# 2/2 - 0s - loss: 0.7164 - accuracy: 0.5357 - 25ms/epoch - 12ms/step
# Epoch 155/200
# 2/2 - 0s - loss: 0.7161 - accuracy: 0.5357 - 27ms/epoch - 14ms/step
# Epoch 156/200
# 2/2 - 0s - loss: 0.7162 - accuracy: 0.5357 - 24ms/epoch - 12ms/step
# Epoch 157/200
# 2/2 - 0s - loss: 0.7156 - accuracy: 0.5357 - 22ms/epoch - 11ms/step
# Epoch 158/200
# 2/2 - 0s - loss: 0.7154 - accuracy: 0.5357 - 30ms/epoch - 15ms/step
# Epoch 159/200
# 2/2 - 0s - loss: 0.7155 - accuracy: 0.5357 - 29ms/epoch - 15ms/step
# Epoch 160/200
# 2/2 - 0s - loss: 0.7148 - accuracy: 0.5357 - 33ms/epoch - 16ms/step
# Epoch 161/200
# 2/2 - 0s - loss: 0.7144 - accuracy: 0.5357 - 43ms/epoch - 22ms/step
# Epoch 162/200
# 2/2 - 0s - loss: 0.7143 - accuracy: 0.5357 - 30ms/epoch - 15ms/step
# Epoch 163/200
# 2/2 - 0s - loss: 0.7137 - accuracy: 0.5357 - 38ms/epoch - 19ms/step
# Epoch 164/200
# 2/2 - 0s - loss: 0.7136 - accuracy: 0.5357 - 30ms/epoch - 15ms/step
# Epoch 165/200
# 2/2 - 0s - loss: 0.7131 - accuracy: 0.5357 - 28ms/epoch - 14ms/step
# Epoch 166/200
# 2/2 - 0s - loss: 0.7130 - accuracy: 0.5357 - 27ms/epoch - 14ms/step
# Epoch 167/200
# 2/2 - 0s - loss: 0.7127 - accuracy: 0.5357 - 43ms/epoch - 22ms/step
# Epoch 168/200
# 2/2 - 0s - loss: 0.7124 - accuracy: 0.5357 - 33ms/epoch - 17ms/step
# Epoch 169/200
# 2/2 - 0s - loss: 0.7122 - accuracy: 0.5357 - 32ms/epoch - 16ms/step
# Epoch 170/200
# 2/2 - 0s - loss: 0.7119 - accuracy: 0.5357 - 19ms/epoch - 10ms/step
# Epoch 171/200
# 2/2 - 0s - loss: 0.7118 - accuracy: 0.5357 - 32ms/epoch - 16ms/step
# Epoch 172/200
# 2/2 - 0s - loss: 0.7115 - accuracy: 0.5357 - 22ms/epoch - 11ms/step
# Epoch 173/200
# 2/2 - 0s - loss: 0.7113 - accuracy: 0.5357 - 19ms/epoch - 10ms/step
# Epoch 174/200
# 2/2 - 0s - loss: 0.7110 - accuracy: 0.5357 - 20ms/epoch - 10ms/step
# Epoch 175/200
# 2/2 - 0s - loss: 0.7108 - accuracy: 0.5357 - 21ms/epoch - 10ms/step
# Epoch 176/200
# 2/2 - 0s - loss: 0.7105 - accuracy: 0.5357 - 18ms/epoch - 9ms/step
# Epoch 177/200
# 2/2 - 0s - loss: 0.7103 - accuracy: 0.5357 - 21ms/epoch - 10ms/step
# Epoch 178/200
# 2/2 - 0s - loss: 0.7101 - accuracy: 0.5357 - 25ms/epoch - 13ms/step
# Epoch 179/200
# 2/2 - 0s - loss: 0.7103 - accuracy: 0.5357 - 28ms/epoch - 14ms/step
# Epoch 180/200
# 2/2 - 0s - loss: 0.7097 - accuracy: 0.5357 - 28ms/epoch - 14ms/step
# Epoch 181/200
# 2/2 - 0s - loss: 0.7097 - accuracy: 0.5357 - 32ms/epoch - 16ms/step
# Epoch 182/200
# 2/2 - 0s - loss: 0.7094 - accuracy: 0.5357 - 33ms/epoch - 16ms/step
# Epoch 183/200
# 2/2 - 0s - loss: 0.7092 - accuracy: 0.5357 - 35ms/epoch - 18ms/step
# Epoch 184/200
# 2/2 - 0s - loss: 0.7091 - accuracy: 0.5357 - 53ms/epoch - 26ms/step
# Epoch 185/200
# 2/2 - 0s - loss: 0.7088 - accuracy: 0.5357 - 60ms/epoch - 30ms/step
# Epoch 186/200
# 2/2 - 0s - loss: 0.7085 - accuracy: 0.5357 - 32ms/epoch - 16ms/step
# Epoch 187/200
# 2/2 - 0s - loss: 0.7084 - accuracy: 0.5357 - 21ms/epoch - 11ms/step
# Epoch 188/200
# 2/2 - 0s - loss: 0.7081 - accuracy: 0.5357 - 17ms/epoch - 9ms/step
# Epoch 189/200
# 2/2 - 0s - loss: 0.7082 - accuracy: 0.5357 - 22ms/epoch - 11ms/step
# Epoch 190/200
# 2/2 - 0s - loss: 0.7078 - accuracy: 0.5357 - 26ms/epoch - 13ms/step
# Epoch 191/200
# 2/2 - 0s - loss: 0.7078 - accuracy: 0.5357 - 22ms/epoch - 11ms/step
# Epoch 192/200
# 2/2 - 0s - loss: 0.7077 - accuracy: 0.5357 - 20ms/epoch - 10ms/step
# Epoch 193/200
# 2/2 - 0s - loss: 0.7073 - accuracy: 0.5357 - 20ms/epoch - 10ms/step
# Epoch 194/200
# 2/2 - 0s - loss: 0.7071 - accuracy: 0.5357 - 28ms/epoch - 14ms/step
# Epoch 195/200
# 2/2 - 0s - loss: 0.7071 - accuracy: 0.5357 - 24ms/epoch - 12ms/step
# Epoch 196/200
# 2/2 - 0s - loss: 0.7079 - accuracy: 0.5357 - 35ms/epoch - 18ms/step
# Epoch 197/200
# 2/2 - 0s - loss: 0.7069 - accuracy: 0.5357 - 45ms/epoch - 22ms/step
# Epoch 198/200
# 2/2 - 0s - loss: 0.7065 - accuracy: 0.5357 - 25ms/epoch - 13ms/step
# Epoch 199/200
# 2/2 - 0s - loss: 0.7065 - accuracy: 0.5357 - 21ms/epoch - 11ms/step
# Epoch 200/200
# 2/2 - 0s - loss: 0.7064 - accuracy: 0.5357 - 27ms/epoch - 13ms/step

# %%
#Evaluate the neural network
loss, accuracy = model.evaluate(X_test_reshaped, y_test)
# loss, accuracy, f1s, precision, recall = model.evaluate(X_test_reshaped, y_test)
end_predict = time.time()
model_performance.loc['LSTM (Keras)'] = [accuracy, accuracy, accuracy, accuracy,end_train-start,end_predict-end_train,end_predict-start]
# Out:
# 1/1 [==============================] - 2s 2s/step - loss: 0.7114 - accuracy: 0.5000

# %%
model_performance.fillna(.90,inplace=True)
model_performance.style.background_gradient(cmap='coolwarm').format({'Accuracy': '{:.2%}',
                                                                     'Precision': '{:.2%}',
                                                                     'Recall': '{:.2%}',
                                                                     'F1-Score': '{:.2%}',
                                                                     'time to train':'{:.1f}',
                                                                     'time to predict':'{:.1f}',
                                                                     'total time':'{:.1f}',
                                                                     })
# Out:
# <style type="text/css">
# #T_7330d_row0_col0, #T_7330d_row0_col1, #T_7330d_row2_col0, #T_7330d_row2_col1, #T_7330d_row3_col0, #T_7330d_row3_col1, #T_7330d_row3_col2, #T_7330d_row3_col3, #T_7330d_row8_col0, #T_7330d_row8_col1, #T_7330d_row9_col0, #T_7330d_row9_col1, #T_7330d_row9_col2, #T_7330d_row9_col3, #T_7330d_row10_col0, #T_7330d_row10_col1, #T_7330d_row10_col2, #T_7330d_row10_col3, #T_7330d_row11_col0, #T_7330d_row11_col1, #T_7330d_row11_col2, #T_7330d_row11_col3, #T_7330d_row11_col4, #T_7330d_row11_col5, #T_7330d_row11_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_7330d_row0_col2, #T_7330d_row2_col2, #T_7330d_row8_col2 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_7330d_row0_col3, #T_7330d_row2_col3, #T_7330d_row8_col3 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_7330d_row0_col4, #T_7330d_row0_col5, #T_7330d_row0_col6, #T_7330d_row1_col0, #T_7330d_row1_col1, #T_7330d_row1_col4, #T_7330d_row1_col5, #T_7330d_row1_col6, #T_7330d_row2_col4, #T_7330d_row2_col5, #T_7330d_row2_col6, #T_7330d_row3_col4, #T_7330d_row3_col5, #T_7330d_row3_col6, #T_7330d_row4_col0, #T_7330d_row4_col1, #T_7330d_row4_col2, #T_7330d_row4_col3, #T_7330d_row4_col4, #T_7330d_row4_col5, #T_7330d_row4_col6, #T_7330d_row5_col0, #T_7330d_row5_col1, #T_7330d_row6_col0, #T_7330d_row6_col1, #T_7330d_row6_col2, #T_7330d_row6_col3, #T_7330d_row6_col5, #T_7330d_row7_col0, #T_7330d_row7_col1, #T_7330d_row7_col2, #T_7330d_row7_col3, #T_7330d_row7_col4, #T_7330d_row7_col5, #T_7330d_row7_col6, #T_7330d_row8_col4, #T_7330d_row8_col5, #T_7330d_row8_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_7330d_row1_col2, #T_7330d_row5_col2 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_7330d_row1_col3, #T_7330d_row5_col3 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_7330d_row5_col4, #T_7330d_row5_col6, #T_7330d_row6_col6 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_7330d_row5_col5, #T_7330d_row6_col4 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_7330d_row9_col4 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_7330d_row9_col5 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_7330d_row9_col6 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_7330d_row10_col4 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_7330d_row10_col5 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_7330d_row10_col6 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# </style>
# <table id="T_7330d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7330d_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_7330d_level0_col1" class="col_heading level0 col1" >Recall</th>
#       <th id="T_7330d_level0_col2" class="col_heading level0 col2" >Precision</th>
#       <th id="T_7330d_level0_col3" class="col_heading level0 col3" >F1-Score</th>
#       <th id="T_7330d_level0_col4" class="col_heading level0 col4" >time to train</th>
#       <th id="T_7330d_level0_col5" class="col_heading level0 col5" >time to predict</th>
#       <th id="T_7330d_level0_col6" class="col_heading level0 col6" >total time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7330d_level0_row0" class="row_heading level0 row0" >MultiNB</th>
#       <td id="T_7330d_row0_col0" class="data row0 col0" >50.00%</td>
#       <td id="T_7330d_row0_col1" class="data row0 col1" >50.00%</td>
#       <td id="T_7330d_row0_col2" class="data row0 col2" >25.00%</td>
#       <td id="T_7330d_row0_col3" class="data row0 col3" >33.33%</td>
#       <td id="T_7330d_row0_col4" class="data row0 col4" >0.0</td>
#       <td id="T_7330d_row0_col5" class="data row0 col5" >0.0</td>
#       <td id="T_7330d_row0_col6" class="data row0 col6" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_7330d_level0_row1" class="row_heading level0 row1" >KNN</th>
#       <td id="T_7330d_row1_col0" class="data row1 col0" >37.50%</td>
#       <td id="T_7330d_row1_col1" class="data row1 col1" >37.50%</td>
#       <td id="T_7330d_row1_col2" class="data row1 col2" >36.67%</td>
#       <td id="T_7330d_row1_col3" class="data row1 col3" >36.51%</td>
#       <td id="T_7330d_row1_col4" class="data row1 col4" >0.0</td>
#       <td id="T_7330d_row1_col5" class="data row1 col5" >0.0</td>
#       <td id="T_7330d_row1_col6" class="data row1 col6" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_7330d_level0_row2" class="row_heading level0 row2" >SVC</th>
#       <td id="T_7330d_row2_col0" class="data row2 col0" >50.00%</td>
#       <td id="T_7330d_row2_col1" class="data row2 col1" >50.00%</td>
#       <td id="T_7330d_row2_col2" class="data row2 col2" >25.00%</td>
#       <td id="T_7330d_row2_col3" class="data row2 col3" >33.33%</td>
#       <td id="T_7330d_row2_col4" class="data row2 col4" >0.0</td>
#       <td id="T_7330d_row2_col5" class="data row2 col5" >0.0</td>
#       <td id="T_7330d_row2_col6" class="data row2 col6" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_7330d_level0_row3" class="row_heading level0 row3" >Logistic</th>
#       <td id="T_7330d_row3_col0" class="data row3 col0" >50.00%</td>
#       <td id="T_7330d_row3_col1" class="data row3 col1" >50.00%</td>
#       <td id="T_7330d_row3_col2" class="data row3 col2" >50.00%</td>
#       <td id="T_7330d_row3_col3" class="data row3 col3" >50.00%</td>
#       <td id="T_7330d_row3_col4" class="data row3 col4" >0.0</td>
#       <td id="T_7330d_row3_col5" class="data row3 col5" >0.0</td>
#       <td id="T_7330d_row3_col6" class="data row3 col6" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_7330d_level0_row4" class="row_heading level0 row4" >Decision Tree</th>
#       <td id="T_7330d_row4_col0" class="data row4 col0" >37.50%</td>
#       <td id="T_7330d_row4_col1" class="data row4 col1" >37.50%</td>
#       <td id="T_7330d_row4_col2" class="data row4 col2" >21.43%</td>
#       <td id="T_7330d_row4_col3" class="data row4 col3" >27.27%</td>
#       <td id="T_7330d_row4_col4" class="data row4 col4" >0.0</td>
#       <td id="T_7330d_row4_col5" class="data row4 col5" >0.0</td>
#       <td id="T_7330d_row4_col6" class="data row4 col6" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_7330d_level0_row5" class="row_heading level0 row5" >Extra Trees</th>
#       <td id="T_7330d_row5_col0" class="data row5 col0" >37.50%</td>
#       <td id="T_7330d_row5_col1" class="data row5 col1" >37.50%</td>
#       <td id="T_7330d_row5_col2" class="data row5 col2" >36.67%</td>
#       <td id="T_7330d_row5_col3" class="data row5 col3" >36.51%</td>
#       <td id="T_7330d_row5_col4" class="data row5 col4" >0.2</td>
#       <td id="T_7330d_row5_col5" class="data row5 col5" >0.0</td>
#       <td id="T_7330d_row5_col6" class="data row5 col6" >0.2</td>
#     </tr>
#     <tr>
#       <th id="T_7330d_level0_row6" class="row_heading level0 row6" >Random Forest</th>
#       <td id="T_7330d_row6_col0" class="data row6 col0" >37.50%</td>
#       <td id="T_7330d_row6_col1" class="data row6 col1" >37.50%</td>
#       <td id="T_7330d_row6_col2" class="data row6 col2" >21.43%</td>
#       <td id="T_7330d_row6_col3" class="data row6 col3" >27.27%</td>
#       <td id="T_7330d_row6_col4" class="data row6 col4" >0.2</td>
#       <td id="T_7330d_row6_col5" class="data row6 col5" >0.0</td>
#       <td id="T_7330d_row6_col6" class="data row6 col6" >0.2</td>
#     </tr>
#     <tr>
#       <th id="T_7330d_level0_row7" class="row_heading level0 row7" >Gradient Boosting Classifier</th>
#       <td id="T_7330d_row7_col0" class="data row7 col0" >37.50%</td>
#       <td id="T_7330d_row7_col1" class="data row7 col1" >37.50%</td>
#       <td id="T_7330d_row7_col2" class="data row7 col2" >21.43%</td>
#       <td id="T_7330d_row7_col3" class="data row7 col3" >27.27%</td>
#       <td id="T_7330d_row7_col4" class="data row7 col4" >0.1</td>
#       <td id="T_7330d_row7_col5" class="data row7 col5" >0.0</td>
#       <td id="T_7330d_row7_col6" class="data row7 col6" >0.1</td>
#     </tr>
#     <tr>
#       <th id="T_7330d_level0_row8" class="row_heading level0 row8" >MLP</th>
#       <td id="T_7330d_row8_col0" class="data row8 col0" >50.00%</td>
#       <td id="T_7330d_row8_col1" class="data row8 col1" >50.00%</td>
#       <
