# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

# %%
# !pip install -q yfinance

# %%
import yfinance as yf

# %%
df = pd.read_csv("/content/drive/MyDrive/GOOGL.csv").drop(columns=['time','source'])
df
# Out:
#     ticker                                           headline        date
# 0    googl  Why Smart Investors Can’t Ignore the Allure of...  2024-04-22
# 1    googl  What's Going On With Nvidia and AMD Stocks On ...  2024-04-22
# 2    googl  Microsoft And Oracle Could Be TikTok's 'Likely...  2024-04-22
# 3    googl  ETF Winners Amid Last Week's Record Loss in "M...  2024-04-22
# 4    googl  RBC Capital Remains a Buy on Alphabet Class A ...  2024-04-22
# ..     ...                                                ...         ...
# 445  googl                Least shorted S&P 500 stocks in May  2024-06-18
# 446  googl  3 AI Stocks to Buy Following the Nvidia Stock ...  2024-06-18
# 447  googl  3 Tech Stocks to Buy That Are Growing Dividend...  2024-06-18
# 448  googl             3 Bargain Stocks to Buy Now: June 2024  2024-06-18
# 449  googl  YouTube Introduces New Experimental 'notes' Fe...  2024-06-18
#
# [450 rows x 3 columns]

# %%
df = df.groupby('date')['headline'].agg(' '.join).reset_index()
df['Date']= pd.to_datetime(df['date'])
df.drop(columns=['date'], inplace = True)

# %%
df
# Out:
#                                              headline       Date
# 0   Why Smart Investors Can’t Ignore the Allure of... 2024-04-22
# 1   7 Stocks With the Most Potential to Rocket on ... 2024-04-23
# 2   Google delays phaseout of third-party cookies ... 2024-04-24
# 3   Destiny Tech100: Why I Wouldn’t Touch DXYZ Sto... 2024-04-25
# 4   Strong Buy Rating for Alphabet Class A (GOOGL)... 2024-04-26
# 5   Nvidia Who? 3 AI Plays Destined to Outshine th... 2024-04-27
# 6   With rate cuts pushed out, Goldman looks at qu... 2024-04-28
# 7   Alphabet Stock Analysis: Buy, Sell, or Hold? W... 2024-04-29
# 8   JMP Securities Reaffirms Their Buy Rating on A... 2024-04-30
# 9   Alphabet Stock Analysis: Earnings Bolster the ... 2024-05-01
# 10  Bet on Amazon Stock’s AI-Driven Ad Juggernaut ... 2024-05-02
# 11  Stock Market Crash Alert: 7 Must-Buy Stocks Wh... 2024-05-03
# 12  Stock Market Crash Alert: 7 Must-Buy Nasdaq St... 2024-05-04
# 13  Secret Pick: Double Your Money With Forgotten ... 2024-05-06
# 14  The 3 Best Magnificent 7 Stocks to Buy in May ... 2024-05-07
# 15  The 3 Best Social Media Stocks to Buy in May 2... 2024-05-08
# 16  3 Stocks Positioning Themselves for the Future... 2024-05-09
# 17  The 7 Best Long-Term Stocks to Buy in May 2024... 2024-05-10
# 18  AMD Stock Alert: Why You Should Sell Advanced ... 2024-05-11
# 19  AAPL Analysis: Why Apple Stock Dipped in Q2 an... 2024-05-12
# 20  The 7 Most Undervalued Stocks With Strong Fund... 2024-05-13
# 21  As 'Roaring Kitty' Returns, Here Are 3 ETFs To... 2024-05-14
# 22  Alphabet Class A (GOOGL) Receives a Buy from J... 2024-05-15
# 23  Alphabet Class A (GOOGL) Receives a Buy from B... 2024-05-16
# 24  3 Cheap AI Stocks to Buy Now: May 2024  Analys... 2024-05-17
# 25  This Week in Layoffs: 3 Strong Stocks That Are... 2024-05-19
# 26  UBS Sticks to Their Hold Rating for Alphabet C... 2024-05-20
# 27  Netflix Stock Hits 52-Weeks High After NFL Dea... 2024-05-21
# 28  JMP Securities Remains a Buy on Alphabet Class... 2024-05-22
# 29  The Fast Track: 7 Stocks That Can Double Your ... 2024-05-23
# 30  Alphabet Stock Strategy: No Need to Bail on GO... 2024-05-24
# 31  Go Gaga for GOOG? 3 Things That Make Alphabet ... 2024-05-25
# 32  Wall Street Favorites: 3 Magnificent 7 Stocks ... 2024-05-27
# 33  3 Battered Stocks That Even Warren Buffett Cou... 2024-05-28
# 34  Bullish Buying Opportunity: 3 ETFs to Scoop Up... 2024-05-29
# 35  Best Buy Likely To Report Lower Q1 Earnings; H... 2024-05-30
# 36  If You Can Only Buy One REIT Stock in May, It ... 2024-05-31
# 37  3 Stocks to Buy ASAP Before the TikTok Ban Sen... 2024-06-01
# 38  The Tech Trifecta: 3 Stocks With Unbeatable Co... 2024-06-02
# 39  Apple Stock Outlook: The Calm Before the AI St... 2024-06-03
# 40  AI Alchemists: 3 Stocks Transforming Data into... 2024-06-04
# 41  The 3 Best ETFs to Buy in June 2024 Alphabet t... 2024-06-05
# 42  Hedge Fund Favorites: 7 Stocks to Buy When You... 2024-06-06
# 43  7 Top AI Stocks to Buy in June for Long-Term G... 2024-06-07
# 44  Microsoft Stock Analysis: AI Is the Secret Sau... 2024-06-08
# 45  How to Play Apple’s Big AI Reveal Tomorrow Mai... 2024-06-09
# 46  7 Blue-Chip Stocks to Add to Your June Buy Lis... 2024-06-10
# 47  Buy Rating Affirmed: Alphabet’s Market Positio... 2024-06-11
# 48  Alphabet Class A (GOOGL) Receives a Buy from E... 2024-06-12
# 49  Screaming Buys- 3 Tech Stocks That Are Just Be... 2024-06-13
# 50  3 Stocks to Catapult Your $100K Into a Cool Mi... 2024-06-14
# 51  Why Intel Stock Is Undervalued and Well-Positi... 2024-06-15
# 52  The 7 Best Autonomous Driving Stocks to Buy in... 2024-06-17
# 53  Forget Nvidia: Why Apple’s AI Bombshell Could ... 2024-06-18

# %%
def process(data):
    data["Tomorrow"] = data["Close"].shift(-1)
    data["target"] = (data["Tomorrow"] > data["Close"]).astype(int)
    # data['P/L'] = data["Close"]-data['Open']
    data.drop(columns=['Volume','Adj Close'], inplace = True)
    return data

def pull_out(stock, data):
    price = pd.DataFrame(yf.download(stock, period="max"))
    # data = data[data.index>= '2023-12-31']
    price.reset_index(inplace = True)
    merged_df = pd.merge(data, price, on='Date', how='outer').dropna()
    return (merged_df)

# %%
import spacy
# Load the spaCy English model
nlp = spacy.load('en_core_web_sm')

def tokenize_text(text):
    # Process the text with spaCy
    doc = nlp(text)
    # Extract tokens (lemmatized tokens in this example)
    tokens = [token.lemma_ for token in doc if not token.is_stop and not token.is_punct]
    return tokens

# %%
data = process(pull_out("GOOGL", df))
data['text'] = data['headline'].apply(tokenize_text)
news = data.copy()
news.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                                             headline       Date        Open  \
# 0  Why Smart Investors Can’t Ignore the Allure of... 2024-04-22  154.309998
# 1  7 Stocks With the Most Potential to Rocket on ... 2024-04-23  156.960007
# 2  Google delays phaseout of third-party cookies ... 2024-04-24  157.490005
# 3  Destiny Tech100: Why I Wouldn’t Touch DXYZ Sto... 2024-04-25  151.330002
# 4  Strong Buy Rating for Alphabet Class A (GOOGL)... 2024-04-26  174.369995
#
#          High         Low       Close    Tomorrow  target  \
# 0  157.639999  154.059998  156.279999  158.259995       1
# 1  158.970001  156.279999  158.259995  159.130005       1
# 2  159.570007  157.169998  159.130005  156.000000       0
# 3  156.490005  150.869995  156.000000  171.949997       1
# 4  174.710007  169.649994  171.949997  166.149994       0
#
#                                                 text
# 0  [Smart, investor, ignore, allure, Amazon, Flyw...
# 1         [7, stock, Potential, Rocket, Q1, earning]
# 2  [Google, delay, phaseout, party, cookie, Chrom...
# 3  [Destiny, Tech100, touch, dxyz, stock, 10, Foo...
# 4  [Strong, Buy, Rating, Alphabet, Class, GOOGL, ...

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
import nltk
nltk.download('vader_lexicon')
from tqdm.notebook import tqdm

sia = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %%
# Run the polarity score on the entire dataset
res = {}
for i, row in tqdm(news.iterrows(), total=len(news)):
    text = row['headline']
    myid = row['Date']
    res[myid] = sia.polarity_scores(text)

# %%
vaders = pd.DataFrame(res).T
vaders = vaders.reset_index().rename(columns={'index': 'Date'})
vaders = vaders.merge(news, how='left')

# %%
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from scipy.special import softmax

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from scipy.special import softmax
import torch

# Initialize tokenizer and model
tokenizer = AutoTokenizer.from_pretrained("cardiffnlp/twitter-roberta-base-sentiment")
model = AutoModelForSequenceClassification.from_pretrained("cardiffnlp/twitter-roberta-base-sentiment")


def polarity_scores_roberta(text):
    # Tokenize input text
    inputs = tokenizer(text, return_tensors='pt', padding=True, truncation=True, max_length=512)  # Adjust max_length as per your need

    # Forward pass through the model
    with torch.no_grad():
        outputs = model(**inputs)

    # Get logits and apply softmax
    logits = outputs.logits
    probabilities = softmax(logits, axis=1).flatten()  # Flatten to convert 2D array to 1D

    # Assuming logits order: [negative, positive]
    scores_dict = {
        'roberta_neg': probabilities[0],
        'roberta_pos': probabilities[1]
    }

    return scores_dict

# # Example usage
# example_text = "he is a good boy best"
# scores = polarity_scores_roberta(example_text)
# print(scores)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/747 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/499M [00:00<?, ?B/s]

# %%
res = {}
for i, row in tqdm(news.iterrows(), total=len(news)):
    # try:
        text = row['headline']
        myid = row['Date']
        vader_result = sia.polarity_scores(text)
        vader_result_rename = {}
        for key, value in vader_result.items():
            vader_result_rename[f"vader_{key}"] = value
        roberta_result = polarity_scores_roberta(text)
        both = {**vader_result_rename, **roberta_result}
        res[myid] = vader_result_rename
# Out:
#   0%|          | 0/41 [00:00<?, ?it/s]

# %%
results_df = pd.DataFrame(res).T
results_df = results_df.reset_index().rename(columns={'index': 'Date'})
results_df = results_df.merge(news, how='left').dropna()

# %%
results_df.tail()
# Out:
#          Date  vader_neg  vader_neu  vader_pos  vader_compound  \
# 35 2024-06-11      0.044      0.813      0.143          0.9697
# 36 2024-06-12      0.008      0.809      0.183          0.9834
# 37 2024-06-13      0.054      0.797      0.149          0.8885
# 38 2024-06-14      0.000      0.783      0.217          0.9709
# 39 2024-06-17      0.015      0.914      0.071          0.8126
#
#                                              headline        Open        High  \
# 35  Buy Rating Affirmed: Alphabet’s Market Positio...  176.220001  176.839996
# 36  Alphabet Class A (GOOGL) Receives a Buy from E...  178.250000  180.410004
# 37  Screaming Buys- 3 Tech Stocks That Are Just Be...  176.110001  176.740005
# 38  3 Stocks to Catapult Your $100K Into a Cool Mi...  174.220001  177.059998
# 39  The 7 Best Autonomous Driving Stocks to Buy in...  175.460007  178.360001
#
#            Low       Close    Tomorrow  target  \
# 35  173.770004  176.619995  177.789993       1
# 36  176.110001  177.789993  175.160004       0
# 37  174.880005  175.160004  176.789993       1
# 38  174.149994  176.789993  177.240005       1
# 39  174.809998  177.240005  175.089996       0
#
#                                                  text
# 35  [buy, Rating, Affirmed, Alphabet, Market, Posi...
# 36  [Alphabet, Class, GOOGL, receive, buy, Evercor...
# 37  [scream, Buys-, 3, Tech, stock, beg, buy, Goog...
# 38  [3, stock, catapult, $, 100, k, Cool, Million,...
# 39  [7, Best, Autonomous, Driving, stock, buy, Jun...

# %%
X = results_df.drop(columns=['Date','Close','headline','target', 'text','High','Low','Open','vader_pos'])
y=results_df['target']

# %%
import gensim.downloader

glove_vectors = gensim.downloader.load('word2vec-google-news-300')
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
def get_average_word2vec(tokens, model):
    valid_tokens = [token for token in tokens if token in model]
    if not valid_tokens:
        return np.zeros(model.vector_size)
    vectors = [model[token] for token in valid_tokens]
    return np.mean(vectors, axis=0)

# Apply the function to the 'tokens' column to get the embeddings
news['embedding'] = news['text'].apply(lambda x: get_average_word2vec(x, glove_vectors))

# %%
# Convert embeddings to separate columns
embedding_df = pd.DataFrame(news['embedding'].to_list(), index=news.index)
embedding_df.columns = [f'embedding_{i}' for i in range(embedding_df.shape[1])]

# Concatenate the embeddings with the original DataFrame
news = pd.concat([news, embedding_df], axis=1).drop(columns=['embedding'])

# %%
news.head()
# Out:
#                                             headline       Date        Open  \
# 0  Why Smart Investors Can’t Ignore the Allure of... 2024-04-22  154.309998
# 1  7 Stocks With the Most Potential to Rocket on ... 2024-04-23  156.960007
# 2  Google delays phaseout of third-party cookies ... 2024-04-24  157.490005
# 3  Destiny Tech100: Why I Wouldn’t Touch DXYZ Sto... 2024-04-25  151.330002
# 4  Strong Buy Rating for Alphabet Class A (GOOGL)... 2024-04-26  174.369995
#
#          High         Low       Close    Tomorrow  target  \
# 0  157.639999  154.059998  156.279999  158.259995       1
# 1  158.970001  156.279999  158.259995  159.130005       1
# 2  159.570007  157.169998  159.130005  156.000000       0
# 3  156.490005  150.869995  156.000000  171.949997       1
# 4  174.710007  169.649994  171.949997  166.149994       0
#
#                                                 text  embedding_0  ...  \
# 0  [Smart, investor, ignore, allure, Amazon, Flyw...     0.071254  ...
# 1         [7, stock, Potential, Rocket, Q1, earning]     0.018799  ...
# 2  [Google, delay, phaseout, party, cookie, Chrom...     0.020733  ...
# 3  [Destiny, Tech100, touch, dxyz, stock, 10, Foo...     0.051662  ...
# 4  [Strong, Buy, Rating, Alphabet, Class, GOOGL, ...     0.038616  ...
#
#    embedding_290  embedding_291  embedding_292  embedding_293  embedding_294  \
# 0       0.017695       0.017291      -0.109096       0.008174       0.098929
# 1       0.014893       0.074280      -0.303630      -0.041748       0.053497
# 2      -0.014528       0.005207      -0.115126      -0.029414       0.017310
# 3      -0.009302       0.034577      -0.147928      -0.004760       0.067205
# 4       0.006563       0.027367      -0.150067      -0.014375       0.076558
#
#    embedding_295  embedding_296  embedding_297  embedding_298  embedding_299
# 0      -0.064732      -0.007370       0.000527       0.045966      -0.012761
# 1      -0.067424       0.027547       0.012329      -0.008830      -0.088867
# 2      -0.035289      -0.017071       0.006647       0.012790       0.021226
# 3      -0.049271       0.009123      -0.005506       0.043809      -0.059121
# 4      -0.061882       0.005319       0.032902       0.014871       0.026588
#
# [5 rows x 309 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(ngram_range = (1,4),max_features= 10000)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X, y,test_size=0.2,random_state=2)

# %% [markdown]
# ### Import Metrics

# %%
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score
from sklearn.metrics import confusion_matrix # will plot the confusion matrix
import time
model_performance = pd.DataFrame(columns=['Accuracy','Recall','Precision','F1-Score','time to train','time to predict','total time'])

# %% [markdown]
# MultinomailNB

# %%
from sklearn.naive_bayes import MultinomialNB
start = time.time()
model =MultinomialNB().fit(X_train,y_train)
end_train = time.time()
y_predictions = model.predict(X_test) # These are the predictions from the test data.
end_predict = time.time()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-fe7938c21869> in <cell line: 3>()
#       1 from sklearn.naive_bayes import MultinomialNB
#       2 start = time.time()
# ----> 3 model =MultinomialNB().fit(X_train,y_train)
#       4 end_train = time.time()
#       5 y_predictions = model.predict(X_test) # These are the predictions from the test data.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/naive_bayes.py in fit(self, X, y, sample_weight)
#     774         n_classes = Y.shape[1]
#     775         self._init_counters(n_classes, n_features)
# --> 776         self._count(X, Y)
#     777         alpha = self._check_alpha()
#     778         self._update_feature_log_prob(alpha)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/naive_bayes.py in _count(self, X, Y)
#     896     def _count(self, X, Y):
#     897         """Count and smooth feature occurrences."""
# --> 898         check_non_negative(X, "MultinomialNB (input X)")
#     899         self.feature_count_ += safe_sparse_dot(Y.T, X)
#     900         self.class_count_ += Y.sum(axis=0)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_non_negative(X, whom)
#    1416
#    1417     if X_min < 0:
# -> 1418         raise ValueError("Negative values in data passed to %s" % whom)
#    1419
#    1420
#
# ValueError: Negative values in data passed to MultinomialNB (input X)

# %%
accuracy = accuracy_score(y_test, y_predictions)
recall = recall_score(y_test, y_predictions, average='weighted')
precision = precision_score(y_test, y_predictions, average='weighted')
f1s = f1_score(y_test, y_predictions, average='weighted')

print("Accuracy: "+ "{:.2%}".format(accuracy))
print("Recall: "+ "{:.2%}".format(recall))
print("Precision: "+ "{:.2%}".format(precision))
print("F1-Score: "+ "{:.2%}".format(f1s))
print("time to train: "+ "{:.2f}".format(end_train-start)+" s")
print("time to predict: "+"{:.2f}".format(end_predict-end_train)+" s")
print("total: "+"{:.2f}".format(end_predict-start)+" s")
model_performance.loc['MultiNB'] = [accuracy, recall, precision, f1s,end_train-start,end_predict-end_train,end_predict-start]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-f17702a9aa7e> in <cell line: 1>()
# ----> 1 accuracy = accuracy_score(y_test, y_predictions)
#       2 recall = recall_score(y_test, y_predictions, average='weighted')
#       3 precision = precision_score(y_test, y_predictions, average='weighted')
#       4 f1s = f1_score(y_test, y_predictions, average='weighted')
#       5
#
# NameError: name 'y_predictions' is not defined

# %% [markdown]
# KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
start = time.time()
model = KNeighborsClassifier().fit(X_train,y_train)
end_train = time.time()
y_predictions = model.predict(X_test) # These are the predictions from the test data.
end_predict = time.time()

# %%
accuracy = accuracy_score(y_test, y_predictions)
recall = recall_score(y_test, y_predictions, average='weighted')
precision = precision_score(y_test, y_predictions, average='weighted')
f1s = f1_score(y_test, y_predictions, average='weighted')

print("Accuracy: "+ "{:.2%}".format(accuracy))
print("Recall: "+ "{:.2%}".format(recall))
print("Precision: "+ "{:.2%}".format(precision))
print("F1-Score: "+ "{:.2%}".format(f1s))
print("time to train: "+ "{:.2f}".format(end_train-start)+" s")
print("time to predict: "+"{:.2f}".format(end_predict-end_train)+" s")
print("total: "+"{:.2f}".format(end_predict-start)+" s")
model_performance.loc['KNN'] = [accuracy, recall, precision, f1s,end_train-start,end_predict-end_train,end_predict-start]
# Out:
# Accuracy: 75.00%
# Recall: 75.00%
# Precision: 82.14%
# F1-Score: 70.83%
# time to train: 0.00 s
# time to predict: 0.00 s
# total: 0.01 s

# %% [markdown]
# SVC

# %%
from sklearn.svm import SVC
start = time.time()
model = SVC(kernel='sigmoid', gamma=1.0).fit(X_train,y_train)
end_train = time.time()
y_predictions = model.predict(X_test) # These are the predictions from the test data.
end_predict = time.time()

# %%
accuracy = accuracy_score(y_test, y_predictions)
recall = recall_score(y_test, y_predictions, average='weighted')
precision = precision_score(y_test, y_predictions, average='weighted')
f1s = f1_score(y_test, y_predictions, average='weighted')

print("Accuracy: "+ "{:.2%}".format(accuracy))
print("Recall: "+ "{:.2%}".format(recall))
print("Precision: "+ "{:.2%}".format(precision))
print("F1-Score: "+ "{:.2%}".format(f1s))
print("time to train: "+ "{:.2f}".format(end_train-start)+" s")
print("time to predict: "+"{:.2f}".format(end_predict-end_train)+" s")
print("total: "+"{:.2f}".format(end_predict-start)+" s")
model_performance.loc['SVC'] = [accuracy, recall, precision, f1s,end_train-start,end_predict-end_train,end_predict-start]
# Out:
# Accuracy: 62.50%
# Recall: 62.50%
# Precision: 39.06%
# F1-Score: 48.08%
# time to train: 0.01 s
# time to predict: 0.00 s
# total: 0.01 s
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
start = time.time()
model = LogisticRegression().fit(X_train,y_train)
end_train = time.time()
y_predictions = model.predict(X_test) # These are the predictions from the test data.
end_predict = time.time()

# %%
accuracy = accuracy_score(y_test, y_predictions)
recall = recall_score(y_test, y_predictions, average='weighted')
precision = precision_score(y_test, y_predictions, average='weighted')
f1s = f1_score(y_test, y_predictions, average='weighted')

print("Accuracy: "+ "{:.2%}".format(accuracy))
print("Recall: "+ "{:.2%}".format(recall))
print("Precision: "+ "{:.2%}".format(precision))
print("F1-Score: "+ "{:.2%}".format(f1s))
print("time to train: "+ "{:.2f}".format(end_train-start)+" s")
print("time to predict: "+"{:.2f}".format(end_predict-end_train)+" s")
print("total: "+"{:.2f}".format(end_predict-start)+" s")
model_performance.loc['Logistic'] = [accuracy, recall, precision, f1s,end_train-start,end_predict-end_train,end_predict-start]
# Out:
# Accuracy: 62.50%
# Recall: 62.50%
# Precision: 39.06%
# F1-Score: 48.08%
# time to train: 0.03 s
# time to predict: 0.00 s
# total: 0.03 s
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# Decision Trees

# %%
from sklearn.tree import DecisionTreeClassifier
start = time.time()
model = DecisionTreeClassifier().fit(X_train,y_train)
end_train = time.time()
y_predictions = model.predict(X_test) # These are the predictions from the test data.
end_predict = time.time()

# %%
accuracy = accuracy_score(y_test, y_predictions)
recall = recall_score(y_test, y_predictions, average='weighted')
precision = precision_score(y_test, y_predictions, average='weighted')
f1s = f1_score(y_test, y_predictions, average='weighted')

print("Accuracy: "+ "{:.2%}".format(accuracy))
print("Recall: "+ "{:.2%}".format(recall))
print("Precision: "+ "{:.2%}".format(precision))
print("F1-Score: "+ "{:.2%}".format(f1s))
print("time to train: "+ "{:.2f}".format(end_train-start)+" s")
print("time to predict: "+"{:.2f}".format(end_predict-end_train)+" s")
print("total: "+"{:.2f}".format(end_predict-start)+" s")
model_performance.loc['Decision Tree'] = [accuracy, recall, precision, f1s,end_train-start,end_predict-end_train,end_predict-start]
# Out:
# Accuracy: 50.00%
# Recall: 50.00%
# Precision: 50.00%
# F1-Score: 50.00%
# time to train: 0.00 s
# time to predict: 0.00 s
# total: 0.01 s

# %% [markdown]
# Extra Trees

# %%
from sklearn.ensemble import ExtraTreesClassifier
start = time.time()
model_best = ExtraTreesClassifier(random_state=0,n_jobs=-1).fit(X_train,y_train)
end_train = time.time()
y_predictions = model_best.predict(X_test) # These are the predictions from the test data.
end_predict = time.time()

# %%
accuracy = accuracy_score(y_test, y_predictions)
recall = recall_score(y_test, y_predictions, average='weighted')
precision = precision_score(y_test, y_predictions, average='weighted')
f1s = f1_score(y_test, y_predictions, average='weighted')

print("Accuracy: "+ "{:.2%}".format(accuracy))
print("Recall: "+ "{:.2%}".format(recall))
print("Precision: "+ "{:.2%}".format(precision))
print("F1-Score: "+ "{:.2%}".format(f1s))
print("time to train: "+ "{:.2f}".format(end_train-start)+" s")
print("time to predict: "+"{:.2f}".format(end_predict-end_train)+" s")
print("total: "+"{:.2f}".format(end_predict-start)+" s")
model_performance.loc['Extra Trees'] = [accuracy, recall, precision, f1s,end_train-start,end_predict-end_train,end_predict-start]
# Out:
# Accuracy: 75.00%
# Recall: 75.00%
# Precision: 82.14%
# F1-Score: 70.83%
# time to train: 0.18 s
# time to predict: 0.04 s
# total: 0.22 s

# %% [markdown]
# RandomForest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
start = time.time()
model1 = RandomForestClassifier(n_estimators = 100,n_jobs=-1,random_state=0,bootstrap=True,).fit(X_train,y_train)
end_train = time.time()
y_predictions = model.predict(X_test) # These are the predictions from the test data.
end_predict = time.time()

# %%
accuracy = accuracy_score(y_test, y_predictions)
recall = recall_score(y_test, y_predictions, average='weighted')
precision = precision_score(y_test, y_predictions, average='weighted')
f1s = f1_score(y_test, y_predictions, average='weighted')

print("Accuracy: "+ "{:.2%}".format(accuracy))
print("Recall: "+ "{:.2%}".format(recall))
print("Precision: "+ "{:.2%}".format(precision))
print("F1-Score: "+ "{:.2%}".format(f1s))
print("time to train: "+ "{:.2f}".format(end_train-start)+" s")
print("time to predict: "+"{:.2f}".format(end_predict-end_train)+" s")
print("total: "+"{:.2f}".format(end_predict-start)+" s")
model_performance.loc['Random Forest'] = [accuracy, recall, precision, f1s,end_train-start,end_predict-end_train,end_predict-start]
# Out:
# Accuracy: 50.00%
# Recall: 50.00%
# Precision: 50.00%
# F1-Score: 50.00%
# time to train: 0.25 s
# time to predict: 0.00 s
# total: 0.25 s

# %% [markdown]
# Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier
start = time.time()
model = GradientBoostingClassifier().fit(X_train,y_train)
end_train = time.time()
y_predictions = model.predict(X_test) # These are the predictions from the test data.
end_predict = time.time()

# %%
accuracy = accuracy_score(y_test, y_predictions)
recall = recall_score(y_test, y_predictions, average='weighted')
precision = precision_score(y_test, y_predictions, average='weighted')
f1s = f1_score(y_test, y_predictions, average='weighted')

print("Accuracy: "+ "{:.2%}".format(accuracy))
print("Recall: "+ "{:.2%}".format(recall))
print("Precision: "+ "{:.2%}".format(precision))
print("F1-Score: "+ "{:.2%}".format(f1s))
print("time to train: "+ "{:.2f}".format(end_train-start)+" s")
print("time to predict: "+"{:.2f}".format(end_predict-end_train)+" s")
print("total: "+"{:.2f}".format(end_predict-start)+" s")
model_performance.loc['Gradient Boosting Classifier'] = [accuracy, recall, precision, f1s,end_train-start,end_predict-end_train,end_predict-start]
# Out:
# Accuracy: 62.50%
# Recall: 62.50%
# Precision: 39.06%
# F1-Score: 48.08%
# time to train: 0.08 s
# time to predict: 0.00 s
# total: 0.09 s
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# Neural Network MLP

# %%
from sklearn.neural_network import MLPClassifier
start = time.time()
model = MLPClassifier(hidden_layer_sizes = (20,20,),
                      activation='relu',
                      solver='adam',
                      batch_size=2000,
                      verbose=0).fit(X_train,y_train)
end_train = time.time()
y_predictions = model.predict(X_test) # These are the predictions from the test data.
end_predict = time.time()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:605: UserWarning: Got `batch_size` less than 1 or larger than sample size. It is going to be clipped
#   warnings.warn(

# %%
accuracy = accuracy_score(y_test, y_predictions)
recall = recall_score(y_test, y_predictions, average='weighted')
precision = precision_score(y_test, y_predictions, average='weighted')
f1s = f1_score(y_test, y_predictions, average='weighted')

print("Accuracy: "+ "{:.2%}".format(accuracy))
print("Recall: "+ "{:.2%}".format(recall))
print("Precision: "+ "{:.2%}".format(precision))
print("F1-Score: "+ "{:.2%}".format(f1s))
print("time to train: "+ "{:.2f}".format(end_train-start)+" s")
print("time to predict: "+"{:.2f}".format(end_predict-end_train)+" s")
print("total: "+"{:.2f}".format(end_predict-start)+" s")
model_performance.loc['MLP'] = [accuracy, recall, precision, f1s,end_train-start,end_predict-end_train,end_predict-start]
# Out:
# Accuracy: 62.50%
# Recall: 62.50%
# Precision: 39.06%
# F1-Score: 48.08%
# time to train: 0.03 s
# time to predict: 0.00 s
# total: 0.03 s
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# Neural Networks MLP classifier

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, GRU
# !pip install keras_metrics
from keras import metrics
import keras_metrics as km
import keras
import numpy as np
from numpy import array
# Out:
# Collecting keras_metrics
#   Downloading keras_metrics-1.1.0-py2.py3-none-any.whl (5.6 kB)
# Requirement already satisfied: Keras>=2.1.5 in /usr/local/lib/python3.10/dist-packages (from keras_metrics) (2.15.0)
# Installing collected packages: keras_metrics
# Successfully installed keras_metrics-1.1.0

# %%
from keras import backend as K

def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
#Build the feed forward neural network model
def build_model():
    model = Sequential()
    model.add(Dense(20, input_dim=4, activation='relu'))
    model.add(Dense(20, activation='relu'))
    model.add(Dense(20, activation='softmax')) #for multiclass classification
    #Compile the model
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam',
                  metrics=['accuracy',f1_m,precision_m, recall_m]
                 )
    return model

#institate the model
model = build_model()

#fit the model
start = time.time()
model.fit(X_train, y_train, epochs=50, batch_size=16,verbose=2)
end_train = time.time()
# Out:
# Epoch 1/50
# 2/2 - 10s - loss: 29.2018 - accuracy: 0.2812 - f1_m: 0.8360 - precision_m: 0.7188 - recall_m: 1.0000 - 10s/epoch - 5s/step
# Epoch 2/50
# 2/2 - 0s - loss: 26.4250 - accuracy: 0.2812 - f1_m: 0.8267 - precision_m: 0.7188 - recall_m: 1.0000 - 37ms/epoch - 18ms/step
# Epoch 3/50
# 2/2 - 0s - loss: 23.9742 - accuracy: 0.2812 - f1_m: 0.8360 - precision_m: 0.7188 - recall_m: 1.0000 - 50ms/epoch - 25ms/step
# Epoch 4/50
# 2/2 - 0s - loss: 21.4578 - accuracy: 0.2812 - f1_m: 0.8329 - precision_m: 0.7188 - recall_m: 1.0000 - 35ms/epoch - 18ms/step
# Epoch 5/50
# 2/2 - 0s - loss: 18.8733 - accuracy: 0.2812 - f1_m: 0.8360 - precision_m: 0.7188 - recall_m: 1.0000 - 67ms/epoch - 33ms/step
# Epoch 6/50
# 2/2 - 0s - loss: 16.3173 - accuracy: 0.2812 - f1_m: 0.8329 - precision_m: 0.7188 - recall_m: 1.0000 - 97ms/epoch - 48ms/step
# Epoch 7/50
# 2/2 - 0s - loss: 14.2355 - accuracy: 0.2812 - f1_m: 0.8329 - precision_m: 0.7188 - recall_m: 1.0000 - 61ms/epoch - 30ms/step
# Epoch 8/50
# 2/2 - 0s - loss: 12.2532 - accuracy: 0.1562 - f1_m: 0.7886 - precision_m: 0.6964 - recall_m: 0.9091 - 70ms/epoch - 35ms/step
# Epoch 9/50
# 2/2 - 0s - loss: 10.2788 - accuracy: 0.0000e+00 - f1_m: 0.8360 - precision_m: 0.7188 - recall_m: 1.0000 - 67ms/epoch - 33ms/step
# Epoch 10/50
# 2/2 - 0s - loss: 8.2080 - accuracy: 0.2812 - f1_m: 0.8329 - precision_m: 0.7188 - recall_m: 1.0000 - 34ms/epoch - 17ms/step
# Epoch 11/50
# 2/2 - 0s - loss: 6.1321 - accuracy: 0.2812 - f1_m: 0.8329 - precision_m: 0.7188 - recall_m: 1.0000 - 29ms/epoch - 14ms/step
# Epoch 12/50
# 2/2 - 0s - loss: 4.1467 - accuracy: 0.2812 - f1_m: 0.8360 - precision_m: 0.7188 - recall_m: 1.0000 - 28ms/epoch - 14ms/step
# Epoch 13/50
# 2/2 - 0s - loss: 2.2872 - accuracy: 0.2812 - f1_m: 0.8360 - precision_m: 0.7188 - recall_m: 1.0000 - 53ms/epoch - 27ms/step
# Epoch 14/50
# 2/2 - 0s - loss: 0.9978 - accuracy: 0.2812 - f1_m: 0.8329 - precision_m: 0.7188 - recall_m: 1.0000 - 38ms/epoch - 19ms/step
# Epoch 15/50
# 2/2 - 0s - loss: 0.6659 - accuracy: 0.7188 - f1_m: 0.8360 - precision_m: 0.7188 - recall_m: 1.0000 - 35ms/epoch - 17ms/step
# Epoch 16/50
# 2/2 - 0s - loss: 0.8403 - accuracy: 0.7188 - f1_m: 0.8329 - precision_m: 0.7188 - recall_m: 1.0000 - 62ms/epoch - 31ms/step
# Epoch 17/50
# 2/2 - 0s - loss: 1.1429 - accuracy: 0.7188 - f1_m: 0.8360 - precision_m: 0.7188 - recall_m: 1.0000 - 50ms/epoch - 25ms/step
# Epoch 18/50
# 2/2 - 0s - loss: 1.3580 - accuracy: 0.7188 - f1_m: 0.8329 - precision_m: 0.7188 - recall_m: 1.0000 - 34ms/epoch - 17ms/step
# Epoch 19/50
# 2/2 - 0s - loss: 1.4626 - accuracy: 0.7188 - f1_m: 0.8172 - precision_m: 0.7188 - recall_m: 1.0000 - 45ms/epoch - 22ms/step
# Epoch 20/50
# 2/2 - 0s - loss: 1.4636 - accuracy: 0.7188 - f1_m: 0.8172 - precision_m: 0.7188 - recall_m: 1.0000 - 52ms/epoch - 26ms/step
# Epoch 21/50
# 2/2 - 0s - loss: 1.3776 - accuracy: 0.7188 - f1_m: 0.8360 - precision_m: 0.7188 - recall_m: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 22/50
# 2/2 - 0s - loss: 1.2528 - accuracy: 0.7188 - f1_m: 0.8360 - precision_m: 0.7188 - recall_m: 1.0000 - 46ms/epoch - 23ms/step
# Epoch 23/50
# 2/2 - 0s - loss: 1.1080 - accuracy: 0.7188 - f1_m: 0.8267 - precision_m: 0.7188 - recall_m: 1.0000 - 39ms/epoch - 19ms/step
# Epoch 24/50
# 2/2 - 0s - loss: 0.8921 - accuracy: 0.7188 - f1_m: 0.8360 - precision_m: 0.7188 - recall_m: 1.0000 - 52ms/epoch - 26ms/step
# Epoch 25/50
# 2/2 - 0s - loss: 0.6877 - accuracy: 0.7188 - f1_m: 0.8267 - precision_m: 0.7188 - recall_m: 1.0000 - 47ms/epoch - 23ms/step
# Epoch 26/50
# 2/2 - 0s - loss: 0.6119 - accuracy: 0.7188 - f1_m: 0.8360 - precision_m: 0.7188 - recall_m: 1.0000 - 32ms/epoch - 16ms/step
# Epoch 27/50
# 2/2 - 0s - loss: 0.6234 - accuracy: 0.7188 - f1_m: 0.8360 - precision_m: 0.7188 - recall_m: 1.0000 - 29ms/epoch - 15ms/step
# Epoch 28/50
# 2/2 - 0s - loss: 0.7009 - accuracy: 0.4688 - f1_m: 0.8329 - precision_m: 0.7188 - recall_m: 1.0000 - 64ms/epoch - 32ms/step
# Epoch 29/50
# 2/2 - 0s - loss: 0.7628 - accuracy: 0.2812 - f1_m: 0.8329 - precision_m: 0.7188 - recall_m: 1.0000 - 127ms/epoch - 64ms/step
# Epoch 30/50
# 2/2 - 0s - loss: 0.7333 - accuracy: 0.2500 - f1_m: 0.8519 - precision_m: 0.7437 - recall_m: 1.0000 - 48ms/epoch - 24ms/step
# Epoch 31/50
# 2/2 - 0s - loss: 0.6896 - accuracy: 0.6562 - f1_m: 0.8172 - precision_m: 0.7188 - recall_m: 1.0000 - 56ms/epoch - 28ms/step
# Epoch 32/50
# 2/2 - 0s - loss: 0.6070 - accuracy: 0.7188 - f1_m: 0.8360 - precision_m: 0.7188 - recall_m: 1.0000 - 35ms/epoch - 18ms/step
# Epoch 33/50
# 2/2 - 0s - loss: 0.5978 - accuracy: 0.7188 - f1_m: 0.8267 - precision_m: 0.7188 - recall_m: 1.0000 - 32ms/epoch - 16ms/step
# Epoch 34/50
# 2/2 - 0s - loss: 0.6202 - accuracy: 0.7188 - f1_m: 0.8329 - precision_m: 0.7188 - recall_m: 1.0000 - 59ms/epoch - 30ms/step
# Epoch 35/50
# 2/2 - 0s - loss: 0.6381 - accuracy: 0.7188 - f1_m: 0.8360 - precision_m: 0.7188 - recall_m: 1.0000 - 78ms/epoch - 39ms/step
# Epoch 36/50
# 2/2 - 0s - loss: 0.6407 - accuracy: 0.7188 - f1_m: 0.8360 - precision_m: 0.7188 - recall_m: 1.0000 - 44ms/epoch - 22ms/step
# Epoch 37/50
# 2/2 - 0s - loss: 0.6307 - accuracy: 0.7188 - f1_m: 0.8360 - precision_m: 0.7188 - recall_m: 1.0000 - 42ms/epoch - 21ms/step
# Epoch 38/50
# 2/2 - 0s - loss: 0.6139 - accuracy: 0.7188 - f1_m: 0.8360 - precision_m: 0.7188 - recall_m: 1.0000 - 49ms/epoch - 25ms/step
# Epoch 39/50
# 2/2 - 0s - loss: 0.6048 - accuracy: 0.7188 - f1_m: 0.8360 - precision_m: 0.7188 - recall_m: 1.0000 - 40ms/epoch - 20ms/step
# Epoch 40/50
# 2/2 - 0s - loss: 0.6071 - accuracy: 0.7188 - f1_m: 0.8360 - precision_m: 0.7188 - recall_m: 1.0000 - 33ms/epoch - 16ms/step
# Epoch 41/50
# 2/2 - 0s - loss: 0.6104 - accuracy: 0.7188 - f1_m: 0.8360 - precision_m: 0.7188 - recall_m: 1.0000 - 49ms/epoch - 24ms/step
# Epoch 42/50
# 2/2 - 0s - loss: 0.6143 - accuracy: 0.7188 - f1_m: 0.8329 - precision_m: 0.7188 - recall_m: 1.0000 - 66ms/epoch - 33ms/step
# Epoch 43/50
# 2/2 - 0s - loss: 0.6119 - accuracy: 0.7188 - f1_m: 0.8329 - precision_m: 0.7188 - recall_m: 1.0000 - 61ms/epoch - 31ms/step
# Epoch 44/50
# 2/2 - 0s - loss: 0.6078 - accuracy: 0.7188 - f1_m: 0.8360 - precision_m: 0.7188 - recall_m: 1.0000 - 55ms/epoch - 27ms/step
# Epoch 45/50
# 2/2 - 0s - loss: 0.6065 - accuracy: 0.7188 - f1_m: 0.8360 - precision_m: 0.7188 - recall_m: 1.0000 - 45ms/epoch - 22ms/step
# Epoch 46/50
# 2/2 - 0s - loss: 0.6090 - accuracy: 0.7188 - f1_m: 0.8329 - precision_m: 0.7188 - recall_m: 1.0000 - 39ms/epoch - 19ms/step
# Epoch 47/50
# 2/2 - 0s - loss: 0.6088 - accuracy: 0.7188 - f1_m: 0.8267 - precision_m: 0.7188 - recall_m: 1.0000 - 46ms/epoch - 23ms/step
# Epoch 48/50
# 2/2 - 0s - loss: 0.6069 - accuracy: 0.7188 - f1_m: 0.8360 - precision_m: 0.7188 - recall_m: 1.0000 - 57ms/epoch - 28ms/step
# Epoch 49/50
# 2/2 - 0s - loss: 0.6067 - accuracy: 0.7188 - f1_m: 0.8360 - precision_m: 0.7188 - recall_m: 1.0000 - 68ms/epoch - 34ms/step
# Epoch 50/50
# 2/2 - 0s - loss: 0.6057 - accuracy: 0.7188 - f1_m: 0.8360 - precision_m: 0.7188 - recall_m: 1.0000 - 56ms/epoch - 28ms/step

# %%
#Evaluate the neural network
loss, accuracy, f1s, precision, recall = model.evaluate(X_test, y_test)
end_predict = time.time()
model_performance.loc['MLP (Keras)'] = [accuracy, accuracy, accuracy, accuracy,end_train-start,end_predict-end_train,end_predict-start]
# Out:
# 1/1 [==============================] - 1s 765ms/step - loss: 0.6853 - accuracy: 0.6250 - f1_m: 0.7692 - precision_m: 0.6250 - recall_m: 1.0000

# %% [markdown]
# GRU(keras)

# %%
def build_model():
    model = Sequential()
    model.add(GRU(20, return_sequences=True,input_shape=(1,4)))
    model.add(GRU(20, return_sequences=True))
    model.add(Dense(10, activation='softmax')) #for multiclass classification
    #Compile the model
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam',
                  # metrics=['accuracy',f1_m,precision_m, recall_m]
                  metrics=['accuracy']
                 )
    return model

#The GRU input layer must be 3D.
#The meaning of the 3 input dimensions are: samples, time steps, and features.
#reshape input data
X_train_array = array(X_train) #array has been declared in the previous cell
print(len(X_train_array))
X_train_reshaped = X_train_array.reshape(X_train_array.shape[0],1,4)

#reshape output data
X_test_array=  array(X_test)
X_test_reshaped = X_test_array.reshape(X_test_array.shape[0],1,4)


#institate the model
model = build_model()

start = time.time()
#fit the model
model.fit(X_train_reshaped, y_train, epochs=200, batch_size=16,verbose=2)
end_train = time.time()
# Out:
# 32
# Epoch 1/200
# 2/2 - 8s - loss: 2.1955 - accuracy: 0.7188 - 8s/epoch - 4s/step
# Epoch 2/200
# 2/2 - 0s - loss: 2.1657 - accuracy: 0.7188 - 28ms/epoch - 14ms/step
# Epoch 3/200
# 2/2 - 0s - loss: 2.1370 - accuracy: 0.7188 - 29ms/epoch - 14ms/step
# Epoch 4/200
# 2/2 - 0s - loss: 2.1067 - accuracy: 0.7188 - 31ms/epoch - 16ms/step
# Epoch 5/200
# 2/2 - 0s - loss: 2.0789 - accuracy: 0.7188 - 35ms/epoch - 18ms/step
# Epoch 6/200
# 2/2 - 0s - loss: 2.0505 - accuracy: 0.7188 - 35ms/epoch - 18ms/step
# Epoch 7/200
# 2/2 - 0s - loss: 2.0209 - accuracy: 0.7188 - 31ms/epoch - 16ms/step
# Epoch 8/200
# 2/2 - 0s - loss: 1.9922 - accuracy: 0.7188 - 35ms/epoch - 17ms/step
# Epoch 9/200
# 2/2 - 0s - loss: 1.9621 - accuracy: 0.7188 - 27ms/epoch - 14ms/step
# Epoch 10/200
# 2/2 - 0s - loss: 1.9324 - accuracy: 0.7188 - 32ms/epoch - 16ms/step
# Epoch 11/200
# 2/2 - 0s - loss: 1.9024 - accuracy: 0.7188 - 30ms/epoch - 15ms/step
# Epoch 12/200
# 2/2 - 0s - loss: 1.8737 - accuracy: 0.7188 - 36ms/epoch - 18ms/step
# Epoch 13/200
# 2/2 - 0s - loss: 1.8412 - accuracy: 0.7188 - 31ms/epoch - 16ms/step
# Epoch 14/200
# 2/2 - 0s - loss: 1.8090 - accuracy: 0.7188 - 52ms/epoch - 26ms/step
# Epoch 15/200
# 2/2 - 0s - loss: 1.7796 - accuracy: 0.7188 - 58ms/epoch - 29ms/step
# Epoch 16/200
# 2/2 - 0s - loss: 1.7464 - accuracy: 0.7188 - 37ms/epoch - 19ms/step
# Epoch 17/200
# 2/2 - 0s - loss: 1.7134 - accuracy: 0.7188 - 52ms/epoch - 26ms/step
# Epoch 18/200
# 2/2 - 0s - loss: 1.6777 - accuracy: 0.7188 - 38ms/epoch - 19ms/step
# Epoch 19/200
# 2/2 - 0s - loss: 1.6407 - accuracy: 0.7188 - 42ms/epoch - 21ms/step
# Epoch 20/200
# 2/2 - 0s - loss: 1.6028 - accuracy: 0.7188 - 42ms/epoch - 21ms/step
# Epoch 21/200
# 2/2 - 0s - loss: 1.5564 - accuracy: 0.7188 - 47ms/epoch - 23ms/step
# Epoch 22/200
# 2/2 - 0s - loss: 1.5096 - accuracy: 0.7188 - 52ms/epoch - 26ms/step
# Epoch 23/200
# 2/2 - 0s - loss: 1.4581 - accuracy: 0.7188 - 53ms/epoch - 27ms/step
# Epoch 24/200
# 2/2 - 0s - loss: 1.4070 - accuracy: 0.7188 - 44ms/epoch - 22ms/step
# Epoch 25/200
# 2/2 - 0s - loss: 1.3568 - accuracy: 0.7188 - 106ms/epoch - 53ms/step
# Epoch 26/200
# 2/2 - 0s - loss: 1.3100 - accuracy: 0.7188 - 70ms/epoch - 35ms/step
# Epoch 27/200
# 2/2 - 0s - loss: 1.2660 - accuracy: 0.7188 - 51ms/epoch - 26ms/step
# Epoch 28/200
# 2/2 - 0s - loss: 1.2274 - accuracy: 0.7188 - 40ms/epoch - 20ms/step
# Epoch 29/200
# 2/2 - 0s - loss: 1.1946 - accuracy: 0.7188 - 54ms/epoch - 27ms/step
# Epoch 30/200
# 2/2 - 0s - loss: 1.1628 - accuracy: 0.7188 - 47ms/epoch - 23ms/step
# Epoch 31/200
# 2/2 - 0s - loss: 1.1338 - accuracy: 0.7188 - 54ms/epoch - 27ms/step
# Epoch 32/200
# 2/2 - 0s - loss: 1.1067 - accuracy: 0.7188 - 64ms/epoch - 32ms/step
# Epoch 33/200
# 2/2 - 0s - loss: 1.0819 - accuracy: 0.7188 - 80ms/epoch - 40ms/step
# Epoch 34/200
# 2/2 - 0s - loss: 1.0577 - accuracy: 0.7188 - 45ms/epoch - 22ms/step
# Epoch 35/200
# 2/2 - 0s - loss: 1.0344 - accuracy: 0.7188 - 38ms/epoch - 19ms/step
# Epoch 36/200
# 2/2 - 0s - loss: 1.0131 - accuracy: 0.7188 - 28ms/epoch - 14ms/step
# Epoch 37/200
# 2/2 - 0s - loss: 0.9933 - accuracy: 0.7188 - 30ms/epoch - 15ms/step
# Epoch 38/200
# 2/2 - 0s - loss: 0.9742 - accuracy: 0.7188 - 26ms/epoch - 13ms/step
# Epoch 39/200
# 2/2 - 0s - loss: 0.9566 - accuracy: 0.7188 - 140ms/epoch - 70ms/step
# Epoch 40/200
# 2/2 - 0s - loss: 0.9395 - accuracy: 0.7188 - 82ms/epoch - 41ms/step
# Epoch 41/200
# 2/2 - 0s - loss: 0.9236 - accuracy: 0.7188 - 91ms/epoch - 46ms/step
# Epoch 42/200
# 2/2 - 0s - loss: 0.9087 - accuracy: 0.7188 - 48ms/epoch - 24ms/step
# Epoch 43/200
# 2/2 - 0s - loss: 0.8942 - accuracy: 0.7188 - 68ms/epoch - 34ms/step
# Epoch 44/200
# 2/2 - 0s - loss: 0.8807 - accuracy: 0.7188 - 67ms/epoch - 33ms/step
# Epoch 45/200
# 2/2 - 0s - loss: 0.8679 - accuracy: 0.7188 - 45ms/epoch - 23ms/step
# Epoch 46/200
# 2/2 - 0s - loss: 0.8558 - accuracy: 0.7188 - 70ms/epoch - 35ms/step
# Epoch 47/200
# 2/2 - 0s - loss: 0.8445 - accuracy: 0.7188 - 39ms/epoch - 19ms/step
# Epoch 48/200
# 2/2 - 0s - loss: 0.8329 - accuracy: 0.7188 - 43ms/epoch - 22ms/step
# Epoch 49/200
# 2/2 - 0s - loss: 0.8226 - accuracy: 0.7188 - 45ms/epoch - 23ms/step
# Epoch 50/200
# 2/2 - 0s - loss: 0.8121 - accuracy: 0.7188 - 62ms/epoch - 31ms/step
# Epoch 51/200
# 2/2 - 0s - loss: 0.8031 - accuracy: 0.7188 - 63ms/epoch - 32ms/step
# Epoch 52/200
# 2/2 - 0s - loss: 0.7948 - accuracy: 0.7188 - 56ms/epoch - 28ms/step
# Epoch 53/200
# 2/2 - 0s - loss: 0.7855 - accuracy: 0.7188 - 65ms/epoch - 33ms/step
# Epoch 54/200
# 2/2 - 0s - loss: 0.7765 - accuracy: 0.7188 - 57ms/epoch - 29ms/step
# Epoch 55/200
# 2/2 - 0s - loss: 0.7687 - accuracy: 0.7188 - 46ms/epoch - 23ms/step
# Epoch 56/200
# 2/2 - 0s - loss: 0.7615 - accuracy: 0.7188 - 46ms/epoch - 23ms/step
# Epoch 57/200
# 2/2 - 0s - loss: 0.7540 - accuracy: 0.7188 - 40ms/epoch - 20ms/step
# Epoch 58/200
# 2/2 - 0s - loss: 0.7471 - accuracy: 0.7188 - 44ms/epoch - 22ms/step
# Epoch 59/200
# 2/2 - 0s - loss: 0.7409 - accuracy: 0.7188 - 36ms/epoch - 18ms/step
# Epoch 60/200
# 2/2 - 0s - loss: 0.7346 - accuracy: 0.7188 - 37ms/epoch - 18ms/step
# Epoch 61/200
# 2/2 - 0s - loss: 0.7281 - accuracy: 0.7188 - 44ms/epoch - 22ms/step
# Epoch 62/200
# 2/2 - 0s - loss: 0.7227 - accuracy: 0.7188 - 21ms/epoch - 11ms/step
# Epoch 63/200
# 2/2 - 0s - loss: 0.7181 - accuracy: 0.7188 - 26ms/epoch - 13ms/step
# Epoch 64/200
# 2/2 - 0s - loss: 0.7129 - accuracy: 0.7188 - 35ms/epoch - 18ms/step
# Epoch 65/200
# 2/2 - 0s - loss: 0.7085 - accuracy: 0.7188 - 35ms/epoch - 17ms/step
# Epoch 66/200
# 2/2 - 0s - loss: 0.7026 - accuracy: 0.7188 - 40ms/epoch - 20ms/step
# Epoch 67/200
# 2/2 - 0s - loss: 0.6988 - accuracy: 0.7188 - 29ms/epoch - 14ms/step
# Epoch 68/200
# 2/2 - 0s - loss: 0.6944 - accuracy: 0.7188 - 32ms/epoch - 16ms/step
# Epoch 69/200
# 2/2 - 0s - loss: 0.6910 - accuracy: 0.7188 - 40ms/epoch - 20ms/step
# Epoch 70/200
# 2/2 - 0s - loss: 0.6870 - accuracy: 0.7188 - 31ms/epoch - 15ms/step
# Epoch 71/200
# 2/2 - 0s - loss: 0.6853 - accuracy: 0.7188 - 40ms/epoch - 20ms/step
# Epoch 72/200
# 2/2 - 0s - loss: 0.6806 - accuracy: 0.7188 - 41ms/epoch - 21ms/step
# Epoch 73/200
# 2/2 - 0s - loss: 0.6775 - accuracy: 0.7188 - 38ms/epoch - 19ms/step
# Epoch 74/200
# 2/2 - 0s - loss: 0.6749 - accuracy: 0.7188 - 32ms/epoch - 16ms/step
# Epoch 75/200
# 2/2 - 0s - loss: 0.6718 - accuracy: 0.7188 - 37ms/epoch - 19ms/step
# Epoch 76/200
# 2/2 - 0s - loss: 0.6691 - accuracy: 0.7188 - 32ms/epoch - 16ms/step
# Epoch 77/200
# 2/2 - 0s - loss: 0.6668 - accuracy: 0.7188 - 36ms/epoch - 18ms/step
# Epoch 78/200
# 2/2 - 0s - loss: 0.6644 - accuracy: 0.7188 - 29ms/epoch - 14ms/step
# Epoch 79/200
# 2/2 - 0s - loss: 0.6620 - accuracy: 0.7188 - 41ms/epoch - 21ms/step
# Epoch 80/200
# 2/2 - 0s - loss: 0.6601 - accuracy: 0.7188 - 27ms/epoch - 14ms/step
# Epoch 81/200
# 2/2 - 0s - loss: 0.6583 - accuracy: 0.7188 - 28ms/epoch - 14ms/step
# Epoch 82/200
# 2/2 - 0s - loss: 0.6560 - accuracy: 0.7188 - 43ms/epoch - 21ms/step
# Epoch 83/200
# 2/2 - 0s - loss: 0.6541 - accuracy: 0.7188 - 37ms/epoch - 19ms/step
# Epoch 84/200
# 2/2 - 0s - loss: 0.6524 - accuracy: 0.7188 - 32ms/epoch - 16ms/step
# Epoch 85/200
# 2/2 - 0s - loss: 0.6510 - accuracy: 0.7188 - 26ms/epoch - 13ms/step
# Epoch 86/200
# 2/2 - 0s - loss: 0.6491 - accuracy: 0.7188 - 27ms/epoch - 14ms/step
# Epoch 87/200
# 2/2 - 0s - loss: 0.6476 - accuracy: 0.7188 - 50ms/epoch - 25ms/step
# Epoch 88/200
# 2/2 - 0s - loss: 0.6461 - accuracy: 0.7188 - 31ms/epoch - 15ms/step
# Epoch 89/200
# 2/2 - 0s - loss: 0.6447 - accuracy: 0.7188 - 36ms/epoch - 18ms/step
# Epoch 90/200
# 2/2 - 0s - loss: 0.6436 - accuracy: 0.7188 - 31ms/epoch - 15ms/step
# Epoch 91/200
# 2/2 - 0s - loss: 0.6421 - accuracy: 0.7188 - 38ms/epoch - 19ms/step
# Epoch 92/200
# 2/2 - 0s - loss: 0.6409 - accuracy: 0.7188 - 32ms/epoch - 16ms/step
# Epoch 93/200
# 2/2 - 0s - loss: 0.6399 - accuracy: 0.7188 - 32ms/epoch - 16ms/step
# Epoch 94/200
# 2/2 - 0s - loss: 0.6385 - accuracy: 0.7188 - 32ms/epoch - 16ms/step
# Epoch 95/200
# 2/2 - 0s - loss: 0.6376 - accuracy: 0.7188 - 32ms/epoch - 16ms/step
# Epoch 96/200
# 2/2 - 0s - loss: 0.6365 - accuracy: 0.7188 - 30ms/epoch - 15ms/step
# Epoch 97/200
# 2/2 - 0s - loss: 0.6354 - accuracy: 0.7188 - 34ms/epoch - 17ms/step
# Epoch 98/200
# 2/2 - 0s - loss: 0.6344 - accuracy: 0.7188 - 40ms/epoch - 20ms/step
# Epoch 99/200
# 2/2 - 0s - loss: 0.6336 - accuracy: 0.7188 - 33ms/epoch - 16ms/step
# Epoch 100/200
# 2/2 - 0s - loss: 0.6330 - accuracy: 0.7188 - 34ms/epoch - 17ms/step
# Epoch 101/200
# 2/2 - 0s - loss: 0.6318 - accuracy: 0.7188 - 42ms/epoch - 21ms/step
# Epoch 102/200
# 2/2 - 0s - loss: 0.6311 - accuracy: 0.7188 - 58ms/epoch - 29ms/step
# Epoch 103/200
# 2/2 - 0s - loss: 0.6301 - accuracy: 0.7188 - 39ms/epoch - 20ms/step
# Epoch 104/200
# 2/2 - 0s - loss: 0.6293 - accuracy: 0.7188 - 33ms/epoch - 16ms/step
# Epoch 105/200
# 2/2 - 0s - loss: 0.6286 - accuracy: 0.7188 - 46ms/epoch - 23ms/step
# Epoch 106/200
# 2/2 - 0s - loss: 0.6280 - accuracy: 0.7188 - 41ms/epoch - 20ms/step
# Epoch 107/200
# 2/2 - 0s - loss: 0.6271 - accuracy: 0.7188 - 132ms/epoch - 66ms/step
# Epoch 108/200
# 2/2 - 0s - loss: 0.6265 - accuracy: 0.7188 - 41ms/epoch - 21ms/step
# Epoch 109/200
# 2/2 - 0s - loss: 0.6258 - accuracy: 0.7188 - 56ms/epoch - 28ms/step
# Epoch 110/200
# 2/2 - 0s - loss: 0.6254 - accuracy: 0.7188 - 34ms/epoch - 17ms/step
# Epoch 111/200
# 2/2 - 0s - loss: 0.6246 - accuracy: 0.7188 - 47ms/epoch - 23ms/step
# Epoch 112/200
# 2/2 - 0s - loss: 0.6240 - accuracy: 0.7188 - 33ms/epoch - 16ms/step
# Epoch 113/200
# 2/2 - 0s - loss: 0.6234 - accuracy: 0.7188 - 35ms/epoch - 18ms/step
# Epoch 114/200
# 2/2 - 0s - loss: 0.6229 - accuracy: 0.7188 - 44ms/epoch - 22ms/step
# Epoch 115/200
# 2/2 - 0s - loss: 0.6223 - accuracy: 0.7188 - 108ms/epoch - 54ms/step
# Epoch 116/200
# 2/2 - 0s - loss: 0.6218 - accuracy: 0.7188 - 37ms/epoch - 19ms/step
# Epoch 117/200
# 2/2 - 0s - loss: 0.6213 - accuracy: 0.7188 - 40ms/epoch - 20ms/step
# Epoch 118/200
# 2/2 - 0s - loss: 0.6208 - accuracy: 0.7188 - 48ms/epoch - 24ms/step
# Epoch 119/200
# 2/2 - 0s - loss: 0.6203 - accuracy: 0.7188 - 47ms/epoch - 23ms/step
# Epoch 120/200
# 2/2 - 0s - loss: 0.6199 - accuracy: 0.7188 - 64ms/epoch - 32ms/step
# Epoch 121/200
# 2/2 - 0s - loss: 0.6196 - accuracy: 0.7188 - 61ms/epoch - 30ms/step
# Epoch 122/200
# 2/2 - 0s - loss: 0.6192 - accuracy: 0.7188 - 67ms/epoch - 33ms/step
# Epoch 123/200
# 2/2 - 0s - loss: 0.6187 - accuracy: 0.7188 - 41ms/epoch - 20ms/step
# Epoch 124/200
# 2/2 - 0s - loss: 0.6183 - accuracy: 0.7188 - 42ms/epoch - 21ms/step
# Epoch 125/200
# 2/2 - 0s - loss: 0.6177 - accuracy: 0.7188 - 40ms/epoch - 20ms/step
# Epoch 126/200
# 2/2 - 0s - loss: 0.6174 - accuracy: 0.7188 - 54ms/epoch - 27ms/step
# Epoch 127/200
# 2/2 - 0s - loss: 0.6175 - accuracy: 0.7188 - 45ms/epoch - 22ms/step
# Epoch 128/200
# 2/2 - 0s - loss: 0.6176 - accuracy: 0.7188 - 33ms/epoch - 16ms/step
# Epoch 129/200
# 2/2 - 0s - loss: 0.6162 - accuracy: 0.7188 - 31ms/epoch - 16ms/step
# Epoch 130/200
# 2/2 - 0s - loss: 0.6159 - accuracy: 0.7188 - 40ms/epoch - 20ms/step
# Epoch 131/200
# 2/2 - 0s - loss: 0.6156 - accuracy: 0.7188 - 41ms/epoch - 21ms/step
# Epoch 132/200
# 2/2 - 0s - loss: 0.6162 - accuracy: 0.7188 - 38ms/epoch - 19ms/step
# Epoch 133/200
# 2/2 - 0s - loss: 0.6153 - accuracy: 0.7188 - 29ms/epoch - 14ms/step
# Epoch 134/200
# 2/2 - 0s - loss: 0.6146 - accuracy: 0.7188 - 47ms/epoch - 24ms/step
# Epoch 135/200
# 2/2 - 0s - loss: 0.6144 - accuracy: 0.7188 - 36ms/epoch - 18ms/step
# Epoch 136/200
# 2/2 - 0s - loss: 0.6140 - accuracy: 0.7188 - 35ms/epoch - 18ms/step
# Epoch 137/200
# 2/2 - 0s - loss: 0.6137 - accuracy: 0.7188 - 30ms/epoch - 15ms/step
# Epoch 138/200
# 2/2 - 0s - loss: 0.6137 - accuracy: 0.7188 - 29ms/epoch - 14ms/step
# Epoch 139/200
# 2/2 - 0s - loss: 0.6132 - accuracy: 0.7188 - 44ms/epoch - 22ms/step
# Epoch 140/200
# 2/2 - 0s - loss: 0.6129 - accuracy: 0.7188 - 31ms/epoch - 16ms/step
# Epoch 141/200
# 2/2 - 0s - loss: 0.6127 - accuracy: 0.7188 - 30ms/epoch - 15ms/step
# Epoch 142/200
# 2/2 - 0s - loss: 0.6124 - accuracy: 0.7188 - 37ms/epoch - 18ms/step
# Epoch 143/200
# 2/2 - 0s - loss: 0.6121 - accuracy: 0.7188 - 31ms/epoch - 16ms/step
# Epoch 144/200
# 2/2 - 0s - loss: 0.6119 - accuracy: 0.7188 - 29ms/epoch - 15ms/step
# Epoch 145/200
# 2/2 - 0s - loss: 0.6118 - accuracy: 0.7188 - 33ms/epoch - 17ms/step
# Epoch 146/200
# 2/2 - 0s - loss: 0.6116 - accuracy: 0.7188 - 25ms/epoch - 13ms/step
# Epoch 147/200
# 2/2 - 0s - loss: 0.6113 - accuracy: 0.7188 - 40ms/epoch - 20ms/step
# Epoch 148/200
# 2/2 - 0s - loss: 0.6110 - accuracy: 0.7188 - 36ms/epoch - 18ms/step
# Epoch 149/200
# 2/2 - 0s - loss: 0.6112 - accuracy: 0.7188 - 35ms/epoch - 18ms/step
# Epoch 150/200
# 2/2 - 0s - loss: 0.6106 - accuracy: 0.7188 - 37ms/epoch - 18ms/step
# Epoch 151/200
# 2/2 - 0s - loss: 0.6103 - accuracy: 0.7188 - 39ms/epoch - 19ms/step
# Epoch 152/200
# 2/2 - 0s - loss: 0.6102 - accuracy: 0.7188 - 31ms/epoch - 15ms/step
# Epoch 153/200
# 2/2 - 0s - loss: 0.6100 - accuracy: 0.7188 - 52ms/epoch - 26ms/step
# Epoch 154/200
# 2/2 - 0s - loss: 0.6099 - accuracy: 0.7188 - 23ms/epoch - 12ms/step
# Epoch 155/200
# 2/2 - 0s - loss: 0.6097 - accuracy: 0.7188 - 19ms/epoch - 9ms/step
# Epoch 156/200
# 2/2 - 0s - loss: 0.6094 - accuracy: 0.7188 - 23ms/epoch - 11ms/step
# Epoch 157/200
# 2/2 - 0s - loss: 0.6092 - accuracy: 0.7188 - 36ms/epoch - 18ms/step
# Epoch 158/200
# 2/2 - 0s - loss: 0.6092 - accuracy: 0.7188 - 32ms/epoch - 16ms/step
# Epoch 159/200
# 2/2 - 0s - loss: 0.6093 - accuracy: 0.7188 - 22ms/epoch - 11ms/step
# Epoch 160/200
# 2/2 - 0s - loss: 0.6086 - accuracy: 0.7188 - 25ms/epoch - 12ms/step
# Epoch 161/200
# 2/2 - 0s - loss: 0.6086 - accuracy: 0.7188 - 44ms/epoch - 22ms/step
# Epoch 162/200
# 2/2 - 0s - loss: 0.6086 - accuracy: 0.7188 - 32ms/epoch - 16ms/step
# Epoch 163/200
# 2/2 - 0s - loss: 0.6083 - accuracy: 0.7188 - 31ms/epoch - 16ms/step
# Epoch 164/200
# 2/2 - 0s - loss: 0.6082 - accuracy: 0.7188 - 34ms/epoch - 17ms/step
# Epoch 165/200
# 2/2 - 0s - loss: 0.6078 - accuracy: 0.7188 - 35ms/epoch - 18ms/step
# Epoch 166/200
# 2/2 - 0s - loss: 0.6077 - accuracy: 0.7188 - 39ms/epoch - 19ms/step
# Epoch 167/200
# 2/2 - 0s - loss: 0.6075 - accuracy: 0.7188 - 31ms/epoch - 16ms/step
# Epoch 168/200
# 2/2 - 0s - loss: 0.6075 - accuracy: 0.7188 - 35ms/epoch - 17ms/step
# Epoch 169/200
# 2/2 - 0s - loss: 0.6074 - accuracy: 0.7188 - 34ms/epoch - 17ms/step
# Epoch 170/200
# 2/2 - 0s - loss: 0.6071 - accuracy: 0.7188 - 33ms/epoch - 17ms/step
# Epoch 171/200
# 2/2 - 0s - loss: 0.6075 - accuracy: 0.7188 - 37ms/epoch - 19ms/step
# Epoch 172/200
# 2/2 - 0s - loss: 0.6073 - accuracy: 0.7188 - 33ms/epoch - 16ms/step
# Epoch 173/200
# 2/2 - 0s - loss: 0.6067 - accuracy: 0.7188 - 29ms/epoch - 15ms/step
# Epoch 174/200
# 2/2 - 0s - loss: 0.6065 - accuracy: 0.7188 - 37ms/epoch - 18ms/step
# Epoch 175/200
# 2/2 - 0s - loss: 0.6069 - accuracy: 0.7188 - 63ms/epoch - 32ms/step
# Epoch 176/200
# 2/2 - 0s - loss: 0.6063 - accuracy: 0.7188 - 64ms/epoch - 32ms/step
# Epoch 177/200
# 2/2 - 0s - loss: 0.6072 - accuracy: 0.7188 - 50ms/epoch - 25ms/step
# Epoch 178/200
# 2/2 - 0s - loss: 0.6062 - accuracy: 0.7188 - 50ms/epoch - 25ms/step
# Epoch 179/200
# 2/2 - 0s - loss: 0.6059 - accuracy: 0.7188 - 43ms/epoch - 21ms/step
# Epoch 180/200
# 2/2 - 0s - loss: 0.6058 - accuracy: 0.7188 - 48ms/epoch - 24ms/step
# Epoch 181/200
# 2/2 - 0s - loss: 0.6057 - accuracy: 0.7188 - 22ms/epoch - 11ms/step
# Epoch 182/200
# 2/2 - 0s - loss: 0.6058 - accuracy: 0.7188 - 26ms/epoch - 13ms/step
# Epoch 183/200
# 2/2 - 0s - loss: 0.6055 - accuracy: 0.7188 - 35ms/epoch - 18ms/step
# Epoch 184/200
# 2/2 - 0s - loss: 0.6053 - accuracy: 0.7188 - 35ms/epoch - 17ms/step
# Epoch 185/200
# 2/2 - 0s - loss: 0.6054 - accuracy: 0.7188 - 34ms/epoch - 17ms/step
# Epoch 186/200
# 2/2 - 0s - loss: 0.6053 - accuracy: 0.7188 - 44ms/epoch - 22ms/step
# Epoch 187/200
# 2/2 - 0s - loss: 0.6050 - accuracy: 0.7188 - 74ms/epoch - 37ms/step
# Epoch 188/200
# 2/2 - 0s - loss: 0.6049 - accuracy: 0.7188 - 46ms/epoch - 23ms/step
# Epoch 189/200
# 2/2 - 0s - loss: 0.6050 - accuracy: 0.7188 - 52ms/epoch - 26ms/step
# Epoch 190/200
# 2/2 - 0s - loss: 0.6047 - accuracy: 0.7188 - 43ms/epoch - 22ms/step
# Epoch 191/200
# 2/2 - 0s - loss: 0.6046 - accuracy: 0.7188 - 38ms/epoch - 19ms/step
# Epoch 192/200
# 2/2 - 0s - loss: 0.6045 - accuracy: 0.7188 - 29ms/epoch - 15ms/step
# Epoch 193/200
# 2/2 - 0s - loss: 0.6044 - accuracy: 0.7188 - 28ms/epoch - 14ms/step
# Epoch 194/200
# 2/2 - 0s - loss: 0.6043 - accuracy: 0.7188 - 51ms/epoch - 25ms/step
# Epoch 195/200
# 2/2 - 0s - loss: 0.6044 - accuracy: 0.7188 - 29ms/epoch - 14ms/step
# Epoch 196/200
# 2/2 - 0s - loss: 0.6041 - accuracy: 0.7188 - 24ms/epoch - 12ms/step
# Epoch 197/200
# 2/2 - 0s - loss: 0.6041 - accuracy: 0.7188 - 44ms/epoch - 22ms/step
# Epoch 198/200
# 2/2 - 0s - loss: 0.6040 - accuracy: 0.7188 - 35ms/epoch - 18ms/step
# Epoch 199/200
# 2/2 - 0s - loss: 0.6039 - accuracy: 0.7188 - 28ms/epoch - 14ms/step
# Epoch 200/200
# 2/2 - 0s - loss: 0.6038 - accuracy: 0.7188 - 38ms/epoch - 19ms/step

# %%
loss, accuracy = model.evaluate(X_test_reshaped, y_test)
# loss, accuracy, f1s, precision, recall = model.evaluate(X_test_reshaped, y_test)
end_predict = time.time()
model_performance.loc['GRU (Keras)'] = [accuracy, accuracy, accuracy, accuracy, end_train-start,end_predict-end_train,end_predict-start]
# Out:
# 1/1 [==============================] - 3s 3s/step - loss: 0.6931 - accuracy: 0.6250

# %% [markdown]
# LSTM(keras)

# %%
def build_model():
    model = Sequential()
    model.add(LSTM(20, return_sequences=True,input_shape=(1,4)))
    model.add(LSTM(20, return_sequences=True))
    model.add(Dense(10, activation='softmax')) #for multiclass classification
    #Compile the model
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam',
                  # metrics=['accuracy',f1_m,precision_m, recall_m]
                  metrics=['accuracy']
                 )
    return model

#The LSTM input layer must be 3D.
#The meaning of the 3 input dimensions are: samples, time steps, and features.
#reshape input data
X_train_array = array(X_train) #array has been declared in the previous cell
print(len(X_train_array))
X_train_reshaped = X_train_array.reshape(X_train_array.shape[0],1,4)

#reshape output data
X_test_array=  array(X_test)
X_test_reshaped = X_test_array.reshape(X_test_array.shape[0],1,4)


#institate the model
model = build_model()


#fit the model
start = time.time()
model.fit(X_train_reshaped, y_train, epochs=200, batch_size=16,verbose=2)
end_train = time.time()
# Out:
# 32
# Epoch 1/200
# 2/2 - 10s - loss: 2.2825 - accuracy: 0.0000e+00 - 10s/epoch - 5s/step
# Epoch 2/200
# 2/2 - 0s - loss: 2.2638 - accuracy: 0.0000e+00 - 20ms/epoch - 10ms/step
# Epoch 3/200
# 2/2 - 0s - loss: 2.2452 - accuracy: 0.1250 - 16ms/epoch - 8ms/step
# Epoch 4/200
# 2/2 - 0s - loss: 2.2266 - accuracy: 0.2812 - 17ms/epoch - 9ms/step
# Epoch 5/200
# 2/2 - 0s - loss: 2.2081 - accuracy: 0.2812 - 16ms/epoch - 8ms/step
# Epoch 6/200
# 2/2 - 0s - loss: 2.1895 - accuracy: 0.2812 - 17ms/epoch - 8ms/step
# Epoch 7/200
# 2/2 - 0s - loss: 2.1709 - accuracy: 0.2812 - 14ms/epoch - 7ms/step
# Epoch 8/200
# 2/2 - 0s - loss: 2.1521 - accuracy: 0.2812 - 15ms/epoch - 8ms/step
# Epoch 9/200
# 2/2 - 0s - loss: 2.1330 - accuracy: 0.2812 - 17ms/epoch - 8ms/step
# Epoch 10/200
# 2/2 - 0s - loss: 2.1135 - accuracy: 0.2812 - 16ms/epoch - 8ms/step
# Epoch 11/200
# 2/2 - 0s - loss: 2.0937 - accuracy: 0.2812 - 16ms/epoch - 8ms/step
# Epoch 12/200
# 2/2 - 0s - loss: 2.0731 - accuracy: 0.2812 - 16ms/epoch - 8ms/step
# Epoch 13/200
# 2/2 - 0s - loss: 2.0515 - accuracy: 0.2812 - 17ms/epoch - 9ms/step
# Epoch 14/200
# 2/2 - 0s - loss: 2.0287 - accuracy: 0.2812 - 15ms/epoch - 8ms/step
# Epoch 15/200
# 2/2 - 0s - loss: 2.0045 - accuracy: 0.2812 - 17ms/epoch - 9ms/step
# Epoch 16/200
# 2/2 - 0s - loss: 1.9788 - accuracy: 0.2812 - 17ms/epoch - 8ms/step
# Epoch 17/200
# 2/2 - 0s - loss: 1.9521 - accuracy: 0.2812 - 15ms/epoch - 8ms/step
# Epoch 18/200
# 2/2 - 0s - loss: 1.9249 - accuracy: 0.3125 - 16ms/epoch - 8ms/step
# Epoch 19/200
# 2/2 - 0s - loss: 1.8978 - accuracy: 0.7188 - 16ms/epoch - 8ms/step
# Epoch 20/200
# 2/2 - 0s - loss: 1.8706 - accuracy: 0.7188 - 17ms/epoch - 8ms/step
# Epoch 21/200
# 2/2 - 0s - loss: 1.8435 - accuracy: 0.7188 - 18ms/epoch - 9ms/step
# Epoch 22/200
# 2/2 - 0s - loss: 1.8164 - accuracy: 0.7188 - 16ms/epoch - 8ms/step
# Epoch 23/200
# 2/2 - 0s - loss: 1.7890 - accuracy: 0.7188 - 17ms/epoch - 9ms/step
# Epoch 24/200
# 2/2 - 0s - loss: 1.7613 - accuracy: 0.7188 - 17ms/epoch - 8ms/step
# Epoch 25/200
# 2/2 - 0s - loss: 1.7334 - accuracy: 0.7188 - 16ms/epoch - 8ms/step
# Epoch 26/200
# 2/2 - 0s - loss: 1.7052 - accuracy: 0.7188 - 20ms/epoch - 10ms/step
# Epoch 27/200
# 2/2 - 0s - loss: 1.6766 - accuracy: 0.7188 - 20ms/epoch - 10ms/step
# Epoch 28/200
# 2/2 - 0s - loss: 1.6478 - accuracy: 0.7188 - 15ms/epoch - 7ms/step
# Epoch 29/200
# 2/2 - 0s - loss: 1.6187 - accuracy: 0.7188 - 15ms/epoch - 8ms/step
# Epoch 30/200
# 2/2 - 0s - loss: 1.5894 - accuracy: 0.7188 - 15ms/epoch - 8ms/step
# Epoch 31/200
# 2/2 - 0s - loss: 1.5600 - accuracy: 0.7188 - 17ms/epoch - 9ms/step
# Epoch 32/200
# 2/2 - 0s - loss: 1.5304 - accuracy: 0.7188 - 15ms/epoch - 8ms/step
# Epoch 33/200
# 2/2 - 0s - loss: 1.5008 - accuracy: 0.7188 - 16ms/epoch - 8ms/step
# Epoch 34/200
# 2/2 - 0s - loss: 1.4711 - accuracy: 0.7188 - 16ms/epoch - 8ms/step
# Epoch 35/200
# 2/2 - 0s - loss: 1.4414 - accuracy: 0.7188 - 17ms/epoch - 8ms/step
# Epoch 36/200
# 2/2 - 0s - loss: 1.4119 - accuracy: 0.7188 - 16ms/epoch - 8ms/step
# Epoch 37/200
# 2/2 - 0s - loss: 1.3826 - accuracy: 0.7188 - 18ms/epoch - 9ms/step
# Epoch 38/200
# 2/2 - 0s - loss: 1.3534 - accuracy: 0.7188 - 17ms/epoch - 9ms/step
# Epoch 39/200
# 2/2 - 0s - loss: 1.3250 - accuracy: 0.7188 - 17ms/epoch - 8ms/step
# Epoch 40/200
# 2/2 - 0s - loss: 1.2968 - accuracy: 0.7188 - 17ms/epoch - 9ms/step
# Epoch 41/200
# 2/2 - 0s - loss: 1.2685 - accuracy: 0.7188 - 20ms/epoch - 10ms/step
# Epoch 42/200
# 2/2 - 0s - loss: 1.2410 - accuracy: 0.7188 - 16ms/epoch - 8ms/step
# Epoch 43/200
# 2/2 - 0s - loss: 1.2143 - accuracy: 0.7188 - 18ms/epoch - 9ms/step
# Epoch 44/200
# 2/2 - 0s - loss: 1.1881 - accuracy: 0.7188 - 16ms/epoch - 8ms/step
# Epoch 45/200
# 2/2 - 0s - loss: 1.1615 - accuracy: 0.7188 - 16ms/epoch - 8ms/step
# Epoch 46/200
# 2/2 - 0s - loss: 1.1363 - accuracy: 0.7188 - 17ms/epoch - 9ms/step
# Epoch 47/200
# 2/2 - 0s - loss: 1.1135 - accuracy: 0.7188 - 16ms/epoch - 8ms/step
# Epoch 48/200
# 2/2 - 0s - loss: 1.0887 - accuracy: 0.7188 - 17ms/epoch - 9ms/step
# Epoch 49/200
# 2/2 - 0s - loss: 1.0663 - accuracy: 0.7188 - 15ms/epoch - 8ms/step
# Epoch 50/200
# 2/2 - 0s - loss: 1.0433 - accuracy: 0.7188 - 17ms/epoch - 8ms/step
# Epoch 51/200
# 2/2 - 0s - loss: 1.0212 - accuracy: 0.7188 - 16ms/epoch - 8ms/step
# Epoch 52/200
# 2/2 - 0s - loss: 1.0004 - accuracy: 0.7188 - 17ms/epoch - 8ms/step
# Epoch 53/200
# 2/2 - 0s - loss: 0.9803 - accuracy: 0.7188 - 19ms/epoch - 9ms/step
# Epoch 54/200
# 2/2 - 0s - loss: 0.9607 - accuracy: 0.7188 - 16ms/epoch - 8ms/step
# Epoch 55/200
# 2/2 - 0s - loss: 0.9408 - accuracy: 0.7188 - 15ms/epoch - 7ms/step
# Epoch 56/200
# 2/2 - 0s - loss: 0.9193 - accuracy: 0.7188 - 18ms/epoch - 9ms/step
# Epoch 57/200
# 2/2 - 0s - loss: 0.8995 - accuracy: 0.7188 - 18ms/epoch - 9ms/step
# Epoch 58/200
# 2/2 - 0s - loss: 0.8785 - accuracy: 0.7188 - 19ms/epoch - 10ms/step
# Epoch 59/200
# 2/2 - 0s - loss: 0.8588 - accuracy: 0.7188 - 21ms/epoch - 10ms/step
# Epoch 60/200
# 2/2 - 0s - loss: 0.8409 - accuracy: 0.7188 - 16ms/epoch - 8ms/step
# Epoch 61/200
# 2/2 - 0s - loss: 0.8241 - accuracy: 0.7188 - 16ms/epoch - 8ms/step
# Epoch 62/200
# 2/2 - 0s - loss: 0.8097 - accuracy: 0.7188 - 15ms/epoch - 7ms/step
# Epoch 63/200
# 2/2 - 0s - loss: 0.7959 - accuracy: 0.7188 - 16ms/epoch - 8ms/step
# Epoch 64/200
# 2/2 - 0s - loss: 0.7847 - accuracy: 0.7188 - 18ms/epoch - 9ms/step
# Epoch 65/200
# 2/2 - 0s - loss: 0.7737 - accuracy: 0.7188 - 17ms/epoch - 8ms/step
# Epoch 66/200
# 2/2 - 0s - loss: 0.7634 - accuracy: 0.7188 - 19ms/epoch - 9ms/step
# Epoch 67/200
# 2/2 - 0s - loss: 0.7536 - accuracy: 0.7188 - 19ms/epoch - 9ms/step
# Epoch 68/200
# 2/2 - 0s - loss: 0.7449 - accuracy: 0.7188 - 16ms/epoch - 8ms/step
# Epoch 69/200
# 2/2 - 0s - loss: 0.7381 - accuracy: 0.7188 - 18ms/epoch - 9ms/step
# Epoch 70/200
# 2/2 - 0s - loss: 0.7300 - accuracy: 0.7188 - 18ms/epoch - 9ms/step
# Epoch 71/200
# 2/2 - 0s - loss: 0.7222 - accuracy: 0.7188 - 19ms/epoch - 10ms/step
# Epoch 72/200
# 2/2 - 0s - loss: 0.7163 - accuracy: 0.7188 - 24ms/epoch - 12ms/step
# Epoch 73/200
# 2/2 - 0s - loss: 0.7105 - accuracy: 0.7188 - 21ms/epoch - 10ms/step
# Epoch 74/200
# 2/2 - 0s - loss: 0.7049 - accuracy: 0.7188 - 17ms/epoch - 8ms/step
# Epoch 75/200
# 2/2 - 0s - loss: 0.7000 - accuracy: 0.7188 - 19ms/epoch - 9ms/step
# Epoch 76/200
# 2/2 - 0s - loss: 0.6954 - accuracy: 0.7188 - 17ms/epoch - 9ms/step
# Epoch 77/200
# 2/2 - 0s - loss: 0.6915 - accuracy: 0.7188 - 18ms/epoch - 9ms/step
# Epoch 78/200
# 2/2 - 0s - loss: 0.6878 - accuracy: 0.7188 - 18ms/epoch - 9ms/step
# Epoch 79/200
# 2/2 - 0s - loss: 0.6837 - accuracy: 0.7188 - 18ms/epoch - 9ms/step
# Epoch 80/200
# 2/2 - 0s - loss: 0.6805 - accuracy: 0.7188 - 17ms/epoch - 9ms/step
# Epoch 81/200
# 2/2 - 0s - loss: 0.6769 - accuracy: 0.7188 - 18ms/epoch - 9ms/step
# Epoch 82/200
# 2/2 - 0s - loss: 0.6742 - accuracy: 0.7188 - 18ms/epoch - 9ms/step
# Epoch 83/200
# 2/2 - 0s - loss: 0.6714 - accuracy: 0.7188 - 17ms/epoch - 9ms/step
# Epoch 84/200
# 2/2 - 0s - loss: 0.6685 - accuracy: 0.7188 - 16ms/epoch - 8ms/step
# Epoch 85/200
# 2/2 - 0s - loss: 0.6664 - accuracy: 0.7188 - 18ms/epoch - 9ms/step
# Epoch 86/200
# 2/2 - 0s - loss: 0.6638 - accuracy: 0.7188 - 20ms/epoch - 10ms/step
# Epoch 87/200
# 2/2 - 0s - loss: 0.6617 - accuracy: 0.7188 - 19ms/epoch - 9ms/step
# Epoch 88/200
# 2/2 - 0s - loss: 0.6593 - accuracy: 0.7188 - 17ms/epoch - 9ms/step
# Epoch 89/200
# 2/2 - 0s - loss: 0.6574 - accuracy: 0.7188 - 17ms/epoch - 8ms/step
# Epoch 90/200
# 2/2 - 0s - loss: 0.6556 - accuracy: 0.7188 - 18ms/epoch - 9ms/step
# Epoch 91/200
# 2/2 - 0s - loss: 0.6538 - accuracy: 0.7188 - 17ms/epoch - 9ms/step
# Epoch 92/200
# 2/2 - 0s - loss: 0.6520 - accuracy: 0.7188 - 17ms/epoch - 8ms/step
# Epoch 93/200
# 2/2 - 0s - loss: 0.6504 - accuracy: 0.7188 - 17ms/epoch - 8ms/step
# Epoch 94/200
# 2/2 - 0s - loss: 0.6489 - accuracy: 0.7188 - 17ms/epoch - 8ms/step
# Epoch 95/200
# 2/2 - 0s - loss: 0.6475 - accuracy: 0.7188 - 18ms/epoch - 9ms/step
# Epoch 96/200
# 2/2 - 0s - loss: 0.6460 - accuracy: 0.7188 - 18ms/epoch - 9ms/step
# Epoch 97/200
# 2/2 - 0s - loss: 0.6448 - accuracy: 0.7188 - 17ms/epoch - 9ms/step
# Epoch 98/200
# 2/2 - 0s - loss: 0.6437 - accuracy: 0.7188 - 18ms/epoch - 9ms/step
# Epoch 99/200
# 2/2 - 0s - loss: 0.6421 - accuracy: 0.7188 - 17ms/epoch - 8ms/step
# Epoch 100/200
# 2/2 - 0s - loss: 0.6413 - accuracy: 0.7188 - 16ms/epoch - 8ms/step
# Epoch 101/200
# 2/2 - 0s - loss: 0.6399 - accuracy: 0.7188 - 16ms/epoch - 8ms/step
# Epoch 102/200
# 2/2 - 0s - loss: 0.6388 - accuracy: 0.7188 - 19ms/epoch - 9ms/step
# Epoch 103/200
# 2/2 - 0s - loss: 0.6378 - accuracy: 0.7188 - 21ms/epoch - 11ms/step
# Epoch 104/200
# 2/2 - 0s - loss: 0.6369 - accuracy: 0.7188 - 17ms/epoch - 9ms/step
# Epoch 105/200
# 2/2 - 0s - loss: 0.6359 - accuracy: 0.7188 - 16ms/epoch - 8ms/step
# Epoch 106/200
# 2/2 - 0s - loss: 0.6349 - accuracy: 0.7188 - 16ms/epoch - 8ms/step
# Epoch 107/200
# 2/2 - 0s - loss: 0.6340 - accuracy: 0.7188 - 17ms/epoch - 9ms/step
# Epoch 108/200
# 2/2 - 0s - loss: 0.6332 - accuracy: 0.7188 - 18ms/epoch - 9ms/step
# Epoch 109/200
# 2/2 - 0s - loss: 0.6323 - accuracy: 0.7188 - 18ms/epoch - 9ms/step
# Epoch 110/200
# 2/2 - 0s - loss: 0.6317 - accuracy: 0.7188 - 18ms/epoch - 9ms/step
# Epoch 111/200
# 2/2 - 0s - loss: 0.6308 - accuracy: 0.7188 - 20ms/epoch - 10ms/step
# Epoch 112/200
# 2/2 - 0s - loss: 0.6301 - accuracy: 0.7188 - 18ms/epoch - 9ms/step
# Epoch 113/200
# 2/2 - 0s - loss: 0.6294 - accuracy: 0.7188 - 18ms/epoch - 9ms/step
# Epoch 114/200
# 2/2 - 0s - loss: 0.6286 - accuracy: 0.7188 - 18ms/epoch - 9ms/step
# Epoch 115/200
# 2/2 - 0s - loss: 0.6280 - accuracy: 0.7188 - 16ms/epoch - 8ms/step
# Epoch 116/200
# 2/2 - 0s - loss: 0.6277 - accuracy: 0.7188 - 29ms/epoch - 14ms/step
# Epoch 117/200
# 2/2 - 0s - loss: 0.6268 - accuracy: 0.7188 - 19ms/epoch - 9ms/step
# Epoch 118/200
# 2/2 - 0s - loss: 0.6262 - accuracy: 0.7188 - 21ms/epoch - 11ms/step
# Epoch 119/200
# 2/2 - 0s - loss: 0.6255 - accuracy: 0.7188 - 18ms/epoch - 9ms/step
# Epoch 120/200
# 2/2 - 0s - loss: 0.6249 - accuracy: 0.7188 - 19ms/epoch - 9ms/step
# Epoch 121/200
# 2/2 - 0s - loss: 0.6244 - accuracy: 0.7188 - 17ms/epoch - 8ms/step
# Epoch 122/200
# 2/2 - 0s - loss: 0.6239 - accuracy: 0.7188 - 18ms/epoch - 9ms/step
# Epoch 123/200
# 2/2 - 0s - loss: 0.6237 - accuracy: 0.7188 - 15ms/epoch - 7ms/step
# Epoch 124/200
# 2/2 - 0s - loss: 0.6228 - accuracy: 0.7188 - 17ms/epoch - 9ms/step
# Epoch 125/200
# 2/2 - 0s - loss: 0.6226 - accuracy: 0.7188 - 23ms/epoch - 11ms/step
# Epoch 126/200
# 2/2 - 0s - loss: 0.6220 - accuracy: 0.7188 - 17ms/epoch - 8ms/step
# Epoch 127/200
# 2/2 - 0s - loss: 0.6218 - accuracy: 0.7188 - 17ms/epoch - 8ms/step
# Epoch 128/200
# 2/2 - 0s - loss: 0.6211 - accuracy: 0.7188 - 18ms/epoch - 9ms/step
# Epoch 129/200
# 2/2 - 0s - loss: 0.6207 - accuracy: 0.7188 - 18ms/epoch - 9ms/step
# Epoch 130/200
# 2/2 - 0s - loss: 0.6201 - accuracy: 0.7188 - 17ms/epoch - 8ms/step
# Epoch 131/200
# 2/2 - 0s - loss: 0.6197 - accuracy: 0.7188 - 19ms/epoch - 9ms/step
# Epoch 132/200
# 2/2 - 0s - loss: 0.6193 - accuracy: 0.7188 - 17ms/epoch - 8ms/step
# Epoch 133/200
# 2/2 - 0s - loss: 0.6189 - accuracy: 0.7188 - 21ms/epoch - 10ms/step
# Epoch 134/200
# 2/2 - 0s - loss: 0.6185 - accuracy: 0.7188 - 18ms/epoch - 9ms/step
# Epoch 135/200
# 2/2 - 0s - loss: 0.6182 - accuracy: 0.7188 - 17ms/epoch - 8ms/step
# Epoch 136/200
# 2/2 - 0s - loss: 0.6178 - accuracy: 0.7188 - 17ms/epoch - 8ms/step
# Epoch 137/200
# 2/2 - 0s - loss: 0.6175 - accuracy: 0.7188 - 18ms/epoch - 9ms/step
# Epoch 138/200
# 2/2 - 0s - loss: 0.6173 - accuracy: 0.7188 - 17ms/epoch - 8ms/step
# Epoch 139/200
# 2/2 - 0s - loss: 0.6168 - accuracy: 0.7188 - 16ms/epoch - 8ms/step
# Epoch 140/200
# 2/2 - 0s - loss: 0.6165 - accuracy: 0.7188 - 16ms/epoch - 8ms/step
# Epoch 141/200
# 2/2 - 0s - loss: 0.6163 - accuracy: 0.7188 - 17ms/epoch - 8ms/step
# Epoch 142/200
# 2/2 - 0s - loss: 0.6158 - accuracy: 0.7188 - 17ms/epoch - 8ms/step
# Epoch 143/200
# 2/2 - 0s - loss: 0.6156 - accuracy: 0.7188 - 14ms/epoch - 7ms/step
# Epoch 144/200
# 2/2 - 0s - loss: 0.6153 - accuracy: 0.7188 - 16ms/epoch - 8ms/step
# Epoch 145/200
# 2/2 - 0s - loss: 0.6150 - accuracy: 0.7188 - 19ms/epoch - 10ms/step
# Epoch 146/200
# 2/2 - 0s - loss: 0.6148 - accuracy: 0.7188 - 16ms/epoch - 8ms/step
# Epoch 147/200
# 2/2 - 0s - loss: 0.6145 - accuracy: 0.7188 - 17ms/epoch - 8ms/step
# Epoch 148/200
# 2/2 - 0s - loss: 0.6141 - accuracy: 0.7188 - 16ms/epoch - 8ms/step
# Epoch 149/200
# 2/2 - 0s - loss: 0.6138 - accuracy: 0.7188 - 16ms/epoch - 8ms/step
# Epoch 150/200
# 2/2 - 0s - loss: 0.6140 - accuracy: 0.7188 - 16ms/epoch - 8ms/step
# Epoch 151/200
# 2/2 - 0s - loss: 0.6135 - accuracy: 0.7188 - 22ms/epoch - 11ms/step
# Epoch 152/200
# 2/2 - 0s - loss: 0.6132 - accuracy: 0.7188 - 17ms/epoch - 8ms/step
# Epoch 153/200
# 2/2 - 0s - loss: 0.6129 - accuracy: 0.7188 - 18ms/epoch - 9ms/step
# Epoch 154/200
# 2/2 - 0s - loss: 0.6127 - accuracy: 0.7188 - 17ms/epoch - 8ms/step
# Epoch 155/200
# 2/2 - 0s - loss: 0.6126 - accuracy: 0.7188 - 16ms/epoch - 8ms/step
# Epoch 156/200
# 2/2 - 0s - loss: 0.6122 - accuracy: 0.7188 - 16ms/epoch - 8ms/step
# Epoch 157/200
# 2/2 - 0s - loss: 0.6119 - accuracy: 0.7188 - 15ms/epoch - 8ms/step
# Epoch 158/200
# 2/2 - 0s - loss: 0.6119 - accuracy: 0.7188 - 17ms/epoch - 9ms/step
# Epoch 159/200
# 2/2 - 0s - loss: 0.6115 - accuracy: 0.7188 - 15ms/epoch - 8ms/step
# Epoch 160/200
# 2/2 - 0s - loss: 0.6113 - accuracy: 0.7188 - 22ms/epoch - 11ms/step
# Epoch 161/200
# 2/2 - 0s - loss: 0.6111 - accuracy: 0.7188 - 20ms/epoch - 10ms/step
# Epoch 162/200
# 2/2 - 0s - loss: 0.6110 - accuracy: 0.7188 - 17ms/epoch - 8ms/step
# Epoch 163/200
# 2/2 - 0s - loss: 0.6107 - accuracy: 0.7188 - 15ms/epoch - 8ms/step
# Epoch 164/200
# 2/2 - 0s - loss: 0.6106 - accuracy: 0.7188 - 17ms/epoch - 8ms/step
# Epoch 165/200
# 2/2 - 0s - loss: 0.6103 - accuracy: 0.7188 - 15ms/epoch - 7ms/step
# Epoch 166/200
# 2/2 - 0s - loss: 0.6102 - accuracy: 0.7188 - 16ms/epoch - 8ms/step
# Epoch 167/200
# 2/2 - 0s - loss: 0.6104 - accuracy: 0.7188 - 19ms/epoch - 9ms/step
# Epoch 168/200
# 2/2 - 0s - loss: 0.6098 - accuracy: 0.7188 - 24ms/epoch - 12ms/step
# Epoch 169/200
# 2/2 - 0s - loss: 0.6100 - accuracy: 0.7188 - 20ms/epoch - 10ms/step
# Epoch 170/200
# 2/2 - 0s - loss: 0.6096 - accuracy: 0.7188 - 20ms/epoch - 10ms/step
# Epoch 171/200
# 2/2 - 0s - loss: 0.6093 - accuracy: 0.7188 - 22ms/epoch - 11ms/step
# Epoch 172/200
# 2/2 - 0s - loss: 0.6091 - accuracy: 0.7188 - 22ms/epoch - 11ms/step
# Epoch 173/200
# 2/2 - 0s - loss: 0.6090 - accuracy: 0.7188 - 19ms/epoch - 9ms/step
# Epoch 174/200
# 2/2 - 0s - loss: 0.6088 - accuracy: 0.7188 - 30ms/epoch - 15ms/step
# Epoch 175/200
# 2/2 - 0s - loss: 0.6086 - accuracy: 0.7188 - 26ms/epoch - 13ms/step
# Epoch 176/200
# 2/2 - 0s - loss: 0.6089 - accuracy: 0.7188 - 21ms/epoch - 10ms/step
# Epoch 177/200
# 2/2 - 0s - loss: 0.6084 - accuracy: 0.7188 - 21ms/epoch - 11ms/step
# Epoch 178/200
# 2/2 - 0s - loss: 0.6082 - accuracy: 0.7188 - 20ms/epoch - 10ms/step
# Epoch 179/200
# 2/2 - 0s - loss: 0.6080 - accuracy: 0.7188 - 23ms/epoch - 12ms/step
# Epoch 180/200
# 2/2 - 0s - loss: 0.6080 - accuracy: 0.7188 - 19ms/epoch - 10ms/step
# Epoch 181/200
# 2/2 - 0s - loss: 0.6079 - accuracy: 0.7188 - 20ms/epoch - 10ms/step
# Epoch 182/200
# 2/2 - 0s - loss: 0.6077 - accuracy: 0.7188 - 23ms/epoch - 12ms/step
# Epoch 183/200
# 2/2 - 0s - loss: 0.6078 - accuracy: 0.7188 - 20ms/epoch - 10ms/step
# Epoch 184/200
# 2/2 - 0s - loss: 0.6074 - accuracy: 0.7188 - 24ms/epoch - 12ms/step
# Epoch 185/200
# 2/2 - 0s - loss: 0.6072 - accuracy: 0.7188 - 18ms/epoch - 9ms/step
# Epoch 186/200
# 2/2 - 0s - loss: 0.6071 - accuracy: 0.7188 - 20ms/epoch - 10ms/step
# Epoch 187/200
# 2/2 - 0s - loss: 0.6070 - accuracy: 0.7188 - 19ms/epoch - 10ms/step
# Epoch 188/200
# 2/2 - 0s - loss: 0.6068 - accuracy: 0.7188 - 28ms/epoch - 14ms/step
# Epoch 189/200
# 2/2 - 0s - loss: 0.6067 - accuracy: 0.7188 - 26ms/epoch - 13ms/step
# Epoch 190/200
# 2/2 - 0s - loss: 0.6066 - accuracy: 0.7188 - 27ms/epoch - 13ms/step
# Epoch 191/200
# 2/2 - 0s - loss: 0.6066 - accuracy: 0.7188 - 25ms/epoch - 13ms/step
# Epoch 192/200
# 2/2 - 0s - loss: 0.6065 - accuracy: 0.7188 - 29ms/epoch - 14ms/step
# Epoch 193/200
# 2/2 - 0s - loss: 0.6062 - accuracy: 0.7188 - 26ms/epoch - 13ms/step
# Epoch 194/200
# 2/2 - 0s - loss: 0.6063 - accuracy: 0.7188 - 25ms/epoch - 12ms/step
# Epoch 195/200
# 2/2 - 0s - loss: 0.6060 - accuracy: 0.7188 - 25ms/epoch - 12ms/step
# Epoch 196/200
# 2/2 - 0s - loss: 0.6059 - accuracy: 0.7188 - 25ms/epoch - 13ms/step
# Epoch 197/200
# 2/2 - 0s - loss: 0.6058 - accuracy: 0.7188 - 26ms/epoch - 13ms/step
# Epoch 198/200
# 2/2 - 0s - loss: 0.6060 - accuracy: 0.7188 - 27ms/epoch - 13ms/step
# Epoch 199/200
# 2/2 - 0s - loss: 0.6056 - accuracy: 0.7188 - 28ms/epoch - 14ms/step
# Epoch 200/200
# 2/2 - 0s - loss: 0.6055 - accuracy: 0.7188 - 26ms/epoch - 13ms/step

# %%
#Evaluate the neural network
loss, accuracy = model.evaluate(X_test_reshaped, y_test)
# loss, accuracy, f1s, precision, recall = model.evaluate(X_test_reshaped, y_test)
end_predict = time.time()
model_performance.loc['LSTM (Keras)'] = [accuracy, accuracy, accuracy, accuracy,end_train-start,end_predict-end_train,end_predict-start]
# Out:
# 1/1 [==============================] - 2s 2s/step - loss: 0.6944 - accuracy: 0.6250

# %%
model_performance.fillna(.90,inplace=True)
model_performance.style.background_gradient(cmap='coolwarm').format({'Accuracy': '{:.2%}',
                                                                     'Precision': '{:.2%}',
                                                                     'Recall': '{:.2%}',
                                                                     'F1-Score': '{:.2%}',
                                                                     'time to train':'{:.1f}',
                                                                     'time to predict':'{:.1f}',
                                                                     'total time':'{:.1f}',
                                                                     })
# Out:
# <style type="text/css">
# #T_83917_row0_col0, #T_83917_row0_col1, #T_83917_row0_col2, #T_83917_row0_col3, #T_83917_row4_col0, #T_83917_row4_col1, #T_83917_row4_col2, #T_83917_row4_col3, #T_83917_row9_col4, #T_83917_row9_col5, #T_83917_row9_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_83917_row0_col4, #T_83917_row0_col5, #T_83917_row0_col6, #T_83917_row1_col2, #T_83917_row1_col3, #T_83917_row1_col4, #T_83917_row1_col5, #T_83917_row1_col6, #T_83917_row2_col2, #T_83917_row2_col3, #T_83917_row2_col4, #T_83917_row2_col5, #T_83917_row2_col6, #T_83917_row3_col0, #T_83917_row3_col1, #T_83917_row3_col4, #T_83917_row3_col5, #T_83917_row3_col6, #T_83917_row5_col0, #T_83917_row5_col1, #T_83917_row5_col5, #T_83917_row6_col2, #T_83917_row6_col3, #T_83917_row6_col4, #T_83917_row6_col5, #T_83917_row6_col6, #T_83917_row7_col2, #T_83917_row7_col3, #T_83917_row7_col4, #T_83917_row7_col5, #T_83917_row7_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_83917_row1_col0, #T_83917_row1_col1, #T_83917_row2_col0, #T_83917_row2_col1, #T_83917_row6_col0, #T_83917_row6_col1, #T_83917_row7_col0, #T_83917_row7_col1, #T_83917_row8_col0, #T_83917_row8_col1, #T_83917_row8_col6, #T_83917_row9_col0, #T_83917_row9_col1, #T_83917_row10_col0, #T_83917_row10_col1 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_83917_row3_col2, #T_83917_row5_col2 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_83917_row3_col3, #T_83917_row5_col3 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_83917_row4_col4, #T_83917_row4_col6 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_83917_row4_col5, #T_83917_row5_col4, #T_83917_row5_col6 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_83917_row8_col2, #T_83917_row9_col2, #T_83917_row10_col2 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_83917_row8_col3, #T_83917_row9_col3, #T_83917_row10_col3 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_83917_row8_col4 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_83917_row8_col5 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_83917_row10_col4 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_83917_row10_col5 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_83917_row10_col6 {
#   background-color: #f7b093;
#   color: #000000;
# }
# </style>
# <table id="T_83917" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_83917_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_83917_level0_col1" class="col_heading level0 col1" >Recall</th>
#       <th id="T_83917_level0_col2" class="col_heading level0 col2" >Precision</th>
#       <th id="T_83917_level0_col3" class="col_heading level0 col3" >F1-Score</th>
#       <th id="T_83917_level0_col4" class="col_heading level0 col4" >time to train</th>
#       <th id="T_83917_level0_col5" class="col_heading level0 col5" >time to predict</th>
#       <th id="T_83917_level0_col6" class="col_heading level0 col6" >total time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83917_level0_row0" class="row_heading level0 row0" >KNN</th>
#       <td id="T_83917_row0_col0" class="data row0 col0" >75.00%</td>
#       <td id="T_83917_row0_col1" class="data row0 col1" >75.00%</td>
#       <td id="T_83917_row0_col2" class="data row0 col2" >82.14%</td>
#       <td id="T_83917_row0_col3" class="data row0 col3" >70.83%</td>
#       <td id="T_83917_row0_col4" class="data row0 col4" >0.0</td>
#       <td id="T_83917_row0_col5" class="data row0 col5" >0.0</td>
#       <td id="T_83917_row0_col6" class="data row0 col6" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_83917_level0_row1" class="row_heading level0 row1" >SVC</th>
#       <td id="T_83917_row1_col0" class="data row1 col0" >62.50%</td>
#       <td id="T_83917_row1_col1" class="data row1 col1" >62.50%</td>
#       <td id="T_83917_row1_col2" class="data row1 col2" >39.06%</td>
#       <td id="T_83917_row1_col3" class="data row1 col3" >48.08%</td>
#       <td id="T_83917_row1_col4" class="data row1 col4" >0.0</td>
#       <td id="T_83917_row1_col5" class="data row1 col5" >0.0</td>
#       <td id="T_83917_row1_col6" class="data row1 col6" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_83917_level0_row2" class="row_heading level0 row2" >Logistic</th>
#       <td id="T_83917_row2_col0" class="data row2 col0" >62.50%</td>
#       <td id="T_83917_row2_col1" class="data row2 col1" >62.50%</td>
#       <td id="T_83917_row2_col2" class="data row2 col2" >39.06%</td>
#       <td id="T_83917_row2_col3" class="data row2 col3" >48.08%</td>
#       <td id="T_83917_row2_col4" class="data row2 col4" >0.0</td>
#       <td id="T_83917_row2_col5" class="data row2 col5" >0.0</td>
#       <td id="T_83917_row2_col6" class="data row2 col6" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_83917_level0_row3" class="row_heading level0 row3" >Decision Tree</th>
#       <td id="T_83917_row3_col0" class="data row3 col0" >50.00%</td>
#       <td id="T_83917_row3_col1" class="data row3 col1" >50.00%</td>
#       <td id="T_83917_row3_col2" class="data row3 col2" >50.00%</td>
#       <td id="T_83917_row3_col3" class="data row3 col3" >50.00%</td>
#       <td id="T_83917_row3_col4" class="data row3 col4" >0.0</td>
#       <td id="T_83917_row3_col5" class="data row3 col5" >0.0</td>
#       <td id="T_83917_row3_col6" class="data row3 col6" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_83917_level0_row4" class="row_heading level0 row4" >Extra Trees</th>
#       <td id="T_83917_row4_col0" class="data row4 col0" >75.00%</td>
#       <td id="T_83917_row4_col1" class="data row4 col1" >75.00%</td>
#       <td id="T_83917_row4_col2" class="data row4 col2" >82.14%</td>
#       <td id="T_83917_row4_col3" class="data row4 col3" >70.83%</td>
#       <td id="T_83917_row4_col4" class="data row4 col4" >0.2</td>
#       <td id="T_83917_row4_col5" class="data row4 col5" >0.0</td>
#       <td id="T_83917_row4_col6" class="data row4 col6" >0.2</td>
#     </tr>
#     <tr>
#       <th id="T_83917_level0_row5" class="row_heading level0 row5" >Random Forest</th>
#       <td id="T_83917_row5_col0" class="data row5 col0" >50.00%</td>
#       <td id="T_83917_row5_col1" class="data row5 col1" >50.00%</td>
#       <td id="T_83917_row5_col2" class="data row5 col2" >50.00%</td>
#       <td id="T_83917_row5_col3" class="data row5 col3" >50.00%</td>
#       <td id="T_83917_row5_col4" class="data row5 col4" >0.2</td>
#       <td id="T_83917_row5_col5" class="data row5 col5" >0.0</td>
#       <td id="T_83917_row5_col6" class="data row5 col6" >0.3</td>
#     </tr>
#     <tr>
#       <th id="T_83917_level0_row6" class="row_heading level0 row6" >Gradient Boosting Classifier</th>
#       <td id="T_83917_row6_col0" class="data row6 col0" >62.50%</td>
#       <td id="T_83917_row6_col1" class="data row6 col1" >62.50%</td>
#       <td id="T_83917_row6_col2" class="data row6 col2" >39.06%</td>
#       <td id="T_83917_row6_col3" class="data row6 col3" >48.08%</td>
#       <td id="T_83917_row6_col4" class="data row6 col4" >0.1</td>
#       <td id="T_83917_row6_col5" class="data row6 col5" >0.0</td>
#       <td id="T_83917_row6_col6" class="data row6 col6" >0.1</td>
#     </tr>
#     <tr>
#       <th id="T_83917_level0_row7" class="row_heading level0 row7" >MLP</th>
#       <td id="T_83917_row7_col0" class="data row7 col0" >62.50%</td>
#       <td id="T_83917_row7_col1" class="data row7 col1" >62.50%</td>
#       <td id="T_83917_row7_col2" class="data row7 col2" >39.06%</td>
#       <td id="T_83917_row7_col3" class="data row7 col3" >48.08%</td>
#       <td id="T_83917_row7_col4" class="data row7 col4" >0.0</td>
#       <td id="T_83917_row7_col5" class="data row7 col5" >0.0</td>
#       <td id="T_83917_row7_col6" class="data row7 col6" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_83917_level0_row8" class="row_heading level0 row8" >MLP (Keras)</th>
#       <td id="T_83917_row8_col0" class="data row8 col0" >62.50%</td>
#       <td id="T_83917_row8_col1" class="data row8 col1" >62.50%</td>
#       <td id="T_83917_row8_col2" class="data row8 col2" >62.50%</td>
#       <td id="T_83917_row8_col3" class="data row8 col3" >62.50%</td>
#       <td id
