# %%
from b_fetch_data import fetch_news, fetch_stock_data
from a_calculations import calculate_max_drawdown, calculate_portfolio_metrics, calculate_sharpe_ratio, plot_signals
from c_sentiment import aggregate_sentiment_scores, generate_trading_signals, calculate_sentiment_scores
from d_simulate_trade import simulate_trades
from e_main import final
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Legion\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
tickers=['AMZN', 'TSLA', 'GOOGL', 'ADBE', 'AXP', 'META', 'NVDA' ,'SPOT' ,'MSFT' ,'JPM']

# %%
import os

# Ensure the directory exists
os.makedirs('csv_files', exist_ok=True)

for ticker in tickers:
    news = fetch_news(ticker)
    news.to_csv(f"csv_files/{ticker}.csv", index=False)
# Out:
# Fetching news for AMZN...
# Fetching news headlines...
#   0%|          | 0/9 [00:00<?, ?it/s]
# 450 headlines scraped from 10 pages
# Fetching news for TSLA...
# Fetching news headlines...
# c:\Users\Legion\Desktop\stock sentiment\b_fetch_data.py:35: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   0%|          | 0/9 [00:00<?, ?it/s]
# 450 headlines scraped from 10 pages
# Fetching news for GOOGL...
# Fetching news headlines...
# c:\Users\Legion\Desktop\stock sentiment\b_fetch_data.py:35: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   0%|          | 0/9 [00:00<?, ?it/s]
# 450 headlines scraped from 10 pages
# Fetching news for ADBE...
# Fetching news headlines...
# ...

# %%
news.head()
# Out:
#   ticker         source                                           headline  \
# 0    jpm    PR Newswire  J.P. MORGAN PRESENTS ANNUAL CURATION OF BOOKS ...
# 1    jpm  InvestorPlace  3 Compelling Stocks to Buy Ahead of Cyber Mond...
# 2    jpm  InvestorPlace  3 Stocks to Buy With Your Holiday Bonus This Year
# 3    jpm  InvestorPlace  Sell Alert: 3 Blue-Chip Stocks Giving Off Majo...
# 4    jpm  InvestorPlace  3 Must-Own Dividend Stocks for Plenty of Passi...
#
#          date      time
# 0  2023-11-20  15:30:00
# 1  2023-11-20  20:37:51
# 2  2023-11-21  10:00:00
# 3  2023-11-22  00:19:33
# 4  2023-11-22  19:56:57

# %%
import pandas as pd
final("NVDA", 0.03, 10000, pd.read_csv(f"csv_files/NVDA.csv"))
# Out:
# Fetching stock prices for NVDA ...
# [*********************100%%**********************]  1 of 1 completed
# Simulating trades...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Legion\Desktop\stock sentiment\.venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'profit'
#
# The above exception was the direct cause of the following exception:
#
# ...
